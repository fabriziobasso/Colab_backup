# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriziobasso/Colab_backup/blob/main/File_02_Calories_NN_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PREDICTING CALOORIES BURNED
#
# ## RMSLE Metric and Competition Context
#
# This notebook is developed for a data science competition focused on predicting **Calories burned** during exercise. The evaluation metric for this competition is the **Root Mean Squared Logarithmic Error (RMSLE)**, which measures the square root of the mean squared difference between the logarithms of predicted and actual values. RMSLE is ideal for datasets with a wide range of target values, as it emphasizes **relative errors**, ensuring balanced performance across small and large calorie values.
#
# The RMSLE formula is:
#
# ![](https://miro.medium.com/v2/resize:fit:720/format:webp/0*AUzyQ1rc6mpQVYfn)
#
# ### Why RMSLE?
# - **Handles Wide Ranges**: RMSLE penalizes relative errors proportionally, making it robust for calorie values ranging from small (e.g., 10 calories) to large (e.g., 1000 calories).
# - **Balanced Evaluation**: Ensures models perform well across the entire spectrum of calorie burn.
# - **Competition Goal**: A lower RMSLE score indicates a precise and generalizable model, critical for ranking high on the leaderboard.
#
# ---
#
# ## Potential Effects of Features on Calorie Burn
#
# The dataset includes the following features to predict calorie burn: **Sex**, **Age**, **Height**, **Weight**, **Duration**, **Heart_Rate**, and **Body_Temp**. Below, we explore how each feature might influence calorie burn:
#
# ### 1. Sex
# - **Impact**: Differences in metabolic rates and muscle mass between males and females affect calorie burn. Males often have higher muscle mass, leading to greater calorie expenditure for the same exercise.
# - **Example**: A male running at the same pace and duration as a female may burn more calories due to higher energy demands.
#
# ### 2. Age
# - **Impact**: Basal metabolic rate (BMR) decreases with age, reducing calorie burn in older individuals due to lower metabolic rates and muscle mass (sarcopenia).
# - **Example**: A 20-year-old may burn more calories than a 50-year-old during identical workouts.
#
# ### 3. Height
# - **Impact**: Taller individuals have more body mass or muscle, requiring more energy for movement, thus burning more calories. Height’s effect is often linked to weight and exercise intensity.
# - **Example**: A taller person may expend more energy covering the same distance.
#
# ### 4. Weight
# - **Impact**: Heavier individuals burn more calories due to the energy required to move greater body mass. Body composition (fat vs. muscle) also influences calorie burn.
# - **Example**: A 90 kg individual burns more calories walking the same distance as a 60 kg individual.
#
# ### 5. Duration
# - **Impact**: Longer exercise sessions directly increase total calorie expenditure, though intensity and exercise type also matter.
# - **Example**: Running for 30 minutes burns more calories than running for 15 minutes.
#
# ### 6. Heart_Rate
# - **Impact**: Higher heart rates indicate greater exercise intensity and metabolic effort, leading to increased calorie burn. Fitness levels can modulate heart rate responses.
# - **Example**: High heart rate during a HIIT workout correlates with higher calorie burn.
#
# ### 7. Body_Temp
# - **Impact**: Rising body temperature during exercise reflects increased metabolic activity and thermoregulation, potentially increasing calorie burn. Environmental factors (e.g., heat) also play a role.
# - **Example**: Exercising in a hot environment may increase calorie expenditure due to thermoregulation.
#
# ---
#
# ## Transition to Analysis
#
# Understanding the relationships between these features and calorie burn is key to building a predictive model. In this notebook, we will:
#
# 1. **Explore Data**: Analyze the distribution of the target variable (**Calories**) and features using visualizations (e.g., histograms, boxplots).
# 2. **Correlation Analysis**: Identify relationships between features and the target using correlation matrices and polar plots.
# 3. **Outlier Detection**: Address anomalies that could skew model performance.
# 4. **Feature Engineering**: Apply techniques like quantile and equal-width binning to enhance model input.
# 5. **Model Development**: Build and evaluate models to minimize RMSLE, aligning with competition objectives.
#
# ### Visualization Strategy
# We will use:
# - **Histograms** and **boxplots** to examine feature distributions.
# - **Correlation matrices** to uncover feature relationships.
# - **Polar plots** for creative visualization of feature impacts.
# - **Pair plots** to explore pairwise relationships.
#
# By systematically analyzing the data, we aim to develop a robust model that accurately predicts calorie burn and excels in the competition.
#
# ---

# %% [markdown]
# # 0.0 Setting

# %% [markdown]
# ## 0.1 Import Libraries:

# %%
# !pip uninstall scikit-learn
# !pip install scikit-learn==1.4

# %%
# %%capture
#!pip install -qq pytorch_tabnet
# !pip install optuna
# !pip install --upgrade catboost
#!pip install optuna-integration-pytorch-tabnet

#from pytorch_tabnet.tab_model import TabNetRegressor

# !pip install --upgrade category-encoders
# !pip install optuna-integration
# !pip install colorama
#!pip install pyfiglet
#!pip install keras-tuner --upgrade
#!pip install keras-nlp
#!pip install BorutaShap
#!pip install scikit-learn==1.2.2
#!pip install scikit-lego
# !pip install skops

# %%
import sklearn
import lightgbm, xgboost, catboost
sklearn.__version__, lightgbm.__version__, xgboost.__version__, catboost.__version__
# Out:
# ('1.6.1', '4.5.0', '2.1.4', '1.2.8')

# %%
# Setup notebook
from pathlib import Path
import ipywidgets as widgets
import pandas as pd
import numpy as np
from pickle import load, dump
import json
import joblib
#from joblib import dump, load
#import calplot as cal

# Graphic Libraries:
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
from termcolor import colored
# Set Style
sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5});
sns.despine(left=True, bottom=True, top=False, right=False);
mpl.rcParams['figure.dpi'] = 120;
mpl.rc('axes', labelsize=12);
plt.rc('xtick',labelsize=10);
plt.rc('ytick',labelsize=10);

mpl.rcParams['axes.spines.top'] = False;
mpl.rcParams['axes.spines.right'] = False;
mpl.rcParams['axes.spines.left'] = True;

# Palette Setup
colors = ['#FB5B68','#FFEB48','#2676A1','#FFBDB0',]
colormap_0 = mpl.colors.LinearSegmentedColormap.from_list("",colors)
palette_1 = sns.color_palette("coolwarm", as_cmap=True)
palette_2 = sns.color_palette("YlOrBr", as_cmap=True)
palette_3 = sns.light_palette("red", as_cmap=True)
palette_4 = sns.color_palette("viridis", as_cmap=True)
palette_5 = sns.color_palette("rocket", as_cmap=True)
palette_6 = sns.color_palette("GnBu", as_cmap=True)
palette_7 = sns.color_palette("tab20c", as_cmap=False)
palette_8 = sns.color_palette("Set2", as_cmap=False)

palette_custom = ['#fbb4ae','#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#f2f2f2']
palette_9 = sns.color_palette(palette_custom, as_cmap=False)

# tool for Excel:
from openpyxl import load_workbook, Workbook
from openpyxl.drawing.image import Image
from openpyxl.styles import Border, Side, PatternFill, Font, GradientFill, Alignment
from openpyxl.worksheet.cell_range import CellRange

from openpyxl.formatting import Rule
from openpyxl.styles import Font, PatternFill, Border
from openpyxl.styles.differential import DifferentialStyle

# Bloomberg
#from xbbg import blp
from catboost import CatBoostRegressor, Pool, CatBoostClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from xgboost.callback import EarlyStopping

import lightgbm as lgb
from lightgbm import (LGBMRegressor,
                      LGBMClassifier,
                      early_stopping,
                      record_evaluation,
                      log_evaluation)

# Time Management
from tqdm import tqdm
from datetime import date
from datetime import datetime
from pandas.tseries.offsets import BMonthEnd, QuarterEnd
import datetime
from pandas.tseries.offsets import BDay # BDay is business day, not birthday...
import datetime as dt
import click
import glob
import os
import gc
import re
import string

from ipywidgets import AppLayout
from ipywidgets import Dropdown, Layout, HTML, AppLayout, VBox, Label, HBox, BoundedFloatText, interact, Output

#from my_func import *

import optuna
from optuna.integration import TFKerasPruningCallback
from optuna.trial import TrialState
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_contour

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from tensorflow.keras import backend as K

from keras import ops
from keras import layers
from keras import activations

from keras.layers import Input, LSTM, Dense, Lambda, RepeatVector, Reshape
from keras.models import Model
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError

from keras.utils import FeatureSpace, plot_model

# Import libraries for Hypertuning
#import keras_tuner as kt
#from keras_tuner.tuners import RandomSearch, GridSearch, BayesianOptimization

#from my_func import *

# preprocessing modules
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RepeatedKFold, cross_val_score, cross_validate, GroupKFold, GridSearchCV, RepeatedStratifiedKFold, cross_val_predict
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

from sklearn.preprocessing import (LabelEncoder,
                                   StandardScaler,
                                   MinMaxScaler,
                                   OrdinalEncoder,
                                   RobustScaler,
                                   PowerTransformer,
                                   OneHotEncoder,
                                   QuantileTransformer,
                                   PolynomialFeatures,
                                   FunctionTransformer)

# metrics
import sklearn
#import skops.io as sio
from sklearn.metrics import (mean_squared_error,
                             root_mean_squared_error,
                             root_mean_squared_log_error,
                             r2_score,
                             mean_absolute_error,
                             mean_absolute_percentage_error,
                             classification_report,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                             multilabel_confusion_matrix,
                             accuracy_score,
                             roc_auc_score,
                             auc,
                             roc_curve,
                             log_loss,
                             make_scorer)
# modeling algos
from sklearn.linear_model import (LogisticRegression,
                                  Lasso,
                                  ridge_regression,
                                  LinearRegression,
                                  Ridge,
                                  RidgeCV,
                                  ElasticNet,
                                  BayesianRidge,
                                  HuberRegressor,
                                  TweedieRegressor,
                                  QuantileRegressor,
                                  ARDRegression,
                                  TheilSenRegressor,
                                  PoissonRegressor,
                                  GammaRegressor)

from sklearn.ensemble import (AdaBoostRegressor,
                              AdaBoostClassifier,
                              RandomForestRegressor,
                              RandomForestClassifier,
                              VotingRegressor,
                              GradientBoostingRegressor,
                              GradientBoostingClassifier,
                              StackingRegressor,
                              StackingClassifier,
                              HistGradientBoostingClassifier,
                              HistGradientBoostingRegressor,
                              ExtraTreesClassifier)

from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.base import clone
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from category_encoders import TargetEncoder, CatBoostEncoder, LeaveOneOutEncoder, OrdinalEncoder, CountEncoder

from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

from sklearn.multioutput import RegressorChain

import itertools
import warnings
from openpyxl import load_workbook

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

import statsmodels.api as sm
from pylab import rcParams
import scipy.stats as ss

#from category_encoders.cat_boost import CatBoostEncoder
#from category_encoders.wrapper import PolynomialWrapper
#from category_encoders.count import CountEncoder
#from category_encoders import TargetEncoder

import skops.io as sio

warnings.filterwarnings('ignore')
#import pyfiglet
#plt.style.use('fivethirtyeight')

# %% [markdown]
# **Formatting and Settings:**

# %%
sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.5,
         'grid.alpha'           :0.5,
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : 'black',
         'axes.titlesize'       : 12,
#         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,
        });

sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5})
# Set Style
mpl.rcParams['figure.dpi'] = 120;

# import font colors
from colorama import Fore, Style, init

# Making sklearn pipeline outputs as dataframe:-
pd.set_option('display.max_columns', 100);
pd.set_option('display.max_rows', 50);

sns.despine(left=True, bottom=True, top=False, right=False)

mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = True

init(autoreset=True)

# %%
from tqdm import tqdm
from itertools import product

import numpy as np
import pandas as pd
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import GroupKFold
from sklearn.impute import SimpleImputer
import torch

import warnings
warnings.filterwarnings("ignore")

# Connect to Colab:#
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 0.2 Functions:

# %% [markdown]
# * **Plotting Functiss**

# %%
def plot_scatter(df, x="feat1", y="feat2", color_feature=None, cmap='viridis'):
    """
    Generates a scatter plot with points colored based on a third feature.

    Args:
        df: Pandas DataFrame containing the data.
        x: Name of the column to use for the x-axis.
        y: Name of the column to use for the y-axis.
        color_feature: Name of the column to use for coloring the points.
                       If None, points will be a single color.
        cmap: Colormap to use for coloring the points (e.g., 'viridis', 'plasma', 'magma', 'inferno', 'cividis').
              See matplotlib documentation for available colormaps.
    """

    plt.figure(figsize=(8, 5))

    if color_feature is not None:
        # Ensure the color feature exists
        if color_feature not in df.columns:
            raise ValueError(f"Color feature '{color_feature}' not found in DataFrame.")

        # Scatter plot with colors
        scatter = plt.scatter(df[x], df[y], c=df[color_feature], cmap=cmap)

        # Add a colorbar
        cbar = plt.colorbar(scatter)
        cbar.set_label(color_feature)  # Label the colorbar

    else:
        # Simple scatter plot (single color)
        plt.scatter(df[x], df[y],color="royalblue",alpha=0.6)

    plt.xlabel(x)
    plt.ylabel(y)
    plt.title("Scatter Plot")  # Add a title for better visualization
    plt.show()

# %% [markdown]
# * **Dataset Management Functions**:

# %%
class Config:

    state = 42
    n_splits = 10
    early_stop = 200

    target = 'Calories'
    train = pd.read_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train.csv')
    test = pd.read_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/test.csv')
    submission = pd.read_csv( "/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv")
    #train_org = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/original.csv")

    original_data = 'N'
    outliers = 'N'
    log_trf = 'Y'
    scaler_trf = 'Y'
    feature_eng = 'N'
    missing = 'Y'
    sqrt_normalization="Y"
    impose_normalization="N"
    trg_enc = "N"
    problem = "Regression"
    metric_goal="LRMSE"
    direction_="minimize"
    log_trans_cols = ["Body_Temp"]
    sqrt_norm_cols = ["Age"]
    impose_norm_cols = []
    trg_enc_feat = []

class Preprocessing():

    def __init__(self):
        self.train = Config.train
        self.test = Config.test
        self.targets = Config.target

        self.prp_data()

    def prp_data(self):

        if Config.original_data == 'Y':
            self.train = pd.concat([self.train, Config.train_org], ignore_index=True).drop_duplicates(ignore_index=True)

        self.train = self.train.drop(['id'], axis=1)
        self.test = self.test.drop(['id'], axis=1)

        self.cat_features = self.train.drop(self.targets, axis=1).select_dtypes(include=['object', 'bool']).columns.tolist()
        self.num_features = self.train.drop(self.targets, axis=1).select_dtypes(exclude=['object', 'bool']).columns.tolist()

        self.train = self.reduce_mem(self.train)
        self.test = self.reduce_mem(self.test)
        return self

    def reduce_mem(self, df):

        numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64', "uint16", "uint32", "uint64"]

        for col in df.columns:
            col_type = df[col].dtypes

            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()

                if "int" in str(col_type):
                    if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)
                else:
                    if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float32)
                    if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)

        return df

class EDA(Config, Preprocessing):

    def __init__(self):
        super().__init__()

        self.data_info()
        self.heatmap()
        self.dist_plots()
        self.cat_feature_plots()
        if Config.problem == 'Classification':
          self.target_pie()
        else:
          self.target_dist()

    def data_info(self):

        for data, label in zip([self.train, self.test], ['Train', 'Test']):
            table_style = [{'selector': 'th:not(.index_name)',
                            'props': [('background-color', 'slategrey'),
                                      ('color', '#FFFFFF'),
                                      ('font-weight', 'bold'),
                                      ('border', '1px solid #DCDCDC'),
                                      ('text-align', 'center')]
                            },
                            {'selector': 'tbody td',
                             'props': [('border', '1px solid #DCDCDC'),
                                       ('font-weight', 'normal')]
                            }]
            print(Style.BRIGHT+Fore.RED+f'\n{label} head\n')
            display(data.head().style.set_table_styles(table_style))

            print(Style.BRIGHT+Fore.RED+f'\n{label} info\n'+Style.RESET_ALL)
            display(data.info())

            print(Style.BRIGHT+Fore.RED+f'\n{label} describe\n')
            display(data.describe().drop(index='count', columns=self.targets, errors = 'ignore').T
                    .style.set_table_styles(table_style).format('{:.3f}'))

            print(Style.BRIGHT+Fore.RED+f'\n{label} missing values\n'+Style.RESET_ALL)
            display(data.isnull().sum())
        return self

    def heatmap(self):
        print(Style.BRIGHT+Fore.RED+f'\nCorrelation Heatmap\n')
        plt.figure(figsize=(7,7))
        corr = self.train.select_dtypes(exclude='object').corr(method='pearson')
        sns.heatmap(corr, fmt = '0.2f', cmap = 'Blues', annot=True, cbar=False)
        plt.show()

    def dist_plots(self):

        print(Style.BRIGHT+Fore.RED+f"\nDistribution analysis - Numerical\n")
        df = pd.concat([self.train[self.num_features].assign(Source = 'Train'),
                        self.test[self.num_features].assign(Source = 'Test'),],
                        axis=0, ignore_index = True)

        fig, axes = plt.subplots(len(self.num_features), 2 ,figsize = (13, len(self.num_features) * 4),
                                 gridspec_kw = {'hspace': 0.3,
                                                'wspace': 0.2,
                                                'width_ratios': [0.70, 0.30]
                                               }
                                )
        for i,col in enumerate(self.num_features):
            try:
                ax = axes[i,0]
            except:
                ax = axes[i]
            sns.kdeplot(data = df[[col, 'Source']], x = col, hue = 'Source',
                        palette = ['royalblue', 'tomato'], ax = ax, alpha=0.7, linewidth = 2
                       )
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col}")
            ax.grid('--',alpha=0.7)

            try:
                ax = axes[i,1]
            except:
                ax = axes[1]
            sns.boxplot(data = df, y = col, x=df.Source, width = 0.5,
                        linewidth = 1, fliersize= 1,
                        ax = ax, palette=['royalblue', 'tomato']
                       )
            ax.set_title(f"\n{col}")
            ax.set(xlabel = '', ylabel = '')
            ax.tick_params(axis='both', which='major')
            ax.set_xticklabels(['Train', 'Test'])

        plt.tight_layout()
        plt.show()

    def cat_feature_plots(self):
        print(Style.BRIGHT+Fore.RED+f"\nDistribution analysis - Categorical\n")
        fig, axes = plt.subplots(len(self.cat_features), 2 ,figsize = (18, len(self.cat_features) * 6),
                                 gridspec_kw = {'hspace': 0.5,
                                                'wspace': 0.2,
                                               }
                                )

        for i, col in enumerate(self.cat_features):
            try:
                ax = axes[i,0]
            except:
                ax = axes[i]
            sns.barplot(data=self.train[col].value_counts().nlargest(10).reset_index(), x=col, y='count', ax=ax, color='royalblue', alpha=0.7)
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col} Train")

            try:
                ax = axes[i,1]
            except:
                ax = axes[i+1]
            sns.barplot(data=self.test[col].value_counts().nlargest(10).reset_index(), x=col, y='count', ax=ax, color='tomato', alpha=0.7)
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col} Test")

        plt.tight_layout()
        plt.show()

    def target_pie(self):
        print(Style.BRIGHT+Fore.RED+f"\nTarget feature distribution\n")
        targets = self.train[self.targets]
        plt.figure(figsize=(6, 6))
        plt.pie(targets.value_counts(), labels=targets.value_counts().index, autopct='%1.2f%%', colors=palette_9)
        plt.show()

    def target_dist(self):
        print(Style.BRIGHT+Fore.RED+f"\nTarget feature distribution\n")
        fig, axes = plt.subplots(1, 1, figsize=(7, 5))
        sns.histplot(self.train[self.targets], kde=True, ax=axes)
        axes.set_title('Distribution of Price')
        axes.set_xlabel(self.targets)
        axes.set_ylabel('Frequency')

# %% [markdown]
# # 1.0 EDA

# %% [markdown]
# ## 1.1 Experiment Area:

# %%
class CFG:
    SEED    = 333
    CV      = KFold(n_splits=15, shuffle=True, random_state=SEED)
    VERSION = '1'

class Data:
    path       = False
    or_path    = ''
    to_drop    = False
    target     = 'Calories'
    drop_duplicates = False

    def __init__(self):
        self.train      = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_train_03.csv",index_col=0).drop(columns=self.to_drop) if self.to_drop else pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_train_03.csv",index_col=0)
        self.test       = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_test_03.csv",index_col=0).drop(columns=self.to_drop) if self.to_drop else pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_test_03.csv",index_col=0)
        self.submission = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)
        self.original   = pd.read_csv(self.or_path) if self.or_path else pd.DataFrame()

        self.train.loc[:,"BMI"] = np.clip(self.train.BMI, a_min=-5.0, a_max=5.0)
        self.test.loc[:,"BMI"] = np.clip(self.test.BMI, a_min=-5.0, a_max=5.0)

    @property
    def X(self):
        return self.train.drop(columns=self.target)
    @property
    def y(self):
        return self.train[[self.target]]
    @property
    def X_test(self):
        return self.test
    @property
    def X_original(self):
        if len(self.original) != 0:
            return self.original.drop(columns=self.target)
        return pd.DataFrame()
    @property
    def y_original(self):
        if len(self.original) != 0:
            return self.original[[self.target]]
        return pd.DataFrame()
    @property
    def cat_features(self):
        return self.X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
    @property
    def num_features(self):
        return self.X.select_dtypes(exclude=['category', 'bool', 'category','int']).columns.to_list()

    def submit(self, sub: np.ndarray, desc: str):
        '''Submit the predictions in the adequate format'''
        self.submission[self.target] = sub
        self.submission.to_csv(f'SUB_{CFG.VERSION}_{desc}.csv', index=False)
        print(colored('Submission has been made.', color='green', attrs=['bold', 'dark']))

    @staticmethod
    def sep_line():
        print(colored(f'{"_____"*14}', color='black'))
        print('')

    @staticmethod
    def head(head_text):
        print(colored(f'{"    "} ➩ {head_text} ', color='green', attrs=['dark']))

    def display_data(self):
        self.head(f'𝐃𝐚𝐭𝐚𝐬𝐞𝐭 𝐬𝐡𝐚𝐩𝐞𝐬 — 𝐓𝐫𝐚𝐢𝐧 | 𝐓𝐞𝐬𝐭: {self.train.shape} | {self.test.shape}')
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐡𝐞𝐚𝐝')
        display(self.train.head(5))
        self.head('𝐓𝐞𝐬𝐭 𝐡𝐞𝐚𝐝')
        display(self.test.head(5))
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐢𝐧𝐟𝐨')
        display(self.train.info())
        self.head('𝐓𝐞𝐬𝐭 𝐢𝐧𝐟𝐨')
        display(self.test.info())
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬')
        display(self.train.describe().T)
        self.head('𝐓𝐞𝐬𝐭 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬')
        display(self.test.describe().T)
        self.sep_line()

        def nunique_null(train, test):
            nunique_train, nunique_test = {}, {}
            nulls_train, nulls_test = {}, {}

            for col in test.columns:
                nunique_train[col], nunique_test[col] = train[col].nunique(), test[col].nunique()
                nulls_train[col], nulls_test[col] = train[col].isna().sum(), test[col].isna().sum()

            df = pd.DataFrame([nunique_train, nunique_test,
                               nulls_train, nulls_test],
                              index=['Train nunique', 'Test nunique',
                                     'Train null', 'Test null'])
            return df

        self.head('𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐚𝐧𝐝 𝐧𝐮𝐥𝐥𝐬')
        display(nunique_null(self.train, self.test))
        self.sep_line()

        self.head('𝐃𝐮𝐩𝐥𝐢𝐜𝐚𝐭𝐞𝐬')
        display(f'Train duplicated: {self.train.duplicated().sum()}')
        display(f'Test duplicated: {self.test.duplicated().sum()}')

        if self.drop_duplicates==True:
          if self.train.duplicated().sum() > 0:
              self.train = self.train.drop_duplicates()
              print('Train duplicates dropped.')
          if self.test.duplicated().sum() > 0:
              #self.test = self.test.drop_duplicates()
              print('Test duplicates dropped.')
        self.sep_line()

        self.head('𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐞𝐬𝐭/𝐢𝐧 𝐭𝐞𝐬𝐭 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧')
        cat_cols = [c for c in self.test.columns if self.train[c].nunique() <= 40 or
                    c in self.test.select_dtypes(include=['object', 'category']).columns]

        def compare_unique_categories(train, test, cat_cols):
            unique_train_dic, unique_test_dic = {}, {}

            for c in cat_cols:
                unique_train_c = train[c].unique()
                unique_test_c = test[c].unique()

                count_tr = sum(1 for cat in unique_train_c if cat not in unique_test_c and not pd.isna(cat))
                count_te = sum(1 for cat in unique_test_c if (cat not in unique_train_c and not pd.isna(cat)))

                unique_train_dic[c] = count_tr
                unique_test_dic[c] = count_te

            result_df = pd.DataFrame([unique_train_dic, unique_test_dic],
                                     index=['in train not in test', 'in test not in train'])

            return result_df

        display(compare_unique_categories(self.train, self.test, cat_cols))

data = Data()
data.display_data()
# Out:
#      ➩ 𝐃𝐚𝐭𝐚𝐬𝐞𝐭 𝐬𝐡𝐚𝐩𝐞𝐬 — 𝐓𝐫𝐚𝐢𝐧 | 𝐓𝐞𝐬𝐭: (765000, 16) | (250000, 15)
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐡𝐞𝐚𝐝
#    Sex    Height    Weight  Duration  Heart_Rate  Body_Temp       BMI  \
# 0    1  1.113015  0.489702  1.266169    0.583480   1.236062 -0.938031
# 1    0 -0.909676 -1.081265 -0.888638   -1.109199  -0.430898 -1.184666
# 2    0 -1.065268 -0.795635 -1.008350   -1.214992  -0.302671  0.209075
# 3    1  1.346402  1.060962  1.146458    1.006650   0.851379  0.026339
# 4    0 -0.676289 -1.009858  1.146458    0.689273   0.723151 -1.479569
#
#    Intensity  Intensity_v1  Heart_Duration  Weight_Duration_Heart  \
# 0   1.183180     -1.090611       -0.952799               1.338352
# 1  -0.923712     -0.418361        0.431582              -1.004625
# 2  -1.017567     -0.286300        0.610071              -1.047153
# 3   1.161541     -0.349679       -0.852901               1.619162
# 4   1.075158     -0.813342       -0.890178               0.535818
#
#    Outliers_Duration_Heart_Temp   BMI_Age       BMR  Age_Group  Calories
# 0                             0  0.848517  0.432900          3     150.0
# 1                             0 -0.455390 -1.608968          6      34.0
# 2                             0 -0.675342 -0.849602          5      29.0
# 3                             0  0.707173  1.219153          1     140.0
# 4                             0  0.799371 -0.340978          3     146.0
#      ➩ 𝐓𝐞𝐬𝐭 𝐡𝐞𝐚𝐝
#         Sex    Height    Weight  Duration  Heart_Rate  Body_Temp       BMI  \
# 750000    1  0.179465  0.418294 -1.008350   -0.897614  -0.302671  0.978939
# 750001    1  1.968769  1.560816  0.547900    0.583480   0.594924 -0.082149
# 750002    0  1.035219  0.703924  0.069054    0.689273   0.466696 -0.214836
# 750003    0 -0.209514 -0.152967  0.547900    1.218235   0.723151  0.199218
# 750004    0 -0.131718 -0.581412  0.069054   -0.157067   0.594924 -1.314534
#
#         Intensity  Intensity_v1  Heart_Duration  Weight_Duration_Heart  \
# 750000  -0.995739      0.295543        0.661858              -0.890129
# 750001   0.507888     -0.260413       -0.611173               1.078027
# 750002   0.093216      0.624933       -0.294981               0.309886
# 750003   0.640408      0.708943       -0.533902               0.544812
# 750004  -0.037914     -0.724309       -0.407071              -0.199594
#
#         Outliers_Duration_Heart_Temp   BMI_Age       BMR  Age_Group
# 750000                             0 -0.658590 -0.307455          4
# 750001                             0  0.470673  1.781711          2
# 750002                             0  0.254207  2.386314          2
# 750003                             0  0.691017  0.711718          3
# 750004                             0  0.119383  0.666806          2
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐢𝐧𝐟𝐨
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Height                        765000 non-null  float64
#  2   Weight                        765000 non-null  float64
#  3   Duration                      765000 non-null  float64
#  4   Heart_Rate                    765000 non-null  float64
#  5   Body_Temp                     765000 non-null  float64
#  6   BMI                           765000 non-null  float64
#  7   Intensity                     765000 non-null  float64
#  8   Intensity_v1                  765000 non-null  float64
#  9   Heart_Duration                765000 non-null  float64
#  10  Weight_Duration_Heart         765000 non-null  float64
#  11  Outliers_Duration_Heart_Temp  765000 non-null  int64
#  12  BMI_Age                       765000 non-null  float64
#  13  BMR                           765000 non-null  float64
#  14  Age_Group                     765000 non-null  int64
#  15  Calories                      765000 non-null  float64
# dtypes: float64(13), int64(3)
# memory usage: 99.2 MB
# None
#      ➩ 𝐓𝐞𝐬𝐭 𝐢𝐧𝐟𝐨
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           250000 non-null  int64
#  1   Height                        250000 non-null  float64
#  2   Weight                        250000 non-null  float64
#  3   Duration                      250000 non-null  float64
#  4   Heart_Rate                    250000 non-null  float64
#  5   Body_Temp                     250000 non-null  float64
#  6   BMI                           250000 non-null  float64
#  7   Intensity                     250000 non-null  float64
#  8   Intensity_v1                  250000 non-null  float64
#  9   Heart_Duration                250000 non-null  float64
#  10  Weight_Duration_Heart         250000 non-null  float64
#  11  Outliers_Duration_Heart_Temp  250000 non-null  int64
#  12  BMI_Age                       250000 non-null  float64
#  13  BMR                           250000 non-null  float64
#  14  Age_Group                     250000 non-null  int64
# dtypes: float64(12), int64(3)
# memory usage: 30.5 MB
# None
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬
#                                  count          mean        std       min  \
# Sex                           765000.0  4.989882e-01   0.499999  0.000000
# Height                        765000.0  5.077641e-16   1.000001 -4.021508
# Weight                        765000.0  1.343297e-16   1.000001 -2.795048
# Duration                      765000.0 -4.197311e-17   1.000001 -1.726619
# Heart_Rate                    765000.0  6.856041e-16   1.000001 -3.013464
# Body_Temp                     765000.0  1.793228e-14   1.000001 -3.764820
# BMI                           765000.0 -1.325152e-04   0.998632 -5.000000
# Intensity                     765000.0  3.098059e-17   1.000001 -1.563858
# Intensity_v1                  765000.0 -1.483010e-15   1.000001 -5.230777
# Heart_Duration                765000.0  1.511371e-15   1.000001 -1.390121
# Weight_Duration_Heart         765000.0  1.852636e-16   1.000001 -1.507367
# Outliers_Duration_Heart_Temp  765000.0  3.921569e-05   0.006262  0.000000
# BMI_Age                       765000.0 -5.015596e-18   1.000001 -3.650672
# BMR                           765000.0 -1.055950e-15   1.000001 -5.745514
# Age_Group                     765000.0  3.623880e+00   1.541745  1.000000
# Calories                      765000.0  8.830742e+01  62.396760  1.000000
#
#                                     25%        50%         75%         max
# Sex                            0.000000   0.000000    1.000000    1.000000
# Height                        -0.831880  -0.053922    0.801832    3.680276
# Weight                        -0.867043  -0.081559    0.846740    4.060081
# Duration                      -0.888638  -0.050658    0.907035    1.745015
# Heart_Rate                    -0.791822  -0.051275    0.795065    3.439877
# Body_Temp                     -0.559126   0.338468    0.851379    1.877201
# BMI                           -0.740093   0.011128    0.736294    5.000000
# Intensity                     -0.875844  -0.105610    0.840522    2.483148
# Intensity_v1                  -0.670825  -0.096130    0.539496    8.631268
# Heart_Duration                -0.757049  -0.333324    0.443798    4.005130
# Weight_Duration_Heart         -0.837452  -0.131506    0.702951    4.344034
# Outliers_Duration_Heart_Temp   0.000000   0.000000    0.000000    1.000000
# BMI_Age                       -0.557168   0.238599    0.770875    1.776116
# BMR                           -0.646752   0.062006    0.719987    4.142021
# Age_Group                      2.000000   3.000000    5.000000    7.000000
# Calories                      34.000000  77.000000  136.000000  314.000000
#      ➩ 𝐓𝐞𝐬𝐭 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬
#                                  count      mean       std       min  \
# Sex                           250000.0  0.498876  0.500000  0.000000
# Height                        250000.0  0.002528  0.997501 -3.710325
# Weight                        250000.0  0.000396  0.998243 -2.580825
# Duration                      250000.0 -0.000926  0.999487 -1.726619
# Heart_Rate                    250000.0 -0.000591  0.999756 -3.013464
# Body_Temp                     250000.0  0.000066  0.998186 -3.764820
# BMI                           250000.0 -0.004466  0.998080 -5.000000
# Intensity                     250000.0 -0.000928  0.999746 -1.563333
# Intensity_v1                  250000.0 -0.000195  0.998002 -4.522650
# Heart_Duration                250000.0 -0.000380  0.997461 -1.312222
# Weight_Duration_Heart         250000.0 -0.000767  0.999786 -1.505219
# Outliers_Duration_Heart_Temp  250000.0  0.000028  0.005291  0.000000
# BMI_Age                       250000.0 -0.000007  0.997969 -3.581874
# BMR                           250000.0  0.001987  0.996776 -4.471438
# Age_Group                     250000.0  3.623832  1.538621  1.000000
#
#                                    25%       50%       75%       max
# Sex                           0.000000  0.000000  1.000000  1.000000
# Height                       -0.831880 -0.053922  0.801832  3.446889
# Weight                       -0.867043 -0.081559  0.846740  3.631636
# Duration                     -0.888638 -0.050658  0.907035  1.745015
# Heart_Rate                   -0.791822 -0.051275  0.795065  3.439877
# Body_Temp                    -0.559126  0.338468  0.723151  1.877201
# BMI                          -0.740093  0.008131  0.728037  5.000000
# Intensity                    -0.876596 -0.107700  0.834455  2.493177
# Intensity_v1                 -0.670825 -0.096189  0.539496  7.783418
# Heart_Duration               -0.757049 -0.326515  0.437294  3.835281
# Weight_Duration_Heart        -0.837925 -0.134480  0.699004  4.053276
# Outliers_Duration_Heart_Temp  0.000000  0.000000  0.000000  1.000000
# BMI_Age                      -0.557096  0.237825  0.769008  1.660620
# BMR                          -0.643023  0.067942  0.720976  3.733496
# Age_Group                     2.000000  3.000000  5.000000  7.000000
# ______________________________________________________________________
#
#      ➩ 𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐚𝐧𝐝 𝐧𝐮𝐥𝐥𝐬
#                Sex  Height  Weight  Duration  Heart_Rate  Body_Temp   BMI  \
# Train nunique    2      92      92        30          63         75  2201
# Test nunique     2      85      84        30          61         51  1812
# Train null       0       0       0         0           0          0     0
# Test null        0       0       0         0           0          0     0
#
#                Intensity  Intensity_v1  Heart_Duration  Weight_Duration_Heart  \
# Train nunique      11378          1268            1102                  21630
# Test nunique        9097          1104             973                  19010
# Train null             0             0               0                      0
# Test null              0             0               0                      0
#
#                Outliers_Duration_Heart_Temp  BMI_Age    BMR  Age_Group
# Train nunique                             2   755723  56336          7
# Test nunique                              2   248941  43551          7
# Train null                                0        0      0          0
# Test null                                 0        0      0          0
# ______________________________________________________________________
#
#      ➩ 𝐃𝐮𝐩𝐥𝐢𝐜𝐚𝐭𝐞𝐬
# 'Train duplicated: 2893'
# 'Test duplicated: 918'
# ______________________________________________________________________
#
#      ➩ 𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐞𝐬𝐭/𝐢𝐧 𝐭𝐞𝐬𝐭 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧
#                       Sex  Duration  Outliers_Duration_Heart_Temp  Age_Group
# in train not in test    0         0                             0          0
# in test not in train    0         0                             0          0

# %%
data.X.shape, data.y.shape, data.X_test.shape
# Out:
# ((765000, 15), (765000, 1), (250000, 15))

# %%
print(data.cat_features)
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %%
#plot_scatter(pd.concat([data.X,data.y],axis=1), x="BMI", y="Intensity", color_feature="Calories")

# %%
data.X.info(),data.X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Height                        765000 non-null  float64
#  2   Weight                        765000 non-null  float64
#  3   Duration                      765000 non-null  float64
#  4   Heart_Rate                    765000 non-null  float64
#  5   Body_Temp                     765000 non-null  float64
#  6   BMI                           765000 non-null  float64
#  7   Intensity                     765000 non-null  float64
#  8   Intensity_v1                  765000 non-null  float64
#  9   Heart_Duration                765000 non-null  float64
#  10  Weight_Duration_Heart         765000 non-null  float64
#  11  Outliers_Duration_Heart_Temp  765000 non-null  int64
#  12  BMI_Age                       765000 non-null  float64
#  13  BMR                           765000 non-null  float64
#  14  Age_Group                     765000 non-null  int64
# dtypes: float64(12), int64(3)
# memory usage: 93.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           250000 non-null  int64
#  1   Height                        250000 non-null  float64
#  2   Weight                        250000 non-null  float64
#  3   Duration                      250000 non-null  float64
#  4   Heart_Rate                    250000 non-null  float64
#  5   Body_Temp                     250000 non-null  float64
#  6   BMI                           250000 non-null  float64
#  7   Intensity                     250000 non-null  float64
#  8   Intensity_v1                  250000 non-null  float64
#  9   Heart_Duration                250000 non-null  float64
#  10  Weight_Duration_Heart         250000 non-null  float64
#  11  Outliers_Duration_Heart_Temp  250000 non-null  int64
#  12  BMI_Age                       250000 non-null  float64
#  13  BMR                           250000 non-null  float64
#  14  Age_Group                     250000 non-null  int64
# dtypes: float64(12), int64(3)
# memory usage: 30.5 MB
# (None, None)

# %%
data.X_test.shape, data.y.shape

y_test_fic = data.y[:len(data.X_test)].copy()
y_test_fic["Calories"]=np.nan

# %% [markdown]
# # 2.0 Neural Networks:

# %%
def dataframe_to_dataset(dataframe, target, categorical_features, numerical_features, shuffle=False, batch_size=32):
    dataframe = dataframe.copy()
    ds = tf.data.Dataset.from_tensor_slices(((dataframe[categorical_features].values,  # First input
                                              dataframe[numerical_features].values),
                                              target))

    if shuffle:
      ds = ds.shuffle(buffer_size=len(dataframe))

    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)

    return ds

def dataframe_to_dataset_test(dataframe, target_finc, categorical_features, numerical_features, batch_size=32):
    dataframe = dataframe.copy()
    ds = tf.data.Dataset.from_tensor_slices(((dataframe[categorical_features].values,  # First input
                                              dataframe[numerical_features].values),
                                              target_finc))

    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)

    return ds

# %%
def plot_training_session(history):
  # Plot training and validation loss scores
  # against the number of epochs.
  plt.figure(figsize=(8, 6))
  plt.plot(history.history['loss'], label='Train')
  plt.plot(history.history['val_loss'], label='Validation')
  plt.grid(linestyle='--')
  plt.ylabel('val_loss')
  plt.xlabel('Epoch')
  plt.title('Train-Validation Scores', pad=13)
  plt.legend(loc='upper right');
  plt.show()

def rmsle(y_true, y_pred):
    """
    Root Mean Squared Logarithmic Error (RMSLE)
    """
    # Ensure y_pred is non-negative and add a small constant to avoid log(0) errors
    y_pred = K.maximum(K.cast(y_pred, tf.float32), K.epsilon()) # Corrected: K.maximum

    first_log = K.log(K.maximum(K.cast(y_pred, tf.float32), K.epsilon()) + 1.) # Corrected: K.maximum
    second_log = K.log(K.maximum(K.cast(y_true, tf.float32), K.epsilon()) + 1.) # Corrected: K.maximum

    return K.sqrt(K.mean(K.square(first_log - second_log)))

# def rmsle(y_true, y_pred):
#     """
#     Root Mean Squared Logarithm Error
#     Args:
#         y_true ([np.array]): test samples
#         y_pred ([np.array]): predicted samples
#     Returns:
#         [float]: root mean squared logarithm error
#     """
#     first_log = K.log(K.clip(y_pred, K.epsilon(), None) + 1.)
#     second_log = K.log(K.clip(y_true, K.epsilon(), None) + 1.)
#     return K.sqrt(K.mean(K.square(first_log - second_log), axis=-1))

# %%
class CFG:
    SEED    = 333
    CV      = KFold(n_splits=11, shuffle=True, random_state=SEED)
    VERSION = '1'

class TrainModels:
    def __init__(self, X, y, X_test, test_finc_target, X_original, y_original, model_, parameters):
        self.model     = model_
        self.parameters = parameters
        self.X          = X
        self.y          = y
        self.test_finc_target = test_finc_target
        self.X_test     = X_test
        self._OOF_train = pd.DataFrame()
        self._OOF_test  = pd.DataFrame()
        self.categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
        self.numerical_features = X.select_dtypes(exclude=['category', 'bool', 'category','int']).columns.to_list()

    def fit_model(self, name="Base_model"):
        oof_train = np.zeros(self.X.shape[0])
        oof_test  = np.zeros(self.X_test.shape[0])
        scores_train = []
        scores_val   = []

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/layers_3_staked_models')

        train_start = 0

        for fold, (train_idx, val_idx) in enumerate(CFG.CV.split(self.X, self.y)):
            x_train, y_train = self.X.iloc[train_idx], self.y.iloc[train_idx]
            x_val,   y_val   = self.X.iloc[val_idx],   self.y.iloc[val_idx]


            train_ds = dataframe_to_dataset(x_train, y_train, self.categorical_features, self.numerical_features, shuffle=True, batch_size=1024)
            val_ds = dataframe_to_dataset(x_val, y_val, self.categorical_features, self.numerical_features, shuffle=False, batch_size=1024)
            test_ds = dataframe_to_dataset_test(self.X_test, self.test_finc_target, self.categorical_features, self.numerical_features, batch_size=1024)

            model = self.model(**self.parameters)

            optimizer = keras.optimizers.Adam(learning_rate=5e-4)
            model.compile(optimizer=optimizer,
                          loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                          metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

            checkpoint_filepath = '/tmp/ckpt/checkpoint.weights.h5'
            model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
                                                                        filepath=checkpoint_filepath,
                                                                        save_weights_only=True,
                                                                        monitor='val_rmsle',
                                                                        mode='min',
                                                                        save_best_only=True
                                                                        )
            if fold >= train_start:
              # Fit the model
              history = model.fit(train_ds,
                                  validation_data=val_ds,
                                  epochs=151,
                                  batch_size=1024,
                                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                                            keras.callbacks.EarlyStopping(patience=21, restore_best_weights=True, monitor="val_rmsle",
                                                                            start_from_epoch=3, mode="min"),
                                              model_checkpoint_callback])

              model.load_weights(checkpoint_filepath)
              model.save(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/keras_models/{name}_{fold}.keras")
              plot_training_session(history)

            else:
              model = tf.keras.models.load_model(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/keras_models/{name}_{fold}.keras",
                                                custom_objects={'rmsle': rmsle})

            model.evaluate(val_ds, verbose=0)

            # Make predictions
            y_pred_train = model.predict(train_ds)
            y_pred_val   = model.predict(val_ds)
            y_pred_test  = model.predict(test_ds)

            # Correct Ranges:

            y_pred_train = np.maximum(y_pred_train, 1.0)
            y_pred_train = np.minimum(y_pred_train, 315.0)

            y_pred_val = np.maximum(y_pred_val, 1.0)
            y_pred_val = np.minimum(y_pred_val, 315.0)

            y_pred_test = np.maximum(y_pred_test, 1.0)
            y_pred_test = np.minimum(y_pred_test, 315.0)

            # Store Results
            oof_train[val_idx] = y_pred_val.reshape(-1)
            oof_test   += (y_pred_test/CFG.CV.get_n_splits()).reshape(-1)

            train_score = root_mean_squared_log_error(y_train, y_pred_train)
            val_score   = root_mean_squared_log_error(y_val, y_pred_val)

            print(f'Fold {fold+1} → Training set Score: {train_score:.5f} | Validation set Score: {val_score:.5f}')

            scores_train.append(train_score)
            scores_val.append(val_score)

            gc.collect()
            K.clear_session()

        self._OOF_train[name] = oof_train
        self._OOF_test[name]  = oof_test

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5')

        print(colored(f'Overall → Training set Score: {np.mean(scores_train):.5f}±{np.std(scores_train):.7f} | Validation set Score: {np.mean(scores_val):.5f}±{np.std(scores_val):.7f}',
              color='green', attrs=['bold', 'dark']))

    @property
    def OOF_train(self):
        return self._OOF_train
    @property
    def OOF_test(self):
        return self._OOF_test

    def save_predictions(self):
        self._OOF_train.to_csv('OOF_train_many_models.csv', index=False)
        self._OOF_test.to_csv('OOF_test_many_models.csv', index=False)

# %% [markdown]
# ### **2.1.0 NeuralNetwork: Dense**

# %%
data.X.sample(3)
# Out:
#         Sex    Height    Weight  Duration  Heart_Rate  Body_Temp       BMI  \
# 149477    0 -0.754084 -0.795635  0.547900   -0.262860   0.723151 -0.572934
# 208767    1  1.346402  1.132370 -1.726619   -1.214992  -2.867226  0.205718
# 270481    1  0.879627  1.132370  0.188765    0.160310   0.466696  1.275832
#
#         Intensity  Intensity_v1  Heart_Duration  Weight_Duration_Heart  \
# 149477   0.343505     -1.552887       -0.720387               0.045695
# 208767  -1.545850      2.671306        3.608055              -1.449722
# 270481   0.111154     -0.405675       -0.446838               0.462105
#
#         Outliers_Duration_Heart_Temp   BMI_Age       BMR  Age_Group
# 149477                             0  0.527693 -0.319023          4
# 208767                             0 -3.014489  0.926048          4
# 270481                             0  0.656051  0.315211          6

# %%
data.X.max(axis=0)
# Out:
# Sex                             1.000000
# Height                          3.680276
# Weight                          4.060081
# Duration                        1.745015
# Heart_Rate                      3.439877
# Body_Temp                       1.877201
# BMI                             5.000000
# Intensity                       2.483148
# Intensity_v1                    8.631268
# Heart_Duration                  4.005130
# Weight_Duration_Heart           4.344034
# Outliers_Duration_Heart_Temp    1.000000
# BMI_Age                         1.776116
# BMR                             4.142021
# Age_Group                       7.000000
# dtype: float64

# %%
data.X.min(axis=0)
# Out:
# Sex                             0.000000
# Height                         -4.021508
# Weight                         -2.795048
# Duration                       -1.726619
# Heart_Rate                     -3.013464
# Body_Temp                      -3.764820
# BMI                            -5.000000
# Intensity                      -1.563858
# Intensity_v1                   -5.230777
# Heart_Duration                 -1.390121
# Weight_Duration_Heart          -1.507367
# Outliers_Duration_Heart_Temp    0.000000
# BMI_Age                        -3.650672
# BMR                            -5.745514
# Age_Group                       1.000000
# dtype: float64

# %%
cat_features = data.cat_features
num_features = data.num_features

cat_features_card = [2,2,8]
cat_features_out = [2, 2, 4]

print(cat_features,cat_features_card)
print(num_features)
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group'] [2, 2, 8]
# ['Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'BMI', 'Intensity', 'Intensity_v1', 'Heart_Duration', 'Weight_Duration_Heart', 'BMI_Age', 'BMR']

# %%
np.ceil(np.sqrt(cat_features_card[1]))
# Out:
# np.float64(2.0)

# %%
def build_model(units=512,last_layer = 1, activation="relu", do_rate=0.25, reg=0.001):

    x_input_cats = layers.Input(shape=(len(cat_features),))
    embs = []
    for j in range(len(cat_features)):
        e = layers.Embedding(cat_features_card[j], cat_features_out[j]) #np.ceil(np.sqrt(cat_features_card[1]))
        x = e(x_input_cats[:,j])
        x = layers.Flatten()(x)
        embs.append(x)

    x_input_nums = layers.Input(shape=(len(num_features),))

    x = layers.Concatenate(axis=-1)(embs+[x_input_nums])
    x = layers.Dense(units, activation=activation, kernel_regularizer=keras.regularizers.l2(reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(do_rate)(x)
    x = layers.Dense(units, activation=activation, kernel_regularizer=keras.regularizers.l2(reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(do_rate)(x)
    x = layers.Dense(int(units/last_layer), activation=activation, kernel_regularizer=keras.regularizers.l2(reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(do_rate)(x)
    x_final = layers.Dense(1, activation='linear')(x)

    model = keras.Model(inputs=[x_input_cats,x_input_nums], outputs=x_final)
    return model

# %%
mod_test = build_model(units=512)
mod_test.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None)            │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None)            │          0 │ input_layer[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None)            │          0 │ input_layer[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 2)         │          4 │ get_item[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 2)         │          4 │ get_item_1[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 4)         │         32 │ get_item_2[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2)         │          0 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 2)         │          0 │ embedding_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 4)         │          0 │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20)        │          0 │ flatten[0][0],    │
# │ (Concatenate)       │                   │            │ flatten_1[0][0],  │
# │                     │                   │            │ flatten_2[0][0],  │
# │                     │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     10,752 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │        513 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 542,761 (2.07 MB)
#  Trainable params: 539,689 (2.06 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %% [markdown]
# #### 2.1.1 Optuna Optimization:

# %%
X_fin = data.X
X_test_fin = data.X_test

X_train_cat = data.X[cat_features]
X_train_num = data.X[num_features]

X_test_cat = data.X_test[cat_features]
X_test_num = data.X_test[num_features]

X_train_cat.info()
X_train_num.info()

y_fin = data.y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Outliers_Duration_Heart_Temp  765000 non-null  int64
#  2   Age_Group                     765000 non-null  int64
# dtypes: int64(3)
# memory usage: 23.3 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Height                 765000 non-null  float64
#  1   Weight                 765000 non-null  float64
#  2   Duration               765000 non-null  float64
#  3   Heart_Rate             765000 non-null  float64
#  4   Body_Temp              765000 non-null  float64
#  5   BMI                    765000 non-null  float64
#  6   Intensity              765000 non-null  float64
#  7   Intensity_v1           765000 non-null  float64
#  8   Heart_Duration         765000 non-null  float64
#  9   Weight_Duration_Heart  765000 non-null  float64
#  10  BMI_Age                765000 non-null  float64
#  11  BMR                    765000 non-null  float64
# dtypes: float64(12)
# memory usage: 75.9 MB

# %%
y_fin.isna().sum()
# Out:
# Calories    0
# dtype: int64

# %% [markdown]
# **OPTIMIZATION SECTION**

# %%
def objective_nn(trial, X, y, n_splits, n_repeats, model=build_model, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold"):

    model_class = model

    categorical_features = cat_features.copy()

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {'units': trial.suggest_categorical('units', [128,256,512,1024]),
              'last_layer': trial.suggest_int('last_layer', 1,2),
              'activation': trial.suggest_categorical('activation', ["relu","silu","mish"]), #, reg=0.001, dropout_rate=0.33) #"relu","selu","gelu","silu"
              'reg': trial.suggest_float('reg', 1e-4, 0.1, log=True),
              'do_rate': trial.suggest_float('do_rate', 0.30, 0.50, step=0.01)
              }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmsle_scores = []

    keras.backend.clear_session()

    iteration_n=0

    for idx_train, idx_valid in kf.split(X, y):
        print(f"Running Fold: {iteration_n}")
        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy()#.reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy()#.reshape(-1, 1)

        X_train_cat = X_train[cat_features]
        X_train_num = X_train[num_features]

        X_valid_cat = X_valid[cat_features]
        X_valid_num = X_valid[num_features]

        # Create the model
        keras.utils.set_random_seed(rs)
        model = model_class(**params)

        optimizer = keras.optimizers.Adam(learning_rate=5e-4)
        model.compile(optimizer=optimizer,
                      loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                      metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

        checkpoint_filepath = '/tmp/ckpt/checkpoint.weights.h5'
        model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_rmsle',
            mode='min',
            save_best_only=True)

        # Fit the model
        model.fit([X_train_cat,X_train_num], y_train,
                  validation_data=([X_valid_cat, X_valid_num], y_valid),
                  epochs=31,
                  batch_size=1024,
                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor="val_rmsle",
                                                            start_from_epoch=3, mode="min"),
                             model_checkpoint_callback])

        model.load_weights(checkpoint_filepath)

        # Make predictions on the validation set
        y_pred = model.predict([X_valid_cat, X_valid_num], batch_size=1024)
        y_pred = np.maximum(y_pred, 1.0)
        y_pred = np.minimum(y_pred, 315.0)

        print("Pred Min: {}".format(y_pred.min()))
        print("Pred Max: {}".format(y_pred.max()))

        # Calculate the RMSE for the current fold
        rmsle_score = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Fold {iteration_n} RMSLE: {rmsle_score}")

        rmsle_scores.append(rmsle_score)
        iteration_n+=1

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmsle_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))
    study.optimize(lambda trial: objective_nn(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=build_model, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
X_fin.isna().sum(), y_fin.min()
# Out:
# (Sex                             0
#  Height                          0
#  Weight                          0
#  Duration                        0
#  Heart_Rate                      0
#  Body_Temp                       0
#  BMI                             0
#  Intensity                       0
#  Intensity_v1                    0
#  Heart_Duration                  0
#  Weight_Duration_Heart           0
#  Outliers_Duration_Heart_Temp    0
#  BMI_Age                         0
#  BMR                             0
#  Age_Group                       0
#  dtype: int64,
#  Calories    1.0
#  dtype: float64)

# %% [markdown]
#   1. {'units': 256,
#  'last_layer': 1,
#  'activation': 'relu',
#  'reg': 0.00039536431216575824,
#  'do_rate': 0.32} Score: 0.0631159157056562

# %%
nn0_study = tune_hyperparameters(X_fin, y_fin, model_class=build_model, n_trials=31, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)

cat_params = nn0_study.best_params
# Out:
# [I 2025-05-18 15:09:30,059] A new study created in memory with name: no-name-43814457-715a-408d-8047-e6842c1cd31c
# Running Fold: 0
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_3_loss: 0.0000e+00 - loss: 3.4957 - msle: 100.7173 - rmsle: 2.1434 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.9351 - val_msle: 81.0378 - val_rmsle: 0.8397 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.9102 - msle: 104.5880 - rmsle: 0.8210 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.5526 - val_msle: 87.2660 - val_rmsle: 0.4952 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.5402 - msle: 94.7716 - rmsle: 0.4866 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.3278 - val_msle: 54.4062 - val_rmsle: 0.2830 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3406 - msle: 76.1510 - rmsle: 0.2979 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.3256 - val_msle: 62.8829 - val_rmsle: 0.2592 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3518 - msle: 50.5058 - rmsle: 0.2907 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2435 - val_msle: 14.7571 - val_rmsle: 0.1816 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3113 - msle: 33.5213 - rmsle: 0.2469 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2444 - val_msle: 11.8410 - val_rmsle: 0.1576 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3040 - msle: 16.6663 - rmsle: 0.2242 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1723 - val_msle: 5.8629 - val_rmsle: 0.1160 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2418 - msle: 12.8139 - rmsle: 0.1921 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1410 - val_msle: 8.5782 - val_rmsle: 0.1030 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2133 - msle: 12.9050 - rmsle: 0.1789 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1542 - val_msle: 4.9814 - val_rmsle: 0.1254 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1990 - msle: 12.9675 - rmsle: 0.1717 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1350 - val_msle: 6.7569 - val_rmsle: 0.1105 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1879 - msle: 13.0284 - rmsle: 0.1645 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1313 - val_msle: 9.6957 - val_rmsle: 0.1102 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1818 - msle: 13.1676 - rmsle: 0.1609 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1243 - val_msle: 6.6984 - val_rmsle: 0.1050 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1747 - msle: 13.2000 - rmsle: 0.1560 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1056 - val_msle: 5.4693 - val_rmsle: 0.0875 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1714 - msle: 13.3043 - rmsle: 0.1538 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0962 - val_msle: 4.4665 - val_rmsle: 0.0795 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1669 - msle: 13.2686 - rmsle: 0.1505 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1135 - val_msle: 5.1244 - val_rmsle: 0.0962 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1641 - msle: 13.2594 - rmsle: 0.1480 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1436 - val_msle: 5.9446 - val_rmsle: 0.1274 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1656 - msle: 13.3735 - rmsle: 0.1495 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1108 - val_msle: 5.3994 - val_rmsle: 0.0957 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1530 - msle: 13.2613 - rmsle: 0.1396 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1012 - val_msle: 4.4104 - val_rmsle: 0.0891 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1525 - msle: 13.1669 - rmsle: 0.1405 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0878 - val_msle: 4.6412 - val_rmsle: 0.0761 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1481 - msle: 13.0617 - rmsle: 0.1367 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1023 - val_msle: 4.3606 - val_rmsle: 0.0909 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1492 - msle: 13.0680 - rmsle: 0.1379 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0912 - val_msle: 4.1824 - val_rmsle: 0.0796 - learning_rate: 2.5000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1473 - msle: 13.0135 - rmsle: 0.1361 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0979 - val_msle: 4.3499 - val_rmsle: 0.0864 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1441 - msle: 12.9597 - rmsle: 0.1332 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0776 - val_msle: 4.1748 - val_rmsle: 0.0677 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1408 - msle: 12.9171 - rmsle: 0.1312 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0774 - val_msle: 4.3208 - val_rmsle: 0.0678 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1404 - msle: 12.9205 - rmsle: 0.1310 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0763 - val_msle: 4.6082 - val_rmsle: 0.0670 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1412 - msle: 12.8751 - rmsle: 0.1320 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0773 - val_msle: 3.8922 - val_rmsle: 0.0679 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1402 - msle: 12.8353 - rmsle: 0.1310 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0826 - val_msle: 4.6525 - val_rmsle: 0.0734 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1383 - msle: 12.8377 - rmsle: 0.1294 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0824 - val_msle: 5.0596 - val_rmsle: 0.0733 - learning_rate: 1.2500e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1375 - msle: 12.7474 - rmsle: 0.1288 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0733 - val_msle: 4.1332 - val_rmsle: 0.0649 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1364 - msle: 12.7312 - rmsle: 0.1282 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0726 - val_msle: 3.9302 - val_rmsle: 0.0644 - learning_rate: 6.2500e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1356 - msle: 12.6896 - rmsle: 0.1276 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0738 - val_msle: 3.8582 - val_rmsle: 0.0659 - learning_rate: 6.2500e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.6612921953201294
# Pred Max: 315.0
# Fold 0 RMSLE: 0.06524952742645537
# Running Fold: 1
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_7_loss: 0.0000e+00 - loss: 3.5128 - msle: 100.7730 - rmsle: 2.1492 - val_dense_7_loss: 0.0000e+00 - val_loss: 1.0320 - val_msle: 90.6379 - val_rmsle: 0.9351 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.9170 - msle: 104.3326 - rmsle: 0.8272 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.5467 - val_msle: 98.9638 - val_rmsle: 0.4781 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.5230 - msle: 93.1285 - rmsle: 0.4629 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.3814 - val_msle: 103.6118 - val_rmsle: 0.3329 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.3413 - msle: 77.7937 - rmsle: 0.2960 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.3148 - val_msle: 124.8170 - val_rmsle: 0.2643 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.3677 - msle: 50.5136 - rmsle: 0.2916 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.2713 - val_msle: 15.8482 - val_rmsle: 0.1829 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.3091 - msle: 31.8677 - rmsle: 0.2339 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.2192 - val_msle: 14.8113 - val_rmsle: 0.1578 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.2781 - msle: 17.0749 - rmsle: 0.2175 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.2069 - val_msle: 7.6436 - val_rmsle: 0.1472 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.2512 - msle: 12.9302 - rmsle: 0.1979 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.2043 - val_msle: 6.5720 - val_rmsle: 0.1630 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.2187 - msle: 12.9818 - rmsle: 0.1807 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1757 - val_msle: 10.3575 - val_rmsle: 0.1456 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.2010 - msle: 13.1066 - rmsle: 0.1713 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1765 - val_msle: 7.9297 - val_rmsle: 0.1508 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1929 - msle: 13.3203 - rmsle: 0.1666 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1213 - val_msle: 4.6938 - val_rmsle: 0.0979 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1818 - msle: 13.2616 - rmsle: 0.1596 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1630 - val_msle: 5.9843 - val_rmsle: 0.1427 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1757 - msle: 13.4060 - rmsle: 0.1554 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1279 - val_msle: 9.0744 - val_rmsle: 0.1095 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1689 - msle: 13.3559 - rmsle: 0.1504 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1074 - val_msle: 6.1386 - val_rmsle: 0.0899 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1636 - msle: 13.4321 - rmsle: 0.1466 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1053 - val_msle: 4.9098 - val_rmsle: 0.0880 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1660 - msle: 13.3829 - rmsle: 0.1487 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1369 - val_msle: 13.0007 - val_rmsle: 0.1214 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1603 - msle: 13.3986 - rmsle: 0.1444 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1229 - val_msle: 10.9834 - val_rmsle: 0.1077 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1602 - msle: 13.3942 - rmsle: 0.1444 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0944 - val_msle: 5.4530 - val_rmsle: 0.0780 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1593 - msle: 13.3506 - rmsle: 0.1432 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1169 - val_msle: 6.5373 - val_rmsle: 0.1002 - learning_rate: 5.0000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1608 - msle: 13.2936 - rmsle: 0.1442 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1248 - val_msle: 10.4240 - val_rmsle: 0.1096 - learning_rate: 5.0000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1584 - msle: 13.2920 - rmsle: 0.1421 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1081 - val_msle: 7.6867 - val_rmsle: 0.0924 - learning_rate: 5.0000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1491 - msle: 13.0663 - rmsle: 0.1351 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1130 - val_msle: 8.5484 - val_rmsle: 0.1012 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1480 - msle: 12.9400 - rmsle: 0.1359 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0810 - val_msle: 4.0229 - val_rmsle: 0.0689 - learning_rate: 2.5000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1444 - msle: 12.9199 - rmsle: 0.1329 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0991 - val_msle: 7.6166 - val_rmsle: 0.0881 - learning_rate: 2.5000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1473 - msle: 12.8714 - rmsle: 0.1358 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.1009 - val_msle: 7.9982 - val_rmsle: 0.0900 - learning_rate: 2.5000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1439 - msle: 12.7880 - rmsle: 0.1329 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0965 - val_msle: 5.6853 - val_rmsle: 0.0858 - learning_rate: 2.5000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1397 - msle: 12.7205 - rmsle: 0.1294 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0956 - val_msle: 4.5001 - val_rmsle: 0.0861 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1390 - msle: 12.6629 - rmsle: 0.1296 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0774 - val_msle: 4.0975 - val_rmsle: 0.0683 - learning_rate: 1.2500e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1380 - msle: 12.6156 - rmsle: 0.1290 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0918 - val_msle: 4.4895 - val_rmsle: 0.0827 - learning_rate: 1.2500e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1365 - msle: 12.5744 - rmsle: 0.1276 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0856 - val_msle: 3.9654 - val_rmsle: 0.0766 - learning_rate: 1.2500e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_7_loss: 0.0000e+00 - loss: 0.1374 - msle: 12.5428 - rmsle: 0.1285 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.0828 - val_msle: 4.4839 - val_rmsle: 0.0740 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.605715274810791
# Pred Max: 315.0
# Fold 1 RMSLE: 0.06898324383424201
# Running Fold: 2
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_11_loss: 0.0000e+00 - loss: 3.5106 - msle: 100.8268 - rmsle: 2.1460 - val_dense_11_loss: 0.0000e+00 - val_loss: 1.0727 - val_msle: 88.5512 - val_rmsle: 0.9743 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.9059 - msle: 104.3630 - rmsle: 0.8144 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.5200 - val_msle: 101.1171 - val_rmsle: 0.4562 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.4934 - msle: 92.0226 - rmsle: 0.4264 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.3191 - val_msle: 75.4502 - val_rmsle: 0.2708 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.3401 - msle: 76.2732 - rmsle: 0.2925 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.3126 - val_msle: 29.2452 - val_rmsle: 0.2328 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.3315 - msle: 61.9198 - rmsle: 0.2580 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.2805 - val_msle: 41.6082 - val_rmsle: 0.2166 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.3028 - msle: 35.4167 - rmsle: 0.2368 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.2335 - val_msle: 9.5847 - val_rmsle: 0.1616 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_11_loss: 0.0000e+00 - loss: 0.2827 - msle: 15.4923 - rmsle: 0.2168 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.2182 - val_msle: 5.1957 - val_rmsle: 0.1675 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.2395 - msle: 12.9537 - rmsle: 0.1921 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1995 - val_msle: 8.2921 - val_rmsle: 0.1564 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.2210 - msle: 12.9215 - rmsle: 0.1812 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1811 - val_msle: 20.5724 - val_rmsle: 0.1476 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.2030 - msle: 12.9270 - rmsle: 0.1720 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1421 - val_msle: 5.2418 - val_rmsle: 0.1175 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1930 - msle: 13.1057 - rmsle: 0.1677 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1240 - val_msle: 7.8664 - val_rmsle: 0.1011 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1819 - msle: 13.1032 - rmsle: 0.1601 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1025 - val_msle: 4.0294 - val_rmsle: 0.0819 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1771 - msle: 13.2249 - rmsle: 0.1568 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1595 - val_msle: 6.0668 - val_rmsle: 0.1413 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1725 - msle: 13.2906 - rmsle: 0.1538 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1606 - val_msle: 9.6532 - val_rmsle: 0.1438 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1675 - msle: 13.2527 - rmsle: 0.1507 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1266 - val_msle: 4.7096 - val_rmsle: 0.1105 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1569 - msle: 13.1756 - rmsle: 0.1425 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1303 - val_msle: 8.9187 - val_rmsle: 0.1179 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1565 - msle: 13.2109 - rmsle: 0.1438 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1283 - val_msle: 6.1768 - val_rmsle: 0.1163 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1528 - msle: 13.1298 - rmsle: 0.1408 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1106 - val_msle: 7.2815 - val_rmsle: 0.0992 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1456 - msle: 13.0728 - rmsle: 0.1346 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0970 - val_msle: 4.0421 - val_rmsle: 0.0869 - learning_rate: 1.2500e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1449 - msle: 13.0116 - rmsle: 0.1350 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0884 - val_msle: 4.5573 - val_rmsle: 0.0787 - learning_rate: 1.2500e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1431 - msle: 12.9349 - rmsle: 0.1336 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0930 - val_msle: 5.6197 - val_rmsle: 0.0836 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1434 - msle: 12.9563 - rmsle: 0.1341 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0912 - val_msle: 4.5154 - val_rmsle: 0.0820 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1424 - msle: 12.8976 - rmsle: 0.1333 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0878 - val_msle: 4.2409 - val_rmsle: 0.0788 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1407 - msle: 12.8443 - rmsle: 0.1318 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0828 - val_msle: 3.9744 - val_rmsle: 0.0739 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1414 - msle: 12.9164 - rmsle: 0.1325 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0802 - val_msle: 3.8725 - val_rmsle: 0.0712 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1398 - msle: 12.8426 - rmsle: 0.1310 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0817 - val_msle: 3.7825 - val_rmsle: 0.0729 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1408 - msle: 12.8536 - rmsle: 0.1320 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0792 - val_msle: 4.1953 - val_rmsle: 0.0705 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1390 - msle: 12.8018 - rmsle: 0.1304 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0927 - val_msle: 4.4614 - val_rmsle: 0.0841 - learning_rate: 1.2500e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1401 - msle: 12.8011 - rmsle: 0.1314 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0799 - val_msle: 3.7252 - val_rmsle: 0.0713 - learning_rate: 1.2500e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1379 - msle: 12.7467 - rmsle: 0.1294 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0796 - val_msle: 3.8387 - val_rmsle: 0.0712 - learning_rate: 1.2500e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1370 - msle: 12.7385 - rmsle: 0.1288 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0797 - val_msle: 4.0776 - val_rmsle: 0.0717 - learning_rate: 6.2500e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 2.0229499340057373
# Pred Max: 312.379638671875
# Fold 2 RMSLE: 0.07105634292099898
# Running Fold: 3
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - dense_15_loss: 0.0000e+00 - loss: 3.5152 - msle: 100.8017 - rmsle: 2.1510 - val_dense_15_loss: 0.0000e+00 - val_loss: 1.0367 - val_msle: 88.9842 - val_rmsle: 0.9478 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.9160 - msle: 104.8586 - rmsle: 0.8320 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.5485 - val_msle: 109.0686 - val_rmsle: 0.4792 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.5046 - msle: 93.4587 - rmsle: 0.4396 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.2966 - val_msle: 61.2016 - val_rmsle: 0.2547 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.3389 - msle: 75.4461 - rmsle: 0.2979 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.2882 - val_msle: 56.3204 - val_rmsle: 0.2474 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.3224 - msle: 53.1933 - rmsle: 0.2830 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.3049 - val_msle: 31.5273 - val_rmsle: 0.2712 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.3066 - msle: 32.1439 - rmsle: 0.2681 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1825 - val_msle: 7.9757 - val_rmsle: 0.1274 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2625 - msle: 13.2917 - rmsle: 0.2136 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.2053 - val_msle: 11.7818 - val_rmsle: 0.1699 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2255 - msle: 13.0559 - rmsle: 0.1910 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1546 - val_msle: 6.7828 - val_rmsle: 0.1266 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2063 - msle: 13.1178 - rmsle: 0.1786 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1746 - val_msle: 15.2156 - val_rmsle: 0.1501 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1974 - msle: 13.2384 - rmsle: 0.1725 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1568 - val_msle: 11.0997 - val_rmsle: 0.1346 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1823 - msle: 13.3410 - rmsle: 0.1608 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1224 - val_msle: 5.9954 - val_rmsle: 0.1024 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1774 - msle: 13.4910 - rmsle: 0.1576 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1054 - val_msle: 4.7454 - val_rmsle: 0.0859 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1735 - msle: 13.5492 - rmsle: 0.1544 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1290 - val_msle: 7.5205 - val_rmsle: 0.1106 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1670 - msle: 13.5878 - rmsle: 0.1493 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1317 - val_msle: 10.5376 - val_rmsle: 0.1144 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1676 - msle: 13.6658 - rmsle: 0.1500 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1119 - val_msle: 8.0470 - val_rmsle: 0.0947 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1582 - msle: 13.5999 - rmsle: 0.1427 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1031 - val_msle: 5.7597 - val_rmsle: 0.0899 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1528 - msle: 13.4744 - rmsle: 0.1398 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0973 - val_msle: 5.2200 - val_rmsle: 0.0841 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1528 - msle: 13.4697 - rmsle: 0.1399 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1102 - val_msle: 8.6356 - val_rmsle: 0.0982 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1507 - msle: 13.4102 - rmsle: 0.1386 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0986 - val_msle: 6.8980 - val_rmsle: 0.0866 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1490 - msle: 13.3529 - rmsle: 0.1371 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0967 - val_msle: 6.0043 - val_rmsle: 0.0851 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1499 - msle: 13.3419 - rmsle: 0.1382 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1062 - val_msle: 6.9181 - val_rmsle: 0.0943 - learning_rate: 2.5000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1486 - msle: 13.3125 - rmsle: 0.1370 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0936 - val_msle: 6.1849 - val_rmsle: 0.0821 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1487 - msle: 13.2851 - rmsle: 0.1373 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0944 - val_msle: 5.5791 - val_rmsle: 0.0829 - learning_rate: 2.5000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1479 - msle: 13.2880 - rmsle: 0.1366 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0906 - val_msle: 4.7281 - val_rmsle: 0.0795 - learning_rate: 2.5000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1461 - msle: 13.1670 - rmsle: 0.1351 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0849 - val_msle: 4.9229 - val_rmsle: 0.0736 - learning_rate: 2.5000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1481 - msle: 13.2163 - rmsle: 0.1367 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1085 - val_msle: 8.8624 - val_rmsle: 0.0975 - learning_rate: 2.5000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1473 - msle: 13.1358 - rmsle: 0.1361 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1008 - val_msle: 6.2386 - val_rmsle: 0.0900 - learning_rate: 2.5000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1472 - msle: 13.1455 - rmsle: 0.1362 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0940 - val_msle: 6.5418 - val_rmsle: 0.0834 - learning_rate: 2.5000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1418 - msle: 13.0096 - rmsle: 0.1316 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0760 - val_msle: 4.1030 - val_rmsle: 0.0663 - learning_rate: 1.2500e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1393 - msle: 12.9361 - rmsle: 0.1300 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0840 - val_msle: 4.7799 - val_rmsle: 0.0749 - learning_rate: 1.2500e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1393 - msle: 12.8390 - rmsle: 0.1304 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0864 - val_msle: 4.4642 - val_rmsle: 0.0771 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.7412999868392944
# Pred Max: 315.0
# Fold 3 RMSLE: 0.0670466110183454
# Running Fold: 4
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - dense_19_loss: 0.0000e+00 - loss: 3.5113 - msle: 100.9384 - rmsle: 2.1476 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.9639 - val_msle: 78.7616 - val_rmsle: 0.8662 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.9176 - msle: 104.6662 - rmsle: 0.8260 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.5408 - val_msle: 116.8868 - val_rmsle: 0.4797 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.5532 - msle: 96.7167 - rmsle: 0.5001 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.7425 - val_msle: 53.3205 - val_rmsle: 0.6917 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.3465 - msle: 83.0283 - rmsle: 0.3004 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.2655 - val_msle: 46.4568 - val_rmsle: 0.2236 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.3327 - msle: 64.6850 - rmsle: 0.2920 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.2611 - val_msle: 41.8638 - val_rmsle: 0.2241 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.3166 - msle: 38.3671 - rmsle: 0.2735 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.3158 - val_msle: 13.6662 - val_rmsle: 0.2528 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2854 - msle: 21.7417 - rmsle: 0.2254 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1843 - val_msle: 5.3136 - val_rmsle: 0.1340 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2512 - msle: 13.1747 - rmsle: 0.2032 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1616 - val_msle: 4.4478 - val_rmsle: 0.1218 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2179 - msle: 12.7807 - rmsle: 0.1821 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1759 - val_msle: 5.7676 - val_rmsle: 0.1473 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2017 - msle: 12.9529 - rmsle: 0.1742 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1494 - val_msle: 9.5530 - val_rmsle: 0.1234 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1903 - msle: 13.0062 - rmsle: 0.1667 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1782 - val_msle: 6.3078 - val_rmsle: 0.1577 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1769 - msle: 13.0887 - rmsle: 0.1574 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1980 - val_msle: 23.0603 - val_rmsle: 0.1764 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1775 - msle: 13.2421 - rmsle: 0.1572 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1387 - val_msle: 8.3649 - val_rmsle: 0.1200 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1699 - msle: 13.2650 - rmsle: 0.1520 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1603 - val_msle: 21.9654 - val_rmsle: 0.1420 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1672 - msle: 13.2352 - rmsle: 0.1500 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1292 - val_msle: 15.7000 - val_rmsle: 0.1116 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1656 - msle: 13.2449 - rmsle: 0.1489 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1319 - val_msle: 8.8908 - val_rmsle: 0.1146 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1620 - msle: 13.2817 - rmsle: 0.1457 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1112 - val_msle: 6.8154 - val_rmsle: 0.0943 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1596 - msle: 13.2665 - rmsle: 0.1435 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1682 - val_msle: 24.9500 - val_rmsle: 0.1510 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1601 - msle: 13.2885 - rmsle: 0.1442 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1516 - val_msle: 19.6550 - val_rmsle: 0.1345 - learning_rate: 5.0000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1584 - msle: 13.2183 - rmsle: 0.1427 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1146 - val_msle: 9.6242 - val_rmsle: 0.0980 - learning_rate: 5.0000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1492 - msle: 13.0839 - rmsle: 0.1351 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0919 - val_msle: 4.7483 - val_rmsle: 0.0798 - learning_rate: 2.5000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1474 - msle: 12.9738 - rmsle: 0.1355 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0902 - val_msle: 4.3898 - val_rmsle: 0.0788 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1463 - msle: 12.8668 - rmsle: 0.1350 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0840 - val_msle: 4.3293 - val_rmsle: 0.0726 - learning_rate: 2.5000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1435 - msle: 12.8221 - rmsle: 0.1326 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1000 - val_msle: 4.1239 - val_rmsle: 0.0892 - learning_rate: 2.5000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1446 - msle: 12.7409 - rmsle: 0.1338 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0967 - val_msle: 3.9354 - val_rmsle: 0.0857 - learning_rate: 2.5000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1446 - msle: 12.7408 - rmsle: 0.1337 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0834 - val_msle: 3.9236 - val_rmsle: 0.0729 - learning_rate: 2.5000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1430 - msle: 12.6806 - rmsle: 0.1324 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0899 - val_msle: 4.7061 - val_rmsle: 0.0792 - learning_rate: 2.5000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1422 - msle: 12.6150 - rmsle: 0.1317 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0919 - val_msle: 4.5460 - val_rmsle: 0.0813 - learning_rate: 2.5000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1422 - msle: 12.6215 - rmsle: 0.1317 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0914 - val_msle: 5.0242 - val_rmsle: 0.0811 - learning_rate: 2.5000e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1369 - msle: 12.4596 - rmsle: 0.1272 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0876 - val_msle: 4.1787 - val_rmsle: 0.0786 - learning_rate: 1.2500e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.1357 - msle: 12.3948 - rmsle: 0.1269 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.0802 - val_msle: 4.2614 - val_rmsle: 0.0714 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.777819275856018
# Pred Max: 315.0
# Fold 4 RMSLE: 0.07207497235723999
# [I 2025-05-18 15:16:15,611] Trial 0 finished with value: 0.06888213951145636 and parameters: {'units': 512, 'last_layer': 2, 'activation': 'relu', 'reg': 0.0036709772285039156, 'do_rate': 0.44999999999999996}. Best is trial 0 with value: 0.06888213951145636.
# Running Fold: 0
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_3_loss: 0.0000e+00 - loss: 8.2193 - msle: 102.5975 - rmsle: 2.6455 - val_dense_3_loss: 0.0000e+00 - val_loss: 1.1649 - val_msle: 81.2067 - val_rmsle: 1.0816 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 1.3375 - msle: 95.4902 - rmsle: 1.2628 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.8073 - val_msle: 65.7623 - val_rmsle: 0.7209 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.8247 - msle: 76.2244 - rmsle: 0.7260 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.4922 - val_msle: 67.0992 - val_rmsle: 0.3786 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.5216 - msle: 67.7976 - rmsle: 0.4095 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.4188 - val_msle: 16.9835 - val_rmsle: 0.3083 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.4638 - msle: 60.8898 - rmsle: 0.3514 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.3263 - val_msle: 13.3370 - val_rmsle: 0.2246 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.4353 - msle: 53.1477 - rmsle: 0.3360 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.3731 - val_msle: 29.3330 - val_rmsle: 0.2852 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.4005 - msle: 43.7185 - rmsle: 0.3109 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.3145 - val_msle: 10.8040 - val_rmsle: 0.2304 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3802 - msle: 33.5550 - rmsle: 0.2979 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2860 - val_msle: 11.1076 - val_rmsle: 0.2162 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3443 - msle: 21.3946 - rmsle: 0.2711 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1744 - val_msle: 9.9575 - val_rmsle: 0.1098 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.3009 - msle: 17.1696 - rmsle: 0.2441 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2077 - val_msle: 8.5523 - val_rmsle: 0.1583 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2743 - msle: 16.6545 - rmsle: 0.2278 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2164 - val_msle: 6.9593 - val_rmsle: 0.1722 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2673 - msle: 16.5814 - rmsle: 0.2232 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.2518 - val_msle: 8.4921 - val_rmsle: 0.2094 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2496 - msle: 16.4585 - rmsle: 0.2119 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1912 - val_msle: 6.9093 - val_rmsle: 0.1574 - learning_rate: 2.5000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2389 - msle: 16.2799 - rmsle: 0.2055 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1560 - val_msle: 6.7832 - val_rmsle: 0.1232 - learning_rate: 2.5000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2367 - msle: 16.1761 - rmsle: 0.2038 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1524 - val_msle: 7.4113 - val_rmsle: 0.1211 - learning_rate: 2.5000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2342 - msle: 16.1247 - rmsle: 0.2025 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1448 - val_msle: 6.5935 - val_rmsle: 0.1141 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2326 - msle: 16.2184 - rmsle: 0.2017 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1345 - val_msle: 8.0727 - val_rmsle: 0.1046 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2263 - msle: 16.0981 - rmsle: 0.1963 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1656 - val_msle: 6.7006 - val_rmsle: 0.1365 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2282 - msle: 16.0471 - rmsle: 0.1988 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1245 - val_msle: 7.8172 - val_rmsle: 0.0959 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2207 - msle: 15.9958 - rmsle: 0.1921 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1195 - val_msle: 6.5497 - val_rmsle: 0.0903 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2214 - msle: 16.0463 - rmsle: 0.1926 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1577 - val_msle: 7.6504 - val_rmsle: 0.1300 - learning_rate: 2.5000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2316 - msle: 16.0634 - rmsle: 0.2032 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1355 - val_msle: 6.4946 - val_rmsle: 0.1075 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2176 - msle: 16.0043 - rmsle: 0.1901 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1451 - val_msle: 6.6994 - val_rmsle: 0.1186 - learning_rate: 2.5000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2060 - msle: 15.9363 - rmsle: 0.1816 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1278 - val_msle: 6.9686 - val_rmsle: 0.1051 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2017 - msle: 15.8977 - rmsle: 0.1793 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1269 - val_msle: 6.4284 - val_rmsle: 0.1051 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2017 - msle: 15.8634 - rmsle: 0.1797 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1186 - val_msle: 6.3491 - val_rmsle: 0.0961 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2032 - msle: 15.8342 - rmsle: 0.1810 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1301 - val_msle: 8.1912 - val_rmsle: 0.1086 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2007 - msle: 15.8008 - rmsle: 0.1791 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1239 - val_msle: 6.6816 - val_rmsle: 0.1021 - learning_rate: 1.2500e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1989 - msle: 15.8074 - rmsle: 0.1775 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1088 - val_msle: 6.3241 - val_rmsle: 0.0867 - learning_rate: 1.2500e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1990 - msle: 15.8333 - rmsle: 0.1776 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1168 - val_msle: 6.5302 - val_rmsle: 0.0956 - learning_rate: 1.2500e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2010 - msle: 15.7823 - rmsle: 0.1799 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1112 - val_msle: 6.4830 - val_rmsle: 0.0903 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 2.5606579780578613
# Pred Max: 297.8239440917969
# Fold 0 RMSLE: 0.0870707808553443
# Running Fold: 1
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_7_loss: 0.0000e+00 - loss: 8.2203 - msle: 102.5705 - rmsle: 2.6440 - val_dense_7_loss: 0.0000e+00 - val_loss: 1.2547 - val_msle: 83.1675 - val_rmsle: 1.1806 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 1.3323 - msle: 95.4761 - rmsle: 1.2591 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.8040 - val_msle: 60.1796 - val_rmsle: 0.7076 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.8165 - msle: 76.0788 - rmsle: 0.7180 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.4733 - val_msle: 57.8775 - val_rmsle: 0.3575 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_7_loss: 0.0000e+00 - loss: 0.5272 - msle: 67.2448 - rmsle: 0.4134 - val_dense_7_loss: 0.0000e+00 - val_loss: 0.4878 - val_msle: 40.5725 - val_rmsle: 0.3102 - learning_rate: 5.0000e-04
# Epoch 5/31
# ...
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1974 - msle: 15.1478 - rmsle: 0.1861 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1095 - val_msle: 5.5871 - val_rmsle: 0.0986 - learning_rate: 1.2500e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1935 - msle: 14.9388 - rmsle: 0.1829 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1132 - val_msle: 5.5019 - val_rmsle: 0.1030 - learning_rate: 6.2500e-05
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1917 - msle: 14.9199 - rmsle: 0.1816 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0895 - val_msle: 5.0792 - val_rmsle: 0.0796 - learning_rate: 6.2500e-05
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1906 - msle: 14.8606 - rmsle: 0.1808 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0969 - val_msle: 5.3125 - val_rmsle: 0.0873 - learning_rate: 6.2500e-05
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1892 - msle: 14.8082 - rmsle: 0.1797 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.1017 - val_msle: 5.9716 - val_rmsle: 0.0924 - learning_rate: 6.2500e-05
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1903 - msle: 14.8947 - rmsle: 0.1811 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0975 - val_msle: 4.9264 - val_rmsle: 0.0884 - learning_rate: 6.2500e-05
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1866 - msle: 14.8389 - rmsle: 0.1776 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0884 - val_msle: 4.9940 - val_rmsle: 0.0795 - learning_rate: 3.1250e-05
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1866 - msle: 14.8123 - rmsle: 0.1779 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0908 - val_msle: 4.9888 - val_rmsle: 0.0821 - learning_rate: 3.1250e-05
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1839 - msle: 14.7890 - rmsle: 0.1752 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0847 - val_msle: 4.9619 - val_rmsle: 0.0762 - learning_rate: 3.1250e-05
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1838 - msle: 14.7444 - rmsle: 0.1754 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0949 - val_msle: 5.3466 - val_rmsle: 0.0866 - learning_rate: 3.1250e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1829 - msle: 14.6849 - rmsle: 0.1747 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0866 - val_msle: 4.9740 - val_rmsle: 0.0784 - learning_rate: 3.1250e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1827 - msle: 14.6905 - rmsle: 0.1746 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0926 - val_msle: 5.4276 - val_rmsle: 0.0846 - learning_rate: 3.1250e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_11_loss: 0.0000e+00 - loss: 0.1811 - msle: 14.6909 - rmsle: 0.1731 - val_dense_11_loss: 0.0000e+00 - val_loss: 0.0882 - val_msle: 5.0893 - val_rmsle: 0.0803 - learning_rate: 1.5625e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 285.9641418457031
# Fold 2 RMSLE: 0.07646847923326894
# Running Fold: 3
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - dense_15_loss: 0.0000e+00 - loss: 13.1548 - msle: 102.2378 - rmsle: 2.3542 - val_dense_15_loss: 0.0000e+00 - val_loss: 1.0174 - val_msle: 79.1427 - val_rmsle: 0.9590 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.8979 - msle: 110.7131 - rmsle: 0.8395 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.5195 - val_msle: 105.5936 - val_rmsle: 0.4697 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.5389 - msle: 108.9925 - rmsle: 0.4903 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.3537 - val_msle: 66.7489 - val_rmsle: 0.3133 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.4008 - msle: 83.9049 - rmsle: 0.3586 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.3885 - val_msle: 16.9424 - val_rmsle: 0.3536 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.3185 - msle: 18.8592 - rmsle: 0.2867 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.2427 - val_msle: 8.4759 - val_rmsle: 0.2110 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2899 - msle: 17.3267 - rmsle: 0.2611 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1803 - val_msle: 7.1496 - val_rmsle: 0.1543 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2752 - msle: 16.9366 - rmsle: 0.2502 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1839 - val_msle: 6.3915 - val_rmsle: 0.1592 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2711 - msle: 16.6310 - rmsle: 0.2467 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1632 - val_msle: 7.9593 - val_rmsle: 0.1415 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2723 - msle: 16.4832 - rmsle: 0.2495 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1694 - val_msle: 5.5282 - val_rmsle: 0.1470 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2594 - msle: 16.2640 - rmsle: 0.2375 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1526 - val_msle: 6.8014 - val_rmsle: 0.1302 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2554 - msle: 16.2051 - rmsle: 0.2334 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1707 - val_msle: 9.1479 - val_rmsle: 0.1491 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2534 - msle: 16.1063 - rmsle: 0.2318 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1250 - val_msle: 7.6041 - val_rmsle: 0.1048 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2437 - msle: 16.0316 - rmsle: 0.2236 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1509 - val_msle: 9.2879 - val_rmsle: 0.1308 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2459 - msle: 15.8507 - rmsle: 0.2251 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1839 - val_msle: 15.0648 - val_rmsle: 0.1648 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2442 - msle: 15.8239 - rmsle: 0.2236 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1406 - val_msle: 10.0302 - val_rmsle: 0.1210 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2223 - msle: 15.5992 - rmsle: 0.2047 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1598 - val_msle: 12.3165 - val_rmsle: 0.1440 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2211 - msle: 15.6024 - rmsle: 0.2054 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1368 - val_msle: 5.4558 - val_rmsle: 0.1205 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2184 - msle: 15.5369 - rmsle: 0.2028 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1480 - val_msle: 9.8816 - val_rmsle: 0.1330 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2091 - msle: 15.4797 - rmsle: 0.1946 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1278 - val_msle: 8.6571 - val_rmsle: 0.1144 - learning_rate: 1.2500e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2057 - msle: 15.3539 - rmsle: 0.1924 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1069 - val_msle: 6.9533 - val_rmsle: 0.0941 - learning_rate: 1.2500e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2040 - msle: 15.3611 - rmsle: 0.1914 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1205 - val_msle: 6.4102 - val_rmsle: 0.1082 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2031 - msle: 15.3503 - rmsle: 0.1907 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1061 - val_msle: 5.2008 - val_rmsle: 0.0939 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2043 - msle: 15.2526 - rmsle: 0.1921 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.0992 - val_msle: 5.0458 - val_rmsle: 0.0870 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2027 - msle: 15.3218 - rmsle: 0.1906 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1293 - val_msle: 6.2811 - val_rmsle: 0.1175 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2013 - msle: 15.2397 - rmsle: 0.1895 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1139 - val_msle: 6.3401 - val_rmsle: 0.1020 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.2006 - msle: 15.2814 - rmsle: 0.1889 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1162 - val_msle: 5.4172 - val_rmsle: 0.1045 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1963 - msle: 15.2576 - rmsle: 0.1849 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1207 - val_msle: 7.6597 - val_rmsle: 0.1097 - learning_rate: 6.2500e-05
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1926 - msle: 15.1872 - rmsle: 0.1816 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1249 - val_msle: 7.7126 - val_rmsle: 0.1142 - learning_rate: 6.2500e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1921 - msle: 15.1724 - rmsle: 0.1813 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1296 - val_msle: 7.6637 - val_rmsle: 0.1190 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1892 - msle: 15.1044 - rmsle: 0.1787 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1144 - val_msle: 6.8922 - val_rmsle: 0.1040 - learning_rate: 3.1250e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_15_loss: 0.0000e+00 - loss: 0.1888 - msle: 15.0628 - rmsle: 0.1785 - val_dense_15_loss: 0.0000e+00 - val_loss: 0.1096 - val_msle: 6.5740 - val_rmsle: 0.0995 - learning_rate: 3.1250e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 287.1817626953125
# Fold 3 RMSLE: 0.08742392383558173
# Running Fold: 4
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - dense_19_loss: 0.0000e+00 - loss: 13.1606 - msle: 102.3119 - rmsle: 2.3611 - val_dense_19_loss: 0.0000e+00 - val_loss: 1.0060 - val_msle: 81.2239 - val_rmsle: 0.9443 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.8874 - msle: 110.3649 - rmsle: 0.8305 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.5806 - val_msle: 101.2625 - val_rmsle: 0.5160 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.5652 - msle: 114.5580 - rmsle: 0.5108 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.3639 - val_msle: 89.5632 - val_rmsle: 0.3173 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.3955 - msle: 88.4042 - rmsle: 0.3530 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.3175 - val_msle: 8.3466 - val_rmsle: 0.2792 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.3091 - msle: 18.7971 - rmsle: 0.2753 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.2116 - val_msle: 8.7352 - val_rmsle: 0.1797 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2794 - msle: 17.0288 - rmsle: 0.2499 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1662 - val_msle: 8.6815 - val_rmsle: 0.1393 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2776 - msle: 16.5988 - rmsle: 0.2500 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1479 - val_msle: 5.9733 - val_rmsle: 0.1220 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2542 - msle: 16.3203 - rmsle: 0.2299 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1286 - val_msle: 8.8826 - val_rmsle: 0.1033 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2503 - msle: 16.1082 - rmsle: 0.2267 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1846 - val_msle: 6.2379 - val_rmsle: 0.1622 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2509 - msle: 16.1349 - rmsle: 0.2283 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.2019 - val_msle: 6.3274 - val_rmsle: 0.1794 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2386 - msle: 15.9669 - rmsle: 0.2171 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1656 - val_msle: 10.0212 - val_rmsle: 0.1429 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2260 - msle: 15.6475 - rmsle: 0.2060 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1782 - val_msle: 6.0544 - val_rmsle: 0.1608 - learning_rate: 2.5000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2220 - msle: 15.6764 - rmsle: 0.2050 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1338 - val_msle: 5.6153 - val_rmsle: 0.1183 - learning_rate: 2.5000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2159 - msle: 15.6193 - rmsle: 0.2007 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1224 - val_msle: 5.2256 - val_rmsle: 0.1069 - learning_rate: 2.5000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2148 - msle: 15.6337 - rmsle: 0.1995 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1317 - val_msle: 8.7137 - val_rmsle: 0.1158 - learning_rate: 2.5000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2189 - msle: 15.6371 - rmsle: 0.2030 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1319 - val_msle: 5.5652 - val_rmsle: 0.1164 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2135 - msle: 15.5379 - rmsle: 0.1980 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1550 - val_msle: 5.7383 - val_rmsle: 0.1397 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_19_loss: 0.0000e+00 - loss: 0.2021 - msle: 15.3654 - rmsle: 0.1876 - val_dense_19_loss: 0.0000e+00 - val_loss: 0.1307 - val_msle: 5.5943 - val_rmsle: 0.1174 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 315.0
# Fold 4 RMSLE: 0.09732265870353252
# [I 2025-05-18 18:49:51,496] Trial 30 finished with value: 0.08382209580466686 and parameters: {'units': 256, 'last_layer': 1, 'activation': 'relu', 'reg': 0.06202135411722056, 'do_rate': 0.32}. Best is trial 25 with value: 0.0631159157056562.

# %%
cat_params
# Out:
# {'units': 256,
#  'last_layer': 1,
#  'activation': 'relu',
#  'reg': 0.00039536431216575824,
#  'do_rate': 0.32}

# %% [markdown]
# #### 2.1.2 Train Model:

# %%
param = {'units': 512, 'last_layer': 1, 'activation': 'relu', 'reg': 0.00012466698516071345, 'do_rate': 0.32329936440008156}
TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, test_finc_target=y_test_fic, X_original=None, y_original=None, model_=build_model, parameters=param)

# %%
TM.fit_model(name="NN_exp_01_v1")

# %% [markdown]
# #### 2.1.3 Store Results:

# %%
train_pred = TM.OOF_train
test_pred = TM.OOF_test
train_pred = pd.DataFrame(data = train_pred, columns = ["NN_exp_01_v1"])


sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

sub["Calories"] =  test_pred.values

sub.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_NN_exp_01_v1.csv")
train_pred.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_NN_exp_01_v1.csv")

# %%
test_pred.min(), test_pred.max()

# %%
train_pred

# %% [markdown]
# ### **2.2.0 NeuralNetwork: Wide and Deep Model v0**

# %%
data.X.sample(3)
# Out:
#         Sex    Height    Weight  Duration  Heart_Rate  Body_Temp       BMI  \
# 197762    1  0.646240  1.132370 -1.487196   -1.532369  -1.713176  1.850788
# 748786    0 -1.454247 -1.509711 -1.008350   -0.157067  -0.687354 -1.444780
# 7613      0  0.179465 -0.010151  0.308477    0.054518   0.723151 -0.287484
#
#         Intensity  Intensity_v1  Heart_Duration  Weight_Duration_Heart  \
# 197762  -1.383167      0.774916        1.835089              -1.255486
# 748786  -0.949960      1.653177        0.776536              -1.075344
# 7613     0.203536     -0.747083       -0.538098               0.187456
#
#         Outliers_Duration_Heart_Temp   BMI_Age       BMR  Age_Group
# 197762                             0 -1.639148  0.399788          5
# 748786                             0 -0.791880 -1.201231          3
# 7613                               0  0.297999  1.446099          2

# %%
data.X.max(axis=0)
# Out:
# Sex                             1.000000
# Height                          3.680276
# Weight                          4.060081
# Duration                        1.745015
# Heart_Rate                      3.439877
# Body_Temp                       1.877201
# BMI                             5.000000
# Intensity                       2.483148
# Intensity_v1                    8.631268
# Heart_Duration                  4.005130
# Weight_Duration_Heart           4.344034
# Outliers_Duration_Heart_Temp    1.000000
# BMI_Age                         1.776116
# BMR                             4.142021
# Age_Group                       7.000000
# dtype: float64

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(data.X.BMI, bins=31)
ax[1].hist(data.X_test.BMI, bins=31, color="salmon")

plt.show()

# %%
cat_features = data.cat_features
num_features = data.num_features

cat_features_card = [2,2,8]
cat_features_out = [2, 2, 4]


print(cat_features,cat_features_card)
print(num_features)
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group'] [2, 2, 8]
# ['Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'BMI', 'Intensity', 'Intensity_v1', 'Heart_Duration', 'Weight_Duration_Heart', 'BMI_Age', 'BMR']

# %%
def wide_deep(units=512, activation="relu", do_rate=0.25, reg=0.001, hidden_layers=3):
    '''
    In this model embedding is performed for the data feeding into both the Deep and and wide layers:
    '''

    x_input_cats = layers.Input(shape=(len(cat_features),))
    embs = []
    for j in range(len(cat_features)):
        e = layers.Embedding(cat_features_card[j], cat_features_out[j]) #np.ceil(np.sqrt(cat_features_card[1]))
        x = e(x_input_cats[:,j])
        x = layers.Flatten()(x)
        embs.append(x)

    x_input_nums = layers.Input(shape=(len(num_features),))

    x = layers.Concatenate(axis=-1)(embs+[x_input_nums])

    wide = layers.BatchNormalization()(x)
    deep = x

    for lay in range(hidden_layers):
        deep = layers.Dense(units,kernel_regularizer=keras.regularizers.l2(reg), name=f"dense_deep_{lay}")(deep)
        deep = layers.BatchNormalization(name=f"bn_deep_{lay}")(deep)
        if activation == "relu":
            deep = layers.ReLU(name=f"relu_deep_{lay}")(deep)
        elif activation == "prelu":
            deep = layers.PReLU(name=f"prelu_deep_{lay}")(deep)
        elif activation == "gelu ":
            deep = activations.gelu(deep)
        elif activation == "silu":
            deep = activations.silu(deep)
        elif activation == "mish":
            deep = layers.Lambda(lambda x: keras.activations.mish(x), name=f"mish_deep_{lay}")(deep)
        elif activation == "celu":
            deep = activations.celu(deep)

        deep = layers.Dropout(do_rate, name=f"do_deep_{lay}")(deep)

    merged = layers.concatenate([wide, deep])

    x_final = layers.Dense(1, activation='linear')(merged)

    model = keras.Model(inputs=[x_input_cats,x_input_nums], outputs=x_final)
    return model

# %%
mod_test = wide_deep(units=512, activation="celu")
mod_test.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_15         │ (None)            │          0 │ input_layer_10[0… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_16         │ (None)            │          0 │ input_layer_10[0… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_17         │ (None)            │          0 │ input_layer_10[0… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_15        │ (None, 2)         │          4 │ get_item_15[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_16        │ (None, 2)         │          4 │ get_item_16[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_17        │ (None, 4)         │         32 │ get_item_17[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_15          │ (None, 2)         │          0 │ embedding_15[0][… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_16          │ (None, 2)         │          0 │ embedding_16[0][… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_17          │ (None, 4)         │          0 │ embedding_17[0][… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_11      │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 20)        │          0 │ flatten_15[0][0], │
# │ (Concatenate)       │                   │            │ flatten_16[0][0], │
# │                     │                   │            │ flatten_17[0][0], │
# │                     │                   │            │ input_layer_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_deep_0        │ (None, 512)       │     10,752 │ concatenate_5[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_deep_0           │ (None, 512)       │      2,048 │ dense_deep_0[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ celu (Celu)         │ (None, 512)       │          0 │ bn_deep_0[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ do_deep_0 (Dropout) │ (None, 512)       │          0 │ celu[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_deep_1        │ (None, 512)       │    262,656 │ do_deep_0[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_deep_1           │ (None, 512)       │      2,048 │ dense_deep_1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ celu_1 (Celu)       │ (None, 512)       │          0 │ bn_deep_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ do_deep_1 (Dropout) │ (None, 512)       │          0 │ celu_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_deep_2        │ (None, 512)       │    262,656 │ do_deep_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_deep_2           │ (None, 512)       │      2,048 │ dense_deep_2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ celu_2 (Celu)       │ (None, 512)       │          0 │ bn_deep_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20)        │         80 │ concatenate_5[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ do_deep_2 (Dropout) │ (None, 512)       │          0 │ celu_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 532)       │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ do_deep_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 1)         │        533 │ concatenate_6[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 542,861 (2.07 MB)
#  Trainable params: 539,749 (2.06 MB)
#  Non-trainable params: 3,112 (12.16 KB)

# %%
#keras.utils.plot_model(mod_test, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### 2.2.1 Optuna Optimization:

# %%
X_fin = data.X
X_test_fin = data.X_test

X_train_cat = data.X[cat_features]
X_train_num = data.X[num_features]

X_test_cat = data.X_test[cat_features]
X_test_num = data.X_test[num_features]

X_train_cat.info()
X_train_num.info()

y_fin = data.y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Outliers_Duration_Heart_Temp  765000 non-null  int64
#  2   Age_Group                     765000 non-null  int64
# dtypes: int64(3)
# memory usage: 23.3 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Height                 765000 non-null  float64
#  1   Weight                 765000 non-null  float64
#  2   Duration               765000 non-null  float64
#  3   Heart_Rate             765000 non-null  float64
#  4   Body_Temp              765000 non-null  float64
#  5   BMI                    765000 non-null  float64
#  6   Intensity              765000 non-null  float64
#  7   Intensity_v1           765000 non-null  float64
#  8   Heart_Duration         765000 non-null  float64
#  9   Weight_Duration_Heart  765000 non-null  float64
#  10  BMI_Age                765000 non-null  float64
#  11  BMR                    765000 non-null  float64
# dtypes: float64(12)
# memory usage: 75.9 MB

# %%
y_fin.isna().sum()
# Out:
# Calories    0
# dtype: int64

# %% [markdown]
# **OPTIMIZATION SECTION**

# %%
def objective_nn(trial, X, y, n_splits, n_repeats, model=wide_deep, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold"):

    model_class = model

    categorical_features = cat_features.copy()

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
              'units': trial.suggest_categorical('units', [128,256,512,1024]),
              'activation': trial.suggest_categorical('activation', ["relu","prelu","silu","mish"]), #, reg=0.001, dropout_rate=0.33)
              'reg': trial.suggest_float('reg', 1e-4, 0.1, log=True),
              'do_rate': trial.suggest_float('do_rate', 0.30, 0.50, step=0.01),
              'hidden_layers': trial.suggest_int('hidden_layers', 1,4)
              }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmsle_scores = []

    keras.backend.clear_session()

    iteration_n=0

    for idx_train, idx_valid in kf.split(X, y):
        print(f"Running Fold: {iteration_n}")
        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy()#.reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy()#.reshape(-1, 1)

        X_train_cat = X_train[cat_features]
        X_train_num = X_train[num_features]

        X_valid_cat = X_valid[cat_features]
        X_valid_num = X_valid[num_features]

        # Create the model
        keras.utils.set_random_seed(rs)
        model = model_class(**params)

        optimizer = keras.optimizers.Adam(learning_rate=5e-4)
        model.compile(optimizer=optimizer,
                      loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                      metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

        checkpoint_filepath = '/tmp/ckpt/checkpoint_dw.weights.h5'
        model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_rmsle',
            mode='min',
            save_best_only=True)

        # Fit the model
        model.fit([X_train_cat,X_train_num], y_train,
                  validation_data=([X_valid_cat, X_valid_num], y_valid),
                  epochs=31,
                  batch_size=1024,
                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor="val_rmsle",
                                                            start_from_epoch=3, mode="min"),
                             model_checkpoint_callback])

        model.load_weights(checkpoint_filepath)

        # Make predictions on the validation set
        y_pred = model.predict([X_valid_cat, X_valid_num], batch_size=1024)
        y_pred = np.maximum(y_pred, 1.0)
        y_pred = np.minimum(y_pred, 315.0)

        print("Pred Min: {}".format(y_pred.min()))
        print("Pred Max: {}".format(y_pred.max()))

        # Calculate the RMSE for the current fold
        rmsle_score = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Fold {iteration_n} RMSLE: {rmsle_score}")

        rmsle_scores.append(rmsle_score)
        iteration_n+=1

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmsle_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))
    study.optimize(lambda trial: objective_nn(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
X_fin.isna().sum(), y_fin.min()
# Out:
# (Sex                             0
#  Height                          0
#  Weight                          0
#  Duration                        0
#  Heart_Rate                      0
#  Body_Temp                       0
#  BMI                             0
#  Intensity                       0
#  Intensity_v1                    0
#  Heart_Duration                  0
#  Weight_Duration_Heart           0
#  Outliers_Duration_Heart_Temp    0
#  BMI_Age                         0
#  BMR                             0
#  Age_Group                       0
#  dtype: int64,
#  Calories    1.0
#  dtype: float64)

# %% [markdown]
#   1. Trial 32 finished with value: 0.06224817614285113 and parameters: {'units': 512, 'last_layer': 2, 'activation': 'silu', 'reg': 0.000103427172893175, 'do_rate': 0.40056000512858025, 'hidden_layers': 2}
#
#   2. Trial 18 finished with value: 0.06211038027842043 and parameters: {'units': 512, 'last_layer': 2, 'activation': 'silu', 'reg': 0.0001004170129215336, 'do_rate': 0.41356627172269655, 'hidden_layers': 3} Best
#
#   3.  Trial 23 finished with value: 0.06239891244956206 and parameters: {'units': 512, 'last_layer': 2, 'activation': 'silu', 'reg': 0.00010001356287977584, 'do_rate': 0.4642367345915417, 'hidden_layers': 2}.

# %%
nn0_study = tune_hyperparameters(X_fin, y_fin, model_class=wide_deep, n_trials=51, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)

cat_params = nn0_study.best_params
# Out:
# [I 2025-05-18 19:29:30,601] A new study created in memory with name: no-name-556a089d-136a-4050-b558-d04fe532fe13
# Running Fold: 0
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - dense_loss: 0.0000e+00 - loss: 2.0549 - msle: 95.4545 - rmsle: 2.0481 - val_dense_loss: 0.0000e+00 - val_loss: 0.5821 - val_msle: 58.7581 - val_rmsle: 0.5742 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.4196 - msle: 46.5712 - rmsle: 0.4120 - val_dense_loss: 0.0000e+00 - val_loss: 0.0971 - val_msle: 9.7340 - val_rmsle: 0.0900 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.1071 - msle: 8.7136 - rmsle: 0.1003 - val_dense_loss: 0.0000e+00 - val_loss: 0.0747 - val_msle: 5.7827 - val_rmsle: 0.0685 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0996 - msle: 7.6975 - rmsle: 0.0937 - val_dense_loss: 0.0000e+00 - val_loss: 0.0724 - val_msle: 5.5169 - val_rmsle: 0.0669 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0965 - msle: 7.5333 - rmsle: 0.0913 - val_dense_loss: 0.0000e+00 - val_loss: 0.0714 - val_msle: 5.2495 - val_rmsle: 0.0665 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0942 - msle: 7.3725 - rmsle: 0.0895 - val_dense_loss: 0.0000e+00 - val_loss: 0.0702 - val_msle: 5.0284 - val_rmsle: 0.0656 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0924 - msle: 7.2754 - rmsle: 0.0881 - val_dense_loss: 0.0000e+00 - val_loss: 0.0692 - val_msle: 4.8157 - val_rmsle: 0.0649 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0908 - msle: 7.1798 - rmsle: 0.0868 - val_dense_loss: 0.0000e+00 - val_loss: 0.0688 - val_msle: 4.6636 - val_rmsle: 0.0648 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0895 - msle: 7.0985 - rmsle: 0.0856 - val_dense_loss: 0.0000e+00 - val_loss: 0.0675 - val_msle: 4.5810 - val_rmsle: 0.0637 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0886 - msle: 7.0468 - rmsle: 0.0850 - val_dense_loss: 0.0000e+00 - val_loss: 0.0675 - val_msle: 4.5320 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0879 - msle: 6.9901 - rmsle: 0.0845 - val_dense_loss: 0.0000e+00 - val_loss: 0.0673 - val_msle: 4.4699 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0872 - msle: 6.9313 - rmsle: 0.0840 - val_dense_loss: 0.0000e+00 - val_loss: 0.0669 - val_msle: 4.4451 - val_rmsle: 0.0636 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0868 - msle: 6.9097 - rmsle: 0.0837 - val_dense_loss: 0.0000e+00 - val_loss: 0.0662 - val_msle: 4.3693 - val_rmsle: 0.0631 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0861 - msle: 6.8678 - rmsle: 0.0831 - val_dense_loss: 0.0000e+00 - val_loss: 0.0662 - val_msle: 4.3539 - val_rmsle: 0.0632 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0857 - msle: 6.8360 - rmsle: 0.0828 - val_dense_loss: 0.0000e+00 - val_loss: 0.0659 - val_msle: 4.3211 - val_rmsle: 0.0630 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0854 - msle: 6.8107 - rmsle: 0.0826 - val_dense_loss: 0.0000e+00 - val_loss: 0.0654 - val_msle: 4.3371 - val_rmsle: 0.0626 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0848 - msle: 6.7718 - rmsle: 0.0821 - val_dense_loss: 0.0000e+00 - val_loss: 0.0653 - val_msle: 4.2505 - val_rmsle: 0.0626 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0846 - msle: 6.7287 - rmsle: 0.0820 - val_dense_loss: 0.0000e+00 - val_loss: 0.0654 - val_msle: 4.2720 - val_rmsle: 0.0627 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0842 - msle: 6.7198 - rmsle: 0.0817 - val_dense_loss: 0.0000e+00 - val_loss: 0.0651 - val_msle: 4.2541 - val_rmsle: 0.0625 - learning_rate: 5.0000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0840 - msle: 6.6960 - rmsle: 0.0815 - val_dense_loss: 0.0000e+00 - val_loss: 0.0646 - val_msle: 4.2053 - val_rmsle: 0.0620 - learning_rate: 5.0000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0839 - msle: 6.6858 - rmsle: 0.0814 - val_dense_loss: 0.0000e+00 - val_loss: 0.0650 - val_msle: 4.2753 - val_rmsle: 0.0625 - learning_rate: 5.0000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0836 - msle: 6.6658 - rmsle: 0.0813 - val_dense_loss: 0.0000e+00 - val_loss: 0.0642 - val_msle: 4.1704 - val_rmsle: 0.0617 - learning_rate: 5.0000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0833 - msle: 6.6455 - rmsle: 0.0810 - val_dense_loss: 0.0000e+00 - val_loss: 0.0642 - val_msle: 4.2103 - val_rmsle: 0.0618 - learning_rate: 5.0000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0832 - msle: 6.6540 - rmsle: 0.0809 - val_dense_loss: 0.0000e+00 - val_loss: 0.0643 - val_msle: 4.2263 - val_rmsle: 0.0619 - learning_rate: 5.0000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0830 - msle: 6.6198 - rmsle: 0.0808 - val_dense_loss: 0.0000e+00 - val_loss: 0.0640 - val_msle: 4.1509 - val_rmsle: 0.0617 - learning_rate: 5.0000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0828 - msle: 6.6149 - rmsle: 0.0806 - val_dense_loss: 0.0000e+00 - val_loss: 0.0642 - val_msle: 4.2194 - val_rmsle: 0.0619 - learning_rate: 5.0000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0826 - msle: 6.5889 - rmsle: 0.0804 - val_dense_loss: 0.0000e+00 - val_loss: 0.0640 - val_msle: 4.2018 - val_rmsle: 0.0617 - learning_rate: 5.0000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0824 - msle: 6.5711 - rmsle: 0.0803 - val_dense_loss: 0.0000e+00 - val_loss: 0.0640 - val_msle: 4.1584 - val_rmsle: 0.0617 - learning_rate: 5.0000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0815 - msle: 6.5112 - rmsle: 0.0794 - val_dense_loss: 0.0000e+00 - val_loss: 0.0638 - val_msle: 4.1113 - val_rmsle: 0.0616 - learning_rate: 2.5000e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0812 - msle: 6.4848 - rmsle: 0.0792 - val_dense_loss: 0.0000e+00 - val_loss: 0.0637 - val_msle: 4.0680 - val_rmsle: 0.0616 - learning_rate: 2.5000e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0813 - msle: 6.5010 - rmsle: 0.0793 - val_dense_loss: 0.0000e+00 - val_loss: 0.0638 - val_msle: 4.0972 - val_rmsle: 0.0618 - learning_rate: 2.5000e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 315.0
# Fold 0 RMSLE: 0.062460234040149054
# Running Fold: 1
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - dense_1_loss: 0.0000e+00 - loss: 2.0554 - msle: 95.3654 - rmsle: 2.0487 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.5787 - val_msle: 58.5811 - val_rmsle: 0.5709 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.4158 - msle: 46.2428 - rmsle: 0.4082 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0894 - val_msle: 9.5867 - val_rmsle: 0.0823 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1069 - msle: 8.6872 - rmsle: 0.1001 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0750 - val_msle: 6.0693 - val_rmsle: 0.0688 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0996 - msle: 7.6963 - rmsle: 0.0937 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0720 - val_msle: 5.5351 - val_rmsle: 0.0666 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0965 - msle: 7.5101 - rmsle: 0.0912 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0705 - val_msle: 5.2098 - val_rmsle: 0.0655 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0938 - msle: 7.3630 - rmsle: 0.0891 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0701 - val_msle: 5.0037 - val_rmsle: 0.0656 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0921 - msle: 7.2753 - rmsle: 0.0878 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0692 - val_msle: 4.8739 - val_rmsle: 0.0650 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0905 - msle: 7.1603 - rmsle: 0.0865 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0676 - val_msle: 4.6694 - val_rmsle: 0.0637 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0892 - msle: 7.0750 - rmsle: 0.0854 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0681 - val_msle: 4.5803 - val_rmsle: 0.0644 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0883 - msle: 7.0228 - rmsle: 0.0847 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0676 - val_msle: 4.5292 - val_rmsle: 0.0641 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0874 - msle: 6.9484 - rmsle: 0.0841 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0678 - val_msle: 4.5908 - val_rmsle: 0.0645 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0859 - msle: 6.8726 - rmsle: 0.0827 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0654 - val_msle: 4.3977 - val_rmsle: 0.0622 - learning_rate: 2.5000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0856 - msle: 6.8394 - rmsle: 0.0825 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0655 - val_msle: 4.3560 - val_rmsle: 0.0625 - learning_rate: 2.5000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0851 - msle: 6.7964 - rmsle: 0.0822 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0655 - val_msle: 4.3851 - val_rmsle: 0.0625 - learning_rate: 2.5000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0847 - msle: 6.7783 - rmsle: 0.0818 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0653 - val_msle: 4.3414 - val_rmsle: 0.0624 - learning_rate: 2.5000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0845 - msle: 6.7841 - rmsle: 0.0818 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 4.2835 - val_rmsle: 0.0621 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0842 - msle: 6.7326 - rmsle: 0.0815 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0651 - val_msle: 4.3550 - val_rmsle: 0.0624 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0839 - msle: 6.7134 - rmsle: 0.0814 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0654 - val_msle: 4.4430 - val_rmsle: 0.0627 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0836 - msle: 6.7008 - rmsle: 0.0811 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0652 - val_msle: 4.4250 - val_rmsle: 0.0626 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0829 - msle: 6.6529 - rmsle: 0.0805 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0642 - val_msle: 4.2383 - val_rmsle: 0.0617 - learning_rate: 1.2500e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0829 - msle: 6.6303 - rmsle: 0.0805 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0640 - val_msle: 4.2346 - val_rmsle: 0.0615 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0828 - msle: 6.6284 - rmsle: 0.0805 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0641 - val_msle: 4.2407 - val_rmsle: 0.0617 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0824 - msle: 6.6031 - rmsle: 0.0801 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0641 - val_msle: 4.2144 - val_rmsle: 0.0617 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0824 - msle: 6.6105 - rmsle: 0.0802 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0639 - val_msle: 4.1949 - val_rmsle: 0.0615 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0824 - msle: 6.5937 - rmsle: 0.0802 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0642 - val_msle: 4.2360 - val_rmsle: 0.0618 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0823 - msle: 6.5969 - rmsle: 0.0801 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0639 - val_msle: 4.1875 - val_rmsle: 0.0616 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0821 - msle: 6.5831 - rmsle: 0.0799 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0639 - val_msle: 4.1999 - val_rmsle: 0.0617 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0817 - msle: 6.5576 - rmsle: 0.0795 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0635 - val_msle: 4.1506 - val_rmsle: 0.0613 - learning_rate: 6.2500e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0817 - msle: 6.5514 - rmsle: 0.0796 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0637 - val_msle: 4.1903 - val_rmsle: 0.0614 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0815 - msle: 6.5157 - rmsle: 0.0794 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0634 - val_msle: 4.1512 - val_rmsle: 0.0612 - learning_rate: 6.2500e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0815 - msle: 6.5229 - rmsle: 0.0794 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0635 - val_msle: 4.1508 - val_rmsle: 0.0613 - learning_rate: 6.2500e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 310.6658935546875
# Fold 1 RMSLE: 0.06181646832956546
# Running Fold: 2
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - dense_2_loss: 0.0000e+00 - loss: 2.0542 - msle: 95.3200 - rmsle: 2.0474 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.5790 - val_msle: 58.5987 - val_rmsle: 0.5712 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.4174 - msle: 46.3281 - rmsle: 0.4099 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0895 - val_msle: 9.3450 - val_rmsle: 0.0825 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1071 - msle: 8.6921 - rmsle: 0.1003 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0753 - val_msle: 5.8143 - val_rmsle: 0.0692 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0996 - msle: 7.6758 - rmsle: 0.0937 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0729 - val_msle: 5.5520 - val_rmsle: 0.0674 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0965 - msle: 7.4992 - rmsle: 0.0912 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0708 - val_msle: 5.2331 - val_rmsle: 0.0659 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0938 - msle: 7.3841 - rmsle: 0.0889 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0695 - val_msle: 5.0940 - val_rmsle: 0.0649 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0920 - msle: 7.2720 - rmsle: 0.0875 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0691 - val_msle: 4.9590 - val_rmsle: 0.0648 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0904 - msle: 7.1822 - rmsle: 0.0862 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0688 - val_msle: 4.9395 - val_rmsle: 0.0648 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0891 - msle: 7.1053 - rmsle: 0.0852 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0708 - val_msle: 5.0693 - val_rmsle: 0.0670 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0882 - msle: 7.0279 - rmsle: 0.0845 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0679 - val_msle: 4.7090 - val_rmsle: 0.0644 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0875 - msle: 7.0036 - rmsle: 0.0840 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0686 - val_msle: 4.8973 - val_rmsle: 0.0652 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0867 - msle: 6.9245 - rmsle: 0.0834 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0679 - val_msle: 4.6953 - val_rmsle: 0.0646 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0860 - msle: 6.8770 - rmsle: 0.0829 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0675 - val_msle: 4.5999 - val_rmsle: 0.0644 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0854 - msle: 6.8315 - rmsle: 0.0824 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0672 - val_msle: 4.5511 - val_rmsle: 0.0643 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0848 - msle: 6.7981 - rmsle: 0.0819 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0679 - val_msle: 4.8519 - val_rmsle: 0.0650 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0845 - msle: 6.7941 - rmsle: 0.0817 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0671 - val_msle: 4.5236 - val_rmsle: 0.0643 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0842 - msle: 6.7499 - rmsle: 0.0815 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0669 - val_msle: 4.4874 - val_rmsle: 0.0642 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0837 - msle: 6.7426 - rmsle: 0.0811 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0667 - val_msle: 4.5277 - val_rmsle: 0.0641 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0836 - msle: 6.7049 - rmsle: 0.0810 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0668 - val_msle: 4.6827 - val_rmsle: 0.0643 - learning_rate: 5.0000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0830 - msle: 6.6795 - rmsle: 0.0806 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0667 - val_msle: 4.5116 - val_rmsle: 0.0642 - learning_rate: 5.0000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0830 - msle: 6.6592 - rmsle: 0.0806 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0665 - val_msle: 4.5047 - val_rmsle: 0.0641 - learning_rate: 5.0000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0826 - msle: 6.6502 - rmsle: 0.0803 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0662 - val_msle: 4.5578 - val_rmsle: 0.0638 - learning_rate: 5.0000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0822 - msle: 6.6088 - rmsle: 0.0799 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0659 - val_msle: 4.4678 - val_rmsle: 0.0636 - learning_rate: 5.0000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0820 - msle: 6.6072 - rmsle: 0.0797 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0662 - val_msle: 4.5879 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0819 - msle: 6.5960 - rmsle: 0.0796 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0662 - val_msle: 4.4541 - val_rmsle: 0.0640 - learning_rate: 5.0000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0816 - msle: 6.5659 - rmsle: 0.0794 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0661 - val_msle: 4.3618 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0808 - msle: 6.5055 - rmsle: 0.0786 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.3490 - val_rmsle: 0.0634 - learning_rate: 2.5000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0805 - msle: 6.4881 - rmsle: 0.0784 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0666 - val_msle: 4.4848 - val_rmsle: 0.0645 - learning_rate: 2.5000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0804 - msle: 6.4677 - rmsle: 0.0784 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0659 - val_msle: 4.3906 - val_rmsle: 0.0638 - learning_rate: 2.5000e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0800 - msle: 6.4358 - rmsle: 0.0780 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0661 - val_msle: 4.3821 - val_rmsle: 0.0642 - learning_rate: 2.5000e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0795 - msle: 6.3935 - rmsle: 0.0776 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0636 - val_msle: 4.1857 - val_rmsle: 0.0616 - learning_rate: 1.2500e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 305.2626953125
# Fold 2 RMSLE: 0.06231964939275678
# Running Fold: 3
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - dense_3_loss: 0.0000e+00 - loss: 2.0551 - msle: 95.3812 - rmsle: 2.0483 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.5758 - val_msle: 58.5242 - val_rmsle: 0.5680 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.4162 - msle: 46.2772 - rmsle: 0.4087 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0996 - val_msle: 9.6724 - val_rmsle: 0.0925 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1083 - msle: 8.7943 - rmsle: 0.1015 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0777 - val_msle: 6.0727 - val_rmsle: 0.0715 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1016 - msle: 7.7743 - rmsle: 0.0956 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0743 - val_msle: 5.6536 - val_rmsle: 0.0687 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0983 - msle: 7.6135 - rmsle: 0.0929 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0728 - val_msle: 5.4672 - val_rmsle: 0.0677 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0959 - msle: 7.5032 - rmsle: 0.0909 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0721 - val_msle: 5.2263 - val_rmsle: 0.0673 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0936 - msle: 7.3689 - rmsle: 0.0890 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0719 - val_msle: 5.3106 - val_rmsle: 0.0675 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0919 - msle: 7.2655 - rmsle: 0.0877 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0714 - val_msle: 5.1663 - val_rmsle: 0.0672 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0906 - msle: 7.1983 - rmsle: 0.0866 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0703 - val_msle: 4.9708 - val_rmsle: 0.0664 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0897 - msle: 7.1238 - rmsle: 0.0859 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0701 - val_msle: 4.9110 - val_rmsle: 0.0664 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0888 - msle: 7.0441 - rmsle: 0.0852 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0690 - val_msle: 4.7230 - val_rmsle: 0.0655 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0879 - msle: 7.0170 - rmsle: 0.0845 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0682 - val_msle: 4.6374 - val_rmsle: 0.0648 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0874 - msle: 6.9694 - rmsle: 0.0842 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0678 - val_msle: 4.5035 - val_rmsle: 0.0646 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0866 - msle: 6.9120 - rmsle: 0.0835 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0676 - val_msle: 4.4228 - val_rmsle: 0.0644 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0863 - msle: 6.8995 - rmsle: 0.0834 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0672 - val_msle: 4.4365 - val_rmsle: 0.0642 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0859 - msle: 6.8588 - rmsle: 0.0830 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0672 - val_msle: 4.4084 - val_rmsle: 0.0643 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0856 - msle: 6.8341 - rmsle: 0.0828 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0674 - val_msle: 4.4325 - val_rmsle: 0.0646 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0854 - msle: 6.8029 - rmsle: 0.0827 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0667 - val_msle: 4.3345 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0848 - msle: 6.7728 - rmsle: 0.0822 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0663 - val_msle: 4.2832 - val_rmsle: 0.0636 - learning_rate: 5.0000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0848 - msle: 6.7759 - rmsle: 0.0822 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0667 - val_msle: 4.3395 - val_rmsle: 0.0641 - learning_rate: 5.0000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0843 - msle: 6.7387 - rmsle: 0.0818 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0659 - val_msle: 4.2846 - val_rmsle: 0.0633 - learning_rate: 5.0000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0841 - msle: 6.7284 - rmsle: 0.0816 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0657 - val_msle: 4.2427 - val_rmsle: 0.0631 - learning_rate: 5.0000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0839 - msle: 6.7048 - rmsle: 0.0815 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.2233 - val_rmsle: 0.0631 - learning_rate: 5.0000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0836 - msle: 6.6999 - rmsle: 0.0813 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0655 - val_msle: 4.2060 - val_rmsle: 0.0631 - learning_rate: 5.0000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0835 - msle: 6.6883 - rmsle: 0.0812 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.2092 - val_rmsle: 0.0632 - learning_rate: 5.0000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0833 - msle: 6.6718 - rmsle: 0.0810 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.2499 - val_rmsle: 0.0632 - learning_rate: 5.0000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0830 - msle: 6.6372 - rmsle: 0.0808 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0651 - val_msle: 4.1802 - val_rmsle: 0.0628 - learning_rate: 5.0000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0830 - msle: 6.6571 - rmsle: 0.0808 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.2190 - val_rmsle: 0.0633 - learning_rate: 5.0000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0828 - msle: 6.6291 - rmsle: 0.0806 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0650 - val_msle: 4.1764 - val_rmsle: 0.0627 - learning_rate: 5.0000e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0827 - msle: 6.6023 - rmsle: 0.0805 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 4.1672 - val_rmsle: 0.0626 - learning_rate: 5.0000e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_3_loss: 0.0000e+00 - loss: 0.0825 - msle: 6.6156 - rmsle: 0.0803 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 4.1001 - val_rmsle: 0.0626 - learning_rate: 5.0000e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 305.29937744140625
# Fold 3 RMSLE: 0.06347527208555301
# Running Fold: 4
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - dense_4_loss: 0.0000e+00 - loss: 2.0566 - msle: 95.5244 - rmsle: 2.0498 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.5803 - val_msle: 58.5229 - val_rmsle: 0.5725 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.4186 - msle: 46.5268 - rmsle: 0.4110 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0892 - val_msle: 9.5466 - val_rmsle: 0.0822 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.1068 - msle: 8.6839 - rmsle: 0.1000 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0741 - val_msle: 6.0476 - val_rmsle: 0.0679 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0991 - msle: 7.6532 - rmsle: 0.0932 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0714 - val_msle: 5.5911 - val_rmsle: 0.0659 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0962 - msle: 7.4582 - rmsle: 0.0909 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0704 - val_msle: 5.4528 - val_rmsle: 0.0654 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0935 - msle: 7.3245 - rmsle: 0.0887 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0703 - val_msle: 5.3764 - val_rmsle: 0.0657 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0915 - msle: 7.2098 - rmsle: 0.0871 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0706 - val_msle: 5.4713 - val_rmsle: 0.0663 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0900 - msle: 7.1104 - rmsle: 0.0859 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0700 - val_msle: 5.3719 - val_rmsle: 0.0659 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0888 - msle: 7.0479 - rmsle: 0.0850 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0709 - val_msle: 5.4678 - val_rmsle: 0.0671 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0878 - msle: 6.9868 - rmsle: 0.0842 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0707 - val_msle: 5.5227 - val_rmsle: 0.0671 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0871 - msle: 6.9488 - rmsle: 0.0837 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0692 - val_msle: 5.3736 - val_rmsle: 0.0658 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0866 - msle: 6.8802 - rmsle: 0.0833 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0700 - val_msle: 5.3790 - val_rmsle: 0.0667 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0859 - msle: 6.8341 - rmsle: 0.0828 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0697 - val_msle: 5.2672 - val_rmsle: 0.0665 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0854 - msle: 6.7941 - rmsle: 0.0824 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0708 - val_msle: 5.7386 - val_rmsle: 0.0678 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0839 - msle: 6.6957 - rmsle: 0.0811 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0653 - val_msle: 4.7223 - val_rmsle: 0.0624 - learning_rate: 2.5000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0836 - msle: 6.6578 - rmsle: 0.0809 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 4.6098 - val_rmsle: 0.0620 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0833 - msle: 6.6588 - rmsle: 0.0806 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0645 - val_msle: 4.5353 - val_rmsle: 0.0618 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0831 - msle: 6.6507 - rmsle: 0.0805 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0649 - val_msle: 4.6996 - val_rmsle: 0.0622 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0828 - msle: 6.5933 - rmsle: 0.0803 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0652 - val_msle: 4.6558 - val_rmsle: 0.0626 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0824 - msle: 6.6000 - rmsle: 0.0800 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0649 - val_msle: 4.5931 - val_rmsle: 0.0624 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0819 - msle: 6.5702 - rmsle: 0.0795 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0635 - val_msle: 4.3468 - val_rmsle: 0.0610 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0819 - msle: 6.5377 - rmsle: 0.0796 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0634 - val_msle: 4.3190 - val_rmsle: 0.0610 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0814 - msle: 6.5128 - rmsle: 0.0791 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0635 - val_msle: 4.2962 - val_rmsle: 0.0611 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0816 - msle: 6.5203 - rmsle: 0.0794 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0635 - val_msle: 4.2939 - val_rmsle: 0.0611 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0811 - msle: 6.4715 - rmsle: 0.0789 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0625 - val_msle: 4.1106 - val_rmsle: 0.0602 - learning_rate: 6.2500e-05
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0810 - msle: 6.4727 - rmsle: 0.0788 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0624 - val_msle: 4.0561 - val_rmsle: 0.0601 - learning_rate: 6.2500e-05
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0810 - msle: 6.4512 - rmsle: 0.0788 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0624 - val_msle: 4.0926 - val_rmsle: 0.0601 - learning_rate: 6.2500e-05
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0808 - msle: 6.4457 - rmsle: 0.0786 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0624 - val_msle: 4.0866 - val_rmsle: 0.0601 - learning_rate: 6.2500e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0807 - msle: 6.4336 - rmsle: 0.0786 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0625 - val_msle: 4.1079 - val_rmsle: 0.0602 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0805 - msle: 6.4259 - rmsle: 0.0784 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0622 - val_msle: 4.0427 - val_rmsle: 0.0600 - learning_rate: 3.1250e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_4_loss: 0.0000e+00 - loss: 0.0804 - msle: 6.4335 - rmsle: 0.0783 - val_dense_4_loss: 0.0000e+00 - val_loss: 0.0622 - val_msle: 4.0146 - val_rmsle: 0.0600 - learning_rate: 3.1250e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 314.8586730957031
# Fold 4 RMSLE: 0.060755436390557145
# [I 2025-05-18 19:35:45,808] Trial 0 finished with value: 0.062165412047716286 and parameters: {'units': 512, 'activation': 'relu', 'reg': 0.00019778644874748975, 'do_rate': 0.38, 'hidden_layers': 1}. Best is trial 0 with value: 0.062165412047716286.
# Running Fold: 0
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - dense_loss: 0.0000e+00 - loss: 2.3767 - msle: 99.6646 - rmsle: 2.3671 - val_dense_loss: 0.0000e+00 - val_loss: 0.9437 - val_msle: 76.2512 - val_rmsle: 0.9338 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.7587 - msle: 67.4108 - rmsle: 0.7495 - val_dense_loss: 0.0000e+00 - val_loss: 0.3291 - val_msle: 38.2088 - val_rmsle: 0.3216 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.2571 - msle: 29.1917 - rmsle: 0.2497 - val_dense_loss: 0.0000e+00 - val_loss: 0.1035 - val_msle: 9.7502 - val_rmsle: 0.0964 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.1337 - msle: 9.5278 - rmsle: 0.1269 - val_dense_loss: 0.0000e+00 - val_loss: 0.0897 - val_msle: 6.1147 - val_rmsle: 0.0833 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.1166 - msle: 8.3429 - rmsle: 0.1105 - val_dense_loss: 0.0000e+00 - val_loss: 0.0732 - val_msle: 5.5041 - val_rmsle: 0.0673 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.1085 - msle: 8.1037 - rmsle: 0.1029 - val_dense_loss: 0.0000e+00 - val_loss: 0.0730 - val_msle: 5.1775 - val_rmsle: 0.0675 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.1045 - msle: 8.0077 - rmsle: 0.0992 - val_dense_loss: 0.0000e+00 - val_loss: 0.0704 - val_msle: 5.0762 - val_rmsle: 0.0653 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.1010 - msle: 7.9060 - rmsle: 0.0961 - val_dense_loss: 0.0000e+00 - val_loss: 0.0710 - val_msle: 4.8868 - val_rmsle: 0.0661 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0991 - msle: 7.8229 - rmsle: 0.0944 - val_dense_loss: 0.0000e+00 - val_loss: 0.0710 - val_msle: 4.8617 - val_rmsle: 0.0664 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0974 - msle: 7.7911 - rmsle: 0.0929 - val_dense_loss: 0.0000e+00 - val_loss: 0.0698 - val_msle: 4.8025 - val_rmsle: 0.0654 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0960 - msle: 7.7583 - rmsle: 0.0917 - val_dense_loss: 0.0000e+00 - val_loss: 0.0688 - val_msle: 4.7071 - val_rmsle: 0.0646 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0949 - msle: 7.6750 - rmsle: 0.0908 - val_dense_loss: 0.0000e+00 - val_loss: 0.0686 - val_msle: 4.6636 - val_rmsle: 0.0645 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0937 - msle: 7.6203 - rmsle: 0.0898 - val_dense_loss: 0.0000e+00 - val_loss: 0.0682 - val_msle: 4.6072 - val_rmsle: 0.0642 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0931 - msle: 7.5772 - rmsle: 0.0893 - val_dense_loss: 0.0000e+00 - val_loss: 0.0678 - val_msle: 4.5788 - val_rmsle: 0.0640 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0920 - msle: 7.5298 - rmsle: 0.0883 - val_dense_loss: 0.0000e+00 - val_loss: 0.0672 - val_msle: 4.5501 - val_rmsle: 0.0635 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0914 - msle: 7.4814 - rmsle: 0.0878 - val_dense_loss: 0.0000e+00 - val_loss: 0.0680 - val_msle: 4.5274 - val_rmsle: 0.0643 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - dense_loss: 0.0000e+00 - loss: 0.0907 - msle: 7.4350 - rmsle: 0.0873 - val_dense_loss: 0.0000e+00 - val_loss: 0.0674 - val_msle: 4.4868 - val_rmsle: 0.0639 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0904 - msle: 7.4094 - rmsle: 0.0871 - val_dense_loss: 0.0000e+00 - val_loss: 0.0674 - val_msle: 4.5060 - val_rmsle: 0.0640 - learning_rate: 5.0000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0891 - msle: 7.3263 - rmsle: 0.0858 - val_dense_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.3802 - val_rmsle: 0.0623 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0886 - msle: 7.3218 - rmsle: 0.0854 - val_dense_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 4.3707 - val_rmsle: 0.0623 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0884 - msle: 7.3056 - rmsle: 0.0853 - val_dense_loss: 0.0000e+00 - val_loss: 0.0653 - val_msle: 4.3231 - val_rmsle: 0.0621 - learning_rate: 2.5000e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0879 - msle: 7.2744 - rmsle: 0.0849 - val_dense_loss: 0.0000e+00 - val_loss: 0.0652 - val_msle: 4.2905 - val_rmsle: 0.0621 - learning_rate: 2.5000e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0877 - msle: 7.2646 - rmsle: 0.0848 - val_dense_loss: 0.0000e+00 - val_loss: 0.0655 - val_msle: 4.2968 - val_rmsle: 0.0624 - learning_rate: 2.5000e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0875 - msle: 7.2548 - rmsle: 0.0846 - val_dense_loss: 0.0000e+00 - val_loss: 0.0652 - val_msle: 4.2838 - val_rmsle: 0.0622 - learning_rate: 2.5000e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0874 - msle: 7.2174 - rmsle: 0.0846 - val_dense_loss: 0.0000e+00 - val_loss: 0.0650 - val_msle: 4.2640 - val_rmsle: 0.0621 - learning_rate: 2.5000e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0872 - msle: 7.1853 - rmsle: 0.0844 - val_dense_loss: 0.0000e+00 - val_loss: 0.0650 - val_msle: 4.2603 - val_rmsle: 0.0622 - learning_rate: 2.5000e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0872 - msle: 7.2057 - rmsle: 0.0844 - val_dense_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 4.2473 - val_rmsle: 0.0620 - learning_rate: 2.5000e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0868 - msle: 7.1667 - rmsle: 0.0841 - val_dense_loss: 0.0000e+00 - val_loss: 0.0651 - val_msle: 4.2481 - val_rmsle: 0.0623 - learning_rate: 2.5000e-04
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0866 - msle: 7.1547 - rmsle: 0.0840 - val_dense_loss: 0.0000e+00 - val_loss: 0.0649 - val_msle: 4.2345 - val_rmsle: 0.0621 - learning_rate: 2.5000e-04
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0862 - msle: 7.1382 - rmsle: 0.0836 - val_dense_loss: 0.0000e+00 - val_loss: 0.0647 - val_msle: 4.2161 - val_rmsle: 0.0620 - learning_rate: 2.5000e-04
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_loss: 0.0000e+00 - loss: 0.0864 - msle: 7.1670 - rmsle: 0.0838 - val_dense_loss: 0.0000e+00 - val_loss: 0.0646 - val_msle: 4.2048 - val_rmsle: 0.0619 - learning_rate: 2.5000e-04
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Pred Min: 1.0
# Pred Max: 315.0
# Fold 0 RMSLE: 0.06281467176372092
# Running Fold: 1
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - dense_1_loss: 0.0000e+00 - loss: 2.3746 - msle: 99.5931 - rmsle: 2.3651 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.9434 - val_msle: 76.3172 - val_rmsle: 0.9336 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.7568 - msle: 67.3033 - rmsle: 0.7477 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.3256 - val_msle: 38.7228 - val_rmsle: 0.3181 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.2552 - msle: 29.0611 - rmsle: 0.2478 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.1020 - val_msle: 9.9623 - val_rmsle: 0.0949 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1330 - msle: 9.4784 - rmsle: 0.1262 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0836 - val_msle: 6.2140 - val_rmsle: 0.0772 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1164 - msle: 8.3068 - rmsle: 0.1102 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0753 - val_msle: 5.5172 - val_rmsle: 0.0694 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1088 - msle: 8.0927 - rmsle: 0.1031 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0727 - val_msle: 5.3708 - val_rmsle: 0.0672 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1042 - msle: 8.0118 - rmsle: 0.0989 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0713 - val_msle: 5.1465 - val_rmsle: 0.0661 - learning_rate: 5.0000e-04
# Epoch 8/31
# ...
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1083 - msle: 8.2551 - rmsle: 0.0983 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0832 - val_msle: 4.2437 - val_rmsle: 0.0734 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1070 - msle: 8.1785 - rmsle: 0.0973 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0859 - val_msle: 6.2538 - val_rmsle: 0.0764 - learning_rate: 5.0000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1062 - msle: 8.1640 - rmsle: 0.0966 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0799 - val_msle: 6.0140 - val_rmsle: 0.0706 - learning_rate: 5.0000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1058 - msle: 8.1145 - rmsle: 0.0963 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0853 - val_msle: 5.7774 - val_rmsle: 0.0759 - learning_rate: 5.0000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1045 - msle: 8.0596 - rmsle: 0.0952 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0820 - val_msle: 4.8388 - val_rmsle: 0.0728 - learning_rate: 5.0000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1039 - msle: 7.9988 - rmsle: 0.0946 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0762 - val_msle: 4.0831 - val_rmsle: 0.0670 - learning_rate: 5.0000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1031 - msle: 7.9255 - rmsle: 0.0939 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0838 - val_msle: 6.2061 - val_rmsle: 0.0744 - learning_rate: 5.0000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1031 - msle: 7.9250 - rmsle: 0.0938 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0791 - val_msle: 4.2528 - val_rmsle: 0.0701 - learning_rate: 5.0000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.1024 - msle: 7.9179 - rmsle: 0.0933 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0803 - val_msle: 4.8732 - val_rmsle: 0.0711 - learning_rate: 5.0000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0988 - msle: 7.5875 - rmsle: 0.0901 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0810 - val_msle: 6.5157 - val_rmsle: 0.0733 - learning_rate: 2.5000e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0973 - msle: 7.6309 - rmsle: 0.0899 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0776 - val_msle: 5.5062 - val_rmsle: 0.0704 - learning_rate: 2.5000e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0967 - msle: 7.6258 - rmsle: 0.0896 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0796 - val_msle: 6.7856 - val_rmsle: 0.0725 - learning_rate: 2.5000e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0931 - msle: 7.2912 - rmsle: 0.0864 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0721 - val_msle: 5.7455 - val_rmsle: 0.0660 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0919 - msle: 7.2672 - rmsle: 0.0860 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0695 - val_msle: 4.4838 - val_rmsle: 0.0638 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0915 - msle: 7.2818 - rmsle: 0.0859 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0695 - val_msle: 4.5012 - val_rmsle: 0.0640 - learning_rate: 1.2500e-04
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0911 - msle: 7.2587 - rmsle: 0.0857 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0674 - val_msle: 4.3057 - val_rmsle: 0.0621 - learning_rate: 1.2500e-04
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0904 - msle: 7.2269 - rmsle: 0.0852 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0683 - val_msle: 4.0480 - val_rmsle: 0.0630 - learning_rate: 1.2500e-04
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0903 - msle: 7.2321 - rmsle: 0.0852 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0686 - val_msle: 4.7039 - val_rmsle: 0.0635 - learning_rate: 1.2500e-04
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0898 - msle: 7.1976 - rmsle: 0.0848 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0687 - val_msle: 4.1429 - val_rmsle: 0.0637 - learning_rate: 1.2500e-04
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0880 - msle: 7.0163 - rmsle: 0.0832 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0667 - val_msle: 4.3688 - val_rmsle: 0.0619 - learning_rate: 6.2500e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0873 - msle: 7.0153 - rmsle: 0.0827 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0666 - val_msle: 4.4030 - val_rmsle: 0.0620 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0869 - msle: 7.0024 - rmsle: 0.0824 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0664 - val_msle: 4.2915 - val_rmsle: 0.0619 - learning_rate: 6.2500e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_1_loss: 0.0000e+00 - loss: 0.0866 - msle: 6.9893 - rmsle: 0.0823 - val_dense_1_loss: 0.0000e+00 - val_loss: 0.0657 - val_msle: 4.0611 - val_rmsle: 0.0614 - learning_rate: 6.2500e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Pred Min: 1.0
# Pred Max: 301.19573974609375
# Fold 1 RMSLE: 0.0619652506270624
# Running Fold: 2
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - dense_2_loss: 0.0000e+00 - loss: 2.1699 - msle: 93.7737 - rmsle: 1.9823 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.5608 - val_msle: 52.9177 - val_rmsle: 0.4831 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.2997 - msle: 29.1441 - rmsle: 0.2409 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.1464 - val_msle: 10.5047 - val_rmsle: 0.1191 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1346 - msle: 8.6683 - rmsle: 0.1113 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.1017 - val_msle: 6.1787 - val_rmsle: 0.0858 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1199 - msle: 8.4155 - rmsle: 0.1051 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0852 - val_msle: 4.5998 - val_rmsle: 0.0725 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1141 - msle: 8.3405 - rmsle: 0.1020 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0933 - val_msle: 6.2019 - val_rmsle: 0.0821 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1107 - msle: 8.2446 - rmsle: 0.0998 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0835 - val_msle: 4.3427 - val_rmsle: 0.0727 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1098 - msle: 8.2270 - rmsle: 0.0993 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0931 - val_msle: 5.0951 - val_rmsle: 0.0829 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1076 - msle: 8.1945 - rmsle: 0.0976 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0861 - val_msle: 5.5513 - val_rmsle: 0.0763 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1058 - msle: 8.0511 - rmsle: 0.0961 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0852 - val_msle: 4.4432 - val_rmsle: 0.0754 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1015 - msle: 7.7764 - rmsle: 0.0923 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0849 - val_msle: 8.1604 - val_rmsle: 0.0768 - learning_rate: 2.5000e-04
# Epoch 11/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.1002 - msle: 7.7695 - rmsle: 0.0923 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0824 - val_msle: 7.2220 - val_rmsle: 0.0748 - learning_rate: 2.5000e-04
# Epoch 12/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0990 - msle: 7.7653 - rmsle: 0.0915 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0792 - val_msle: 5.7701 - val_rmsle: 0.0718 - learning_rate: 2.5000e-04
# Epoch 13/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0986 - msle: 7.7217 - rmsle: 0.0913 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0800 - val_msle: 5.7547 - val_rmsle: 0.0727 - learning_rate: 2.5000e-04
# Epoch 14/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0978 - msle: 7.7016 - rmsle: 0.0906 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0769 - val_msle: 6.0211 - val_rmsle: 0.0698 - learning_rate: 2.5000e-04
# Epoch 15/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0974 - msle: 7.6433 - rmsle: 0.0903 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0780 - val_msle: 5.9111 - val_rmsle: 0.0710 - learning_rate: 2.5000e-04
# Epoch 16/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0967 - msle: 7.6027 - rmsle: 0.0898 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0776 - val_msle: 5.6022 - val_rmsle: 0.0707 - learning_rate: 2.5000e-04
# Epoch 17/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0963 - msle: 7.5976 - rmsle: 0.0894 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0777 - val_msle: 6.5126 - val_rmsle: 0.0708 - learning_rate: 2.5000e-04
# Epoch 18/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0934 - msle: 7.3574 - rmsle: 0.0867 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0689 - val_msle: 4.7067 - val_rmsle: 0.0628 - learning_rate: 1.2500e-04
# Epoch 19/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0923 - msle: 7.3222 - rmsle: 0.0862 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0680 - val_msle: 4.3108 - val_rmsle: 0.0622 - learning_rate: 1.2500e-04
# Epoch 20/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0917 - msle: 7.2781 - rmsle: 0.0860 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0695 - val_msle: 5.3084 - val_rmsle: 0.0639 - learning_rate: 1.2500e-04
# Epoch 21/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0915 - msle: 7.3138 - rmsle: 0.0860 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0679 - val_msle: 4.4693 - val_rmsle: 0.0625 - learning_rate: 1.2500e-04
# Epoch 22/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0912 - msle: 7.2799 - rmsle: 0.0858 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0699 - val_msle: 5.0436 - val_rmsle: 0.0646 - learning_rate: 1.2500e-04
# Epoch 23/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0890 - msle: 7.1318 - rmsle: 0.0838 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0654 - val_msle: 3.6402 - val_rmsle: 0.0603 - learning_rate: 6.2500e-05
# Epoch 24/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0883 - msle: 7.0692 - rmsle: 0.0833 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0656 - val_msle: 3.6334 - val_rmsle: 0.0607 - learning_rate: 6.2500e-05
# Epoch 25/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0878 - msle: 7.0543 - rmsle: 0.0830 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0649 - val_msle: 3.5915 - val_rmsle: 0.0602 - learning_rate: 6.2500e-05
# Epoch 26/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0873 - msle: 7.0328 - rmsle: 0.0827 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0651 - val_msle: 3.8434 - val_rmsle: 0.0605 - learning_rate: 6.2500e-05
# Epoch 27/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0874 - msle: 7.0219 - rmsle: 0.0829 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0646 - val_msle: 3.6153 - val_rmsle: 0.0602 - learning_rate: 6.2500e-05
# Epoch 28/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0870 - msle: 7.0392 - rmsle: 0.0826 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0643 - val_msle: 3.5739 - val_rmsle: 0.0599 - learning_rate: 6.2500e-05
# Epoch 29/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0867 - msle: 7.0015 - rmsle: 0.0824 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0648 - val_msle: 3.6392 - val_rmsle: 0.0605 - learning_rate: 6.2500e-05
# Epoch 30/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0864 - msle: 6.9833 - rmsle: 0.0822 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0647 - val_msle: 3.6151 - val_rmsle: 0.0605 - learning_rate: 6.2500e-05
# Epoch 31/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_2_loss: 0.0000e+00 - loss: 0.0861 - msle: 6.9613 - rmsle: 0.0819 - val_dense_2_loss: 0.0000e+00 - val_loss: 0.0646 - val_msle: 3.7322 - val_rmsle: 0.0603 - learning_rate: 6.2500e-05
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Pred Min: 1.0
# Pred Max: 308.333740234375
# Fold 2 RMSLE: 0.060431801431774304
# Running Fold: 3
# Epoch 1/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - dense_3_loss: 0.0000e+00 - loss: 2.1764 - msle: 93.9390 - rmsle: 1.9889 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.5560 - val_msle: 53.0702 - val_rmsle: 0.4779 - learning_rate: 5.0000e-04
# Epoch 2/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_3_loss: 0.0000e+00 - loss: 0.2977 - msle: 28.8085 - rmsle: 0.2387 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.1396 - val_msle: 12.7404 - val_rmsle: 0.1119 - learning_rate: 5.0000e-04
# Epoch 3/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1377 - msle: 8.8944 - rmsle: 0.1140 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0925 - val_msle: 6.4997 - val_rmsle: 0.0763 - learning_rate: 5.0000e-04
# Epoch 4/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1226 - msle: 8.6417 - rmsle: 0.1075 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0846 - val_msle: 5.8476 - val_rmsle: 0.0715 - learning_rate: 5.0000e-04
# Epoch 5/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1166 - msle: 8.4744 - rmsle: 0.1041 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0813 - val_msle: 4.4664 - val_rmsle: 0.0698 - learning_rate: 5.0000e-04
# Epoch 6/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1128 - msle: 8.3729 - rmsle: 0.1017 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0773 - val_msle: 4.8473 - val_rmsle: 0.0663 - learning_rate: 5.0000e-04
# Epoch 7/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1113 - msle: 8.2770 - rmsle: 0.1005 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0758 - val_msle: 4.2105 - val_rmsle: 0.0652 - learning_rate: 5.0000e-04
# Epoch 8/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1094 - msle: 8.2720 - rmsle: 0.0990 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0750 - val_msle: 4.2046 - val_rmsle: 0.0646 - learning_rate: 5.0000e-04
# Epoch 9/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1083 - msle: 8.2090 - rmsle: 0.0982 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0735 - val_msle: 3.9712 - val_rmsle: 0.0634 - learning_rate: 5.0000e-04
# Epoch 10/31
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - dense_3_loss: 0.0000e+00 - loss: 0.1074 - msle: 8.1373 - rmsle: 0.0975 - val_dense_3_loss: 0.0000e+00 - val_loss: 0.0739 - val_msle: 4.2087 - val_rmsle: 0.0638 - learning_rate: 5.0000e-04
# Epoch 11/31

# %%
cat_params

# %% [markdown]
#   1. Trial 12 finished with value: 0.06098324994799433 and parameters: {'units': 512, 'activation': 'silu', 'reg': 0.00013657286748469812, 'do_rate': 0.38, 'hidden_layers': 2}

# %% [markdown]
# #### 2.2.2 Train Model:

# %%
param = {'units': 512, 'activation': 'silu', 'reg': 0.0001004170129215336, 'do_rate': 0.41356627172269655, 'hidden_layers': 3}

# %%
TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, test_finc_target=y_test_fic, X_original=None, y_original=None, model_=wide_deep, parameters=param)

# %%
TM.fit_model(name="NN_widedeep_01_v1")

# %% [markdown]
# #### 2.2.3 Store Results:

# %%
name_experiment = "NN_widedeep_01_v3"

train_pred = TM.OOF_train
test_pred = TM.OOF_test
train_pred = pd.DataFrame(data = train_pred, columns = [f"{name_experiment}"])

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

sub["Calories"] =  test_pred.values

# %%
test_pred.min(), test_pred.max()

# %%
test_pred.head()

# %%
sub.head()

# %%
train_pred.head()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# ### **2.3.0 NeuralNetwork: Wide and Deep Model v1**
#
# This version of the model includes a Cross Layers within the Wide Branch of the NN.

# %%
data.X.sample(3)

# %%
data.X.max(axis=0)

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(data.X.Age_Group, bins=31)
ax[1].hist(data.X_test.Age_Group, bins=31, color="salmon")

plt.show()

# %%
cat_features = data.cat_features
num_features = data.num_features

cat_features_card = [2,2,8]
cat_features_out = [2, 2, 4]


print(cat_features,cat_features_card)
print(num_features)

# %%
def wide_deep_cross(units=512, activation="relu", do_rate=0.25, reg=0.001, hidden_layers=3, num_cross_layers=2):
    '''
    In this model embedding is performed for the data feeding into both the Deep and and wide layers:
    '''

    x_input_cats = layers.Input(shape=(len(cat_features),))
    embs = []
    for j in range(len(cat_features)):
        e = layers.Embedding(cat_features_card[j], cat_features_out[j]) #np.ceil(np.sqrt(cat_features_card[1]))
        x = e(x_input_cats[:,j])
        x = layers.Flatten()(x)
        embs.append(x)

    x_input_nums = layers.Input(shape=(len(num_features),))

    x = layers.Concatenate(axis=-1)(embs+[x_input_nums])

    deep = x
    wide = x  # Both Branches start with the concatenated features

    # Wide Branch with Cross Layers:
    for _ in range(num_cross_layers):
        xl = layers.Dense(units=x.shape[-1],  # Output dimension same as input
                         kernel_initializer='glorot_uniform',
                         bias_initializer='zeros',
                         activation=None)(wide)  # Linear activation
        # Cross Layer Calculation:
        cross = layers.Multiply()([x, xl])  # Element-wise multiplication
        # Concatenate instead of Add:
        wide = layers.Concatenate(axis=-1)([wide, cross])

    # Deep Branch:
    for lay in range(hidden_layers):
        deep = layers.Dense(units,kernel_regularizer=keras.regularizers.l2(reg), name=f"dense_deep_{lay}")(deep)
        deep = layers.BatchNormalization(name=f"bn_deep_{lay}")(deep)
        if activation == "relu":
            deep = layers.ReLU(name=f"relu_deep_{lay}")(deep)
        elif activation == "prelu":
            deep = layers.PReLU(name=f"prelu_deep_{lay}")(deep)
        elif activation == "gelu ":
            deep = activations.gelu(deep)
        elif activation == "silu":
            deep = activations.silu(deep)
        elif activation == "mish":
            deep = layers.Lambda(lambda x: keras.activations.mish(x), name=f"mish_deep_{lay}")(deep)
        elif activation == "celu":
            deep = activations.celu(deep)

        deep = layers.Dropout(do_rate, name=f"do_deep_{lay}")(deep)

    merged = layers.concatenate([wide, deep])

    x_final = layers.Dense(1, activation='linear')(merged)

    model = keras.Model(inputs=[x_input_cats,x_input_nums], outputs=x_final)
    return model

# %%
mod_test = wide_deep_cross(units=512, activation="celu")
mod_test.summary()

# %%
#keras.utils.plot_model(mod_test, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### 2.3.1 Optuna Optimization:

# %%
X_fin = data.X
X_test_fin = data.X_test

X_train_cat = data.X[cat_features]
X_train_num = data.X[num_features]

X_test_cat = data.X_test[cat_features]
X_test_num = data.X_test[num_features]

X_train_cat.info()
X_train_num.info()

y_fin = data.y

# %%
y_fin.isna().sum()

# %% [markdown]
# **OPTIMIZATION SECTION**

# %%
def objective_nn(trial, X, y, n_splits, n_repeats, model=wide_deep_cross, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold"):

    model_class = model

    categorical_features = cat_features.copy()

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
              'units': trial.suggest_categorical('units', [128,256,512,1024]),
              'num_cross_layers': trial.suggest_int('num_cross_layers', 1, 3),
              'activation': trial.suggest_categorical('activation', ["relu","prelu","silu"]),
              'reg': trial.suggest_float('reg', 1e-4, 0.01, log=True),
              'do_rate': trial.suggest_float('do_rate', 0.25, 0.45),
              'hidden_layers': trial.suggest_int('hidden_layers', 1,3)
              }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmsle_scores = []

    keras.backend.clear_session()

    iteration_n=0

    for idx_train, idx_valid in kf.split(X, y):
        print(f"Running Fold: {iteration_n}")
        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy()#.reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy()#.reshape(-1, 1)

        X_train_cat = X_train[cat_features]
        X_train_num = X_train[num_features]

        X_valid_cat = X_valid[cat_features]
        X_valid_num = X_valid[num_features]

        # Create the model
        keras.utils.set_random_seed(rs)
        model = model_class(**params)

        optimizer = keras.optimizers.Adam(learning_rate=5e-4)
        model.compile(optimizer=optimizer,
                      loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                      metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

        checkpoint_filepath = '/tmp/ckpt/checkpoint_dwc.weights.h5'
        model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_rmsle',
            mode='min',
            save_best_only=True)

        # Fit the model
        model.fit([X_train_cat,X_train_num], y_train,
                  validation_data=([X_valid_cat, X_valid_num], y_valid),
                  epochs=31,
                  batch_size=1024,
                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor="val_rmsle",
                                                            start_from_epoch=3, mode="min"),
                             model_checkpoint_callback])

        model.load_weights(checkpoint_filepath)

        # Make predictions on the validation set
        y_pred = model.predict([X_valid_cat, X_valid_num], batch_size=1024)
        y_pred = np.maximum(y_pred, 1.0)
        y_pred = np.minimum(y_pred, 315.0)

        print("Pred Min: {}".format(y_pred.min()))
        print("Pred Max: {}".format(y_pred.max()))

        # Calculate the RMSE for the current fold
        rmsle_score = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Fold {iteration_n} RMSLE: {rmsle_score}")

        rmsle_scores.append(rmsle_score)
        iteration_n+=1

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmsle_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))
    study.optimize(lambda trial: objective_nn(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
X_fin.isna().sum(), y_fin.min()

# %% [markdown]
#   1. Trial 1 finished with value: 0.061372210432322494 and parameters: {'units': 512, 'num_cross_layers': 1, 'activation': 'relu', 'reg': 0.0007600657726479304, 'do_rate': 0.4197061058874465, 'hidden_layers': 2}.
#
#   2. Trial 6 finished with value: 0.061261933879490194 and parameters: {'units': 256, 'num_cross_layers': 1, 'activation': 'silu', 'reg': 0.0001002990796038959, 'do_rate': 0.39009941717483704, 'hidden_layers': 2}. Best
#
#   3.  Trial

# %%
nn3_study = tune_hyperparameters(X_fin, y_fin, model_class=wide_deep_cross, n_trials=37, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)

cat_params = nn3_study.best_params

# %%
cat_params

# %% [markdown]
# #### 2.1.2 Train Model:

# %%
param = {'units': 512, 'num_cross_layers': 3, 'activation': 'prelu', 'reg': 0.0001360583533261253, 'do_rate': 0.3763917280440354,  'hidden_layers': 2}

# %%
TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, test_finc_target=y_test_fic, X_original=None, y_original=None, model_=wide_deep_cross, parameters=param)

# %%
TM.fit_model(name="NN_widedeepcross_00")

# %% [markdown]
# #### 2.1.3 Store Results:

# %%
name_experiment = "NN_widedeepcross_00"

train_pred = TM.OOF_train
test_pred = TM.OOF_test
train_pred = pd.DataFrame(data = train_pred, columns = [f"{name_experiment}"])

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

sub["Calories"] =  test_pred.values

# %%
test_pred.min(), test_pred.max()

# %%
test_pred.head()

# %%
sub.head()

# %%
train_pred.head()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# ### **2.3.0 NeuralNetwork: TabTransformer Model v0**
#
# This version of the model includes a Cross Layers within the Wide Branch of the NN.

# %%
from functools import partial

class CFG:
    SEED    = 333
    CV      = KFold(n_splits=11, shuffle=True, random_state=SEED)
    VERSION = '1'

class TrainModels:
    def __init__(self, X, y, X_test, test_finc_target, X_original, y_original, model_, parameters):
        self.model     = model_
        self.parameters = parameters
        self.X          = X
        self.y          = y
        self.test_finc_target = test_finc_target
        self.X_test     = X_test
        self._OOF_train = pd.DataFrame()
        self._OOF_test  = pd.DataFrame()
        self.categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
        self.numerical_features = X.select_dtypes(exclude=['category', 'bool', 'category','int']).columns.to_list()

    def fit_model(self, name="Base_model"):
        oof_train = np.zeros(self.X.shape[0])
        oof_test  = np.zeros(self.X_test.shape[0])
        scores_train = []
        scores_val   = []

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/layers_3_staked_models')

        train_start = 7

        for fold, (train_idx, val_idx) in enumerate(CFG.CV.split(self.X, self.y)):
            x_train, y_train = self.X.iloc[train_idx], self.y.iloc[train_idx]
            x_val,   y_val   = self.X.iloc[val_idx],   self.y.iloc[val_idx]


            train_ds = dataframe_to_dataset(x_train, y_train, self.categorical_features, self.numerical_features, shuffle=True, batch_size=1024)
            val_ds = dataframe_to_dataset(x_val, y_val, self.categorical_features, self.numerical_features, shuffle=False, batch_size=1024)
            test_ds = dataframe_to_dataset_test(self.X_test, self.test_finc_target, self.categorical_features, self.numerical_features, batch_size=1024)

            model = self.model(**self.parameters)

            optimizer = keras.optimizers.Adam(learning_rate=1e-3)
            model.compile(optimizer=optimizer,
                          loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                          metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

            checkpoint_filepath = '/tmp/ckpt/checkpoint.weights.h5'
            model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
                                                                        filepath=checkpoint_filepath,
                                                                        save_weights_only=True,
                                                                        monitor='val_rmsle',
                                                                        mode='min',
                                                                        save_best_only=True
                                                                        )
            if fold > train_start:
              # Fit the model
              history = model.fit(train_ds,
                                  validation_data=val_ds,
                                  epochs=151,
                                  batch_size=1024,
                                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                                            keras.callbacks.EarlyStopping(patience=21, restore_best_weights=True, monitor="val_rmsle",
                                                                            start_from_epoch=3, mode="min"),
                                              model_checkpoint_callback])

              model.load_weights(checkpoint_filepath)
              model.save(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/keras_models/{name}_{fold}.keras")
              plot_training_session(history)

            else:
              model = tf.keras.models.load_model(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/keras_models/{name}_{fold}.keras",
                                                custom_objects={'rmsle': rmsle})

            model.evaluate(val_ds, verbose=0)

            # Make predictions
            y_pred_train = model.predict(train_ds)
            y_pred_val   = model.predict(val_ds)
            y_pred_test  = model.predict(test_ds)

            # Correct Ranges:

            y_pred_train = np.maximum(y_pred_train, 1.0)
            y_pred_train = np.minimum(y_pred_train, 315.0)

            y_pred_val = np.maximum(y_pred_val, 1.0)
            y_pred_val = np.minimum(y_pred_val, 315.0)

            y_pred_test = np.maximum(y_pred_test, 1.0)
            y_pred_test = np.minimum(y_pred_test, 315.0)

            # Store Results
            oof_train[val_idx] = y_pred_val.reshape(-1)
            oof_test   += (y_pred_test/CFG.CV.get_n_splits()).reshape(-1)

            train_score = root_mean_squared_log_error(y_train, y_pred_train)
            val_score   = root_mean_squared_log_error(y_val, y_pred_val)

            print(f'Fold {fold+1} → Training set Score: {train_score:.5f} | Validation set Score: {val_score:.5f}')

            scores_train.append(train_score)
            scores_val.append(val_score)

        self._OOF_train[name] = oof_train
        self._OOF_test[name]  = oof_test

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5')

        print(colored(f'Overall → Training set Score: {np.mean(scores_train):.5f}±{np.std(scores_train):.7f} | Validation set Score: {np.mean(scores_val):.5f}±{np.std(scores_val):.7f}',
              color='green', attrs=['bold', 'dark']))

    @property
    def OOF_train(self):
        return self._OOF_train
    @property
    def OOF_test(self):
        return self._OOF_test

    def save_predictions(self):
        self._OOF_train.to_csv('OOF_train_many_models.csv', index=False)
        self._OOF_test.to_csv('OOF_test_many_models.csv', index=False)

# %%
data.X.sample(3)

# %%
data.X.max(axis=0)

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(data.X.Body_Temp, bins=31)
ax[1].hist(data.X_test.Body_Temp, bins=31, color="salmon")

plt.show()

# %%
cat_features = data.cat_features
num_features = data.num_features

cat_features_card = [2,2,8]
cat_features_out = [2, 2, 4]


print(cat_features,cat_features_card)
print(num_features)

# %%
def create_mlp(hidden_units, dropout_rate, activation, normalization_layer, name=None):
    mlp_layers = []
    for units in hidden_units:
        mlp_layers.append(normalization_layer())
        mlp_layers.append(layers.Dense(units, activation=activation))
        mlp_layers.append(layers.Dropout(dropout_rate))

    return keras.Sequential(mlp_layers, name=name)

# %%
[4]*2+[2]

# %%
def tabtransformer(do_rate=0.25, num_cross_layers=2, embedding_dims=4, num_transformer_blocks=3, num_heads=8, mlp_hidden_units_factors=[4]*2+[2]):
    '''
    In this model embedding is performed for the data feeding into both the Deep and and wide layers:
    '''

    x_input_cats = layers.Input(shape=(len(cat_features),))
    x_input_nums = layers.Input(shape=(len(num_features),))



    # Embedding Cat Features
    embs = []
    for j in range(len(cat_features)):
        e = layers.Embedding(cat_features_card[j], embedding_dims) #np.ceil(np.sqrt(cat_features_card[1]))
        x = e(x_input_cats[:,j])
        embs.append(x)

    encoded_categorical_features = ops.stack(embs, axis=1)


    # Create multiple layers of the Transformer block.
    for block_idx in range(num_transformer_blocks):
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embedding_dims,
            dropout=do_rate,
            name=f"multihead_attention_{block_idx}",
        )(encoded_categorical_features, encoded_categorical_features)
        # Skip connection 1.
        x = layers.Add(name=f"skip_connection1_{block_idx}")(
            [attention_output, encoded_categorical_features]
        )
        # Layer normalization 1.
        x = layers.LayerNormalization(name=f"layer_norm1_{block_idx}", epsilon=1e-6)(x)
        # Feedforward.
        feedforward_output = create_mlp(
            hidden_units=[embedding_dims],
            dropout_rate=do_rate,
            activation=keras.activations.gelu,
            normalization_layer=partial(layers.LayerNormalization, epsilon=1e-6),  # using partial to provide keyword arguments before initialization
            name=f"feedforward_{block_idx}",
        )(x)
        # Skip connection 2.
        x = layers.Add(name=f"skip_connection2_{block_idx}")([feedforward_output, x])
        # Layer normalization 2.
        encoded_categorical_features = layers.LayerNormalization(
            name=f"layer_norm2_{block_idx}", epsilon=1e-6
        )(x)

    # Flatten the "contextualized" embeddings of the categorical features.
    categorical_features = layers.Flatten()(encoded_categorical_features)
    # Apply layer normalization to the numerical features.
    numerical_features = layers.LayerNormalization(epsilon=1e-6)(x_input_nums)
    # Prepare the input for the final MLP block.
    features = layers.concatenate([categorical_features, numerical_features], name="concatenate_att_output")

    # Compute MLP hidden_units.
    mlp_hidden_units = [factor * features.shape[-1] for factor in mlp_hidden_units_factors]
    # Create final MLP.
    features = create_mlp(
                          hidden_units=mlp_hidden_units,
                          dropout_rate=do_rate,
                          activation=keras.activations.silu,
                          normalization_layer=layers.BatchNormalization,
                          name="MLP_post_attention",
                         )(features)

    # WIDE Branch of the NN
    embs_cross = []

    for j in embs:
        embs_cross.append(layers.Flatten()(j))

#    embs_cross = layers.Flatten()(embs)
    x1 = layers.Concatenate(axis=-1)(embs_cross+[x_input_nums])

    wide = x1  # Both Branches start with the concatenated features

    # Wide Branch with Cross Layers:
    for _ in range(num_cross_layers):
        xl = layers.Dense(units=x1.shape[-1],  # Output dimension same as input
                         kernel_initializer='glorot_uniform',
                         bias_initializer='zeros',
                         activation=None)(wide)  # Linear activation
        # Cross Layer Calculation:
        cross = layers.Multiply()([x1, xl])  # Element-wise multiplication
        # Concatenate instead of Add:
        wide = layers.Concatenate(axis=-1)([wide, cross])


    merged = layers.concatenate([wide, features])

    x_final = layers.Dense(1, activation='linear')(merged)

    model = keras.Model(inputs=[x_input_cats,x_input_nums], outputs=x_final)
    return model

# %%
mod_test = tabtransformer()
mod_test.summary()

# %%
#keras.utils.plot_model(mod_test, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### 2.3.1 Optuna Optimization:

# %%
X_fin = data.X
X_test_fin = data.X_test

X_train_cat = data.X[cat_features]
X_train_num = data.X[num_features]

X_test_cat = data.X_test[cat_features]
X_test_num = data.X_test[num_features]

X_train_cat.info()
X_train_num.info()

y_fin = data.y

# %%
y_fin.isna().sum()

# %% [markdown]
# **OPTIMIZATION SECTION**

# %% [markdown]
#   1. Trial 3 finished with value: 0.06128411016249404 and parameters: {'num_cross_layers': 3, 'do_rate': 0.34650500123999023, 'embedding_dims': 4, 'num_transformer_blocks': 3, 'num_heads': 4, 'mlp_hidden_units_factors_0': 2, 'mlp_hidden_units_factors_1': 3, 'mlp_hidden_units_factors_2': 2}
#
#   2. rial 22 finished with value: 0.06113841138214773 and parameters: {'num_cross_layers': 3, 'do_rate': 0.3631276829855239, 'embedding_dims': 4, 'num_transformer_blocks': 3, 'num_heads': 12, 'mlp_hidden_units_factors_0': 2, 'mlp_hidden_units_factors_1': 3, 'mlp_hidden_units_factors_2': 1}.
#
#   3. Trial 7 finished with value: 0.060843740984653075 and parameters: {'do_rate': 0.32, 'num_transformer_blocks': 3, 'num_heads': 12, 'mlp_hidden_units_factors_0': 3, 'mlp_hidden_units_factors_1': 2, 'mlp_hidden_units_factors_2': 1}

# %%
def objective_nn(trial, X, y, n_splits, n_repeats, model=tabtransformer, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold"):

#(num_transformer_blocks=3, num_heads=8, mlp_hidden_units_factors=[4]*2+[2])

    model_class = model

    categorical_features = cat_features.copy()

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
              'num_cross_layers': 3, #trial.suggest_int('num_cross_layers', 1, 3),
              'do_rate': trial.suggest_float('do_rate', 0.30, 0.40, step=0.01),
              'embedding_dims': 4, #trial.suggest_categorical('embedding_dims', [4, 8]),
              'num_transformer_blocks': trial.suggest_categorical('num_transformer_blocks', [3, 4]),
              'num_heads': trial.suggest_categorical('num_heads', [4, 8, 12]),
              'mlp_hidden_units_factors_0' : trial.suggest_categorical('mlp_hidden_units_factors_0', [2, 3]),
              'mlp_hidden_units_factors_1' : trial.suggest_categorical('mlp_hidden_units_factors_1', [2, 3]),
              'mlp_hidden_units_factors_2' : trial.suggest_categorical('mlp_hidden_units_factors_2', [1, 2]),
              }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmsle_scores = []

    keras.backend.clear_session()

    iteration_n=0

    for idx_train, idx_valid in kf.split(X, y):
        print(f"Running Fold: {iteration_n}")
        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy()#.reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy()#.reshape(-1, 1)

        X_train_cat = X_train[cat_features]
        X_train_num = X_train[num_features]

        X_valid_cat = X_valid[cat_features]
        X_valid_num = X_valid[num_features]

        # Create the model
        keras.utils.set_random_seed(rs)
        model = model_class(do_rate=params["do_rate"], num_cross_layers=params["num_cross_layers"], embedding_dims=params["embedding_dims"], num_transformer_blocks=params["num_transformer_blocks"],
                            num_heads=params["num_heads"], mlp_hidden_units_factors=[params["mlp_hidden_units_factors_0"]]*params["mlp_hidden_units_factors_1"]+[params["mlp_hidden_units_factors_2"]])

        optimizer = keras.optimizers.Adam(learning_rate=1e-3)
        model.compile(optimizer=optimizer,
                      loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                      metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

        checkpoint_filepath = '/tmp/ckpt/checkpoint_dwc.weights.h5'
        model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_rmsle',
            mode='min',
            save_best_only=True)

        # Fit the model
        model.fit([X_train_cat,X_train_num], y_train,
                  validation_data=([X_valid_cat, X_valid_num], y_valid),
                  epochs=31,
                  batch_size=1024,
                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor="val_rmsle",
                                                            start_from_epoch=3, mode="min"),
                             model_checkpoint_callback])

        model.load_weights(checkpoint_filepath)

        # Make predictions on the validation set
        y_pred = model.predict([X_valid_cat, X_valid_num], batch_size=1024)
        y_pred = np.maximum(y_pred, 1.0)
        y_pred = np.minimum(y_pred, 315.0)

        print("Pred Min: {}".format(y_pred.min()))
        print("Pred Max: {}".format(y_pred.max()))

        # Calculate the RMSE for the current fold
        rmsle_score = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Fold {iteration_n} RMSLE: {rmsle_score}")

        rmsle_scores.append(rmsle_score)
        iteration_n+=1

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmsle_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))
    study.optimize(lambda trial: objective_nn(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
X_fin.isna().sum(), y_fin.min()

# %%
nn3_study = tune_hyperparameters(X_fin, y_fin, model_class=tabtransformer, n_trials=27, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)

cat_params = nn3_study.best_params

# %%
cat_params

# %% [markdown]
# #### 2.1.2 Train Model:

# %%
param =  {'do_rate': 0.32, 'num_transformer_blocks': 3, 'num_heads': 12, 'mlp_hidden_units_factors': [3,3,1]}

# %%
TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, test_finc_target=y_test_fic, X_original=None, y_original=None, model_=tabtransformer, parameters=param)

# %%
TM.fit_model(name="NN_TabTransformer_00")

# %% [markdown]
# #### 2.1.3 Store Results:

# %%
name_experiment = "NN_TabTransformer_00"

train_pred = TM.OOF_train
test_pred = TM.OOF_test
train_pred = pd.DataFrame(data = train_pred, columns = [f"{name_experiment}"])

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

sub["Calories"] =  test_pred.values

# %%
test_pred.min(), test_pred.max()

# %%
test_pred.head()

# %%
sub.head()

# %%
train_pred.head()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# ### **2.3.0 NeuralNetwork: Wide and Deep Model v2**
#
# This version of the model includes a Cross Layers within the Wide Branch of the NN.

# %%
data.X.sample(3)

# %%
data.X.max(axis=0)

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(data.X.Age_Group, bins=31)
ax[1].hist(data.X_test.Age_Group, bins=31, color="salmon")

plt.show()

# %%
cat_features = data.cat_features
num_features = data.num_features

cat_features_card = [2,2,8]
cat_features_out = [2, 2, 4]


print(cat_features,cat_features_card)
print(num_features)

# %%
def wide_deep_cross(units=512, activation="relu", do_rate=0.25, reg=0.001, hidden_layers=3, num_cross_layers=2):
    '''
    In this model embedding is performed for the data feeding into both the Deep and and wide layers:
    '''

    x_input_cats = layers.Input(shape=(len(cat_features),))
    embs = []
    for j in range(len(cat_features)):
        e = layers.Embedding(cat_features_card[j], cat_features_out[j]) #np.ceil(np.sqrt(cat_features_card[1]))
        x = e(x_input_cats[:,j])
        x = layers.Flatten()(x)
        embs.append(x)

    x_input_nums = layers.Input(shape=(len(num_features),))

    x = layers.Concatenate(axis=-1)(embs+[x_input_nums])

    deep = x
    wide = x  # Both Branches start with the concatenated features

    # Wide Branch with Cross Layers:
    for _ in range(num_cross_layers):
        xl = layers.Dense(units=x.shape[-1],  # Output dimension same as input
                         kernel_initializer='glorot_uniform',
                         bias_initializer='zeros',
                         activation=None)(wide)  # Linear activation
        # Cross Layer Calculation:
        cross = layers.Multiply()([x, xl])  # Element-wise multiplication
        # Concatenate instead of Add:
        wide = layers.Concatenate(axis=-1)([wide, cross])

    # Deep Branch:
    for lay in range(hidden_layers):
        deep = layers.Dense(units,kernel_regularizer=keras.regularizers.l2(reg), name=f"dense_deep_{lay}")(deep)
        deep = layers.BatchNormalization(name=f"bn_deep_{lay}")(deep)
        if activation == "relu":
            deep = layers.ReLU(name=f"relu_deep_{lay}")(deep)
        elif activation == "prelu":
            deep = layers.PReLU(name=f"prelu_deep_{lay}")(deep)
        elif activation == "gelu ":
            deep = activations.gelu(deep)
        elif activation == "silu":
            deep = activations.silu(deep)
        elif activation == "mish":
            deep = layers.Lambda(lambda x: keras.activations.mish(x), name=f"mish_deep_{lay}")(deep)
        elif activation == "celu":
            deep = activations.celu(deep)

        deep = layers.Dropout(do_rate, name=f"do_deep_{lay}")(deep)

    merged = layers.concatenate([wide, deep])

    x_final = layers.Dense(1, activation='linear')(merged)

    model = keras.Model(inputs=[x_input_cats,x_input_nums], outputs=x_final)
    return model

# %%
mod_test = wide_deep_cross(units=512, activation="celu")
mod_test.summary()

# %%
#keras.utils.plot_model(mod_test, show_shapes=True, rankdir="LR")

# %% [markdown]
# #### 2.3.1 Optuna Optimization:

# %%
X_fin = data.X
X_test_fin = data.X_test

X_train_cat = data.X[cat_features]
X_train_num = data.X[num_features]

X_test_cat = data.X_test[cat_features]
X_test_num = data.X_test[num_features]

X_train_cat.info()
X_train_num.info()

y_fin = data.y

# %%
y_fin.isna().sum()

# %% [markdown]
# **OPTIMIZATION SECTION**

# %%
def objective_nn(trial, X, y, n_splits, n_repeats, model=wide_deep_cross, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold"):

    model_class = model

    categorical_features = cat_features.copy()

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
              'units': trial.suggest_categorical('units', [128,256,512,1024]),
              'num_cross_layers': trial.suggest_int('num_cross_layers', 1, 3),
              'activation': trial.suggest_categorical('activation', ["relu","prelu","silu"]),
              'reg': trial.suggest_float('reg', 1e-4, 0.01, log=True),
              'do_rate': trial.suggest_float('do_rate', 0.25, 0.45),
              'hidden_layers': trial.suggest_int('hidden_layers', 1,3)
              }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmsle_scores = []

    keras.backend.clear_session()

    iteration_n=0

    for idx_train, idx_valid in kf.split(X, y):
        print(f"Running Fold: {iteration_n}")
        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy()#.reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy()#.reshape(-1, 1)

        X_train_cat = X_train[cat_features]
        X_train_num = X_train[num_features]

        X_valid_cat = X_valid[cat_features]
        X_valid_num = X_valid[num_features]

        # Create the model
        keras.utils.set_random_seed(rs)
        model = model_class(**params)

        optimizer = keras.optimizers.Adam(learning_rate=5e-4)
        model.compile(optimizer=optimizer,
                      loss=[rmsle, keras.losses.MeanSquaredLogarithmicError(name="msle")],
                      metrics=[rmsle, keras.metrics.RootMeanSquaredError(name="msle")])

        checkpoint_filepath = '/tmp/ckpt/checkpoint_dwc.weights.h5'
        model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_rmsle',
            mode='min',
            save_best_only=True)

        # Fit the model
        model.fit([X_train_cat,X_train_num], y_train,
                  validation_data=([X_valid_cat, X_valid_num], y_valid),
                  epochs=31,
                  batch_size=1024,
                  callbacks=[keras.callbacks.ReduceLROnPlateau(patience=3, factor = 0.5, min_lr=1e-6),
                            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor="val_rmsle",
                                                            start_from_epoch=3, mode="min"),
                             model_checkpoint_callback])

        model.load_weights(checkpoint_filepath)

        # Make predictions on the validation set
        y_pred = model.predict([X_valid_cat, X_valid_num], batch_size=1024)
        y_pred = np.maximum(y_pred, 1.0)
        y_pred = np.minimum(y_pred, 315.0)

        print("Pred Min: {}".format(y_pred.min()))
        print("Pred Max: {}".format(y_pred.max()))

        # Calculate the RMSE for the current fold
        rmsle_score = root_mean_squared_log_error(y_valid, y_pred)
        print(f"Fold {iteration_n} RMSLE: {rmsle_score}")

        rmsle_scores.append(rmsle_score)
        iteration_n+=1

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmsle_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))
    study.optimize(lambda trial: objective_nn(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
X_fin.isna().sum(), y_fin.min()

# %% [markdown]
#   1. Trial 1 finished with value: 0.061372210432322494 and parameters: {'units': 512, 'num_cross_layers': 1, 'activation': 'relu', 'reg': 0.0007600657726479304, 'do_rate': 0.4197061058874465, 'hidden_layers': 2}.
#
#   2. Trial 6 finished with value: 0.061261933879490194 and parameters: {'units': 256, 'num_cross_layers': 1, 'activation': 'silu', 'reg': 0.0001002990796038959, 'do_rate': 0.39009941717483704, 'hidden_layers': 2}. Best
#
#   3.  Trial

# %%
nn3_study = tune_hyperparameters(X_fin, y_fin, model_class=wide_deep_cross, n_trials=37, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)

cat_params = nn3_study.best_params

# %%
cat_params

# %% [markdown]
# #### 2.1.2 Train Model:

# %%
param = {'units': 512, 'num_cross_layers': 3, 'activation': 'prelu', 'reg': 0.0001360583533261253, 'do_rate': 0.3763917280440354,  'hidden_layers': 2}

# %%
TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, test_finc_target=y_test_fic, X_original=None, y_original=None, model_=wide_deep_cross, parameters=param)

# %%
TM.fit_model(name="NN_widedeepcross_00")

# %% [markdown]
# #### 2.1.3 Store Results:

# %%
name_experiment = "NN_widedeepcross_00"

train_pred = TM.OOF_train
test_pred = TM.OOF_test
train_pred = pd.DataFrame(data = train_pred, columns = [f"{name_experiment}"])

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

sub["Calories"] =  test_pred.values

# %%
test_pred.min(), test_pred.max()

# %%
test_pred.head()

# %%
sub.head()

# %%
train_pred.head()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# # **3.0 TREE BASED MODELS**

# %%
# from sklearn.utils.class_weight import compute_class_weight

# class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y)
# class_weights = dict(enumerate(class_weights))

# sample_pos_weight = class_weights[1]/class_weights[0]
# sample_pos_weight

# %%
class TrainModels:
    def __init__(self, X, y, X_test, X_original, y_original, models):
        self.models     = models
        self.X          = X
        self.y          = y
        self.X_original = X_original
        self.y_original = y_original
        self.X_test     = X_test
        self._OOF_train = pd.DataFrame()
        self._OOF_test  = pd.DataFrame()
        self.categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()

    @staticmethod
    def convert_cat(df_):
        '''
        A function to convert dtypes to categorical if the catboost with all categorical
        features is called
        '''
        df = df_.copy()
        for c in df.columns.to_list():
            df[c] = df[c].astype(str).astype('category')
        return df


    def fit_model(self, name, model_, train_flag):
        oof_train = np.zeros(self.X.shape[0])
        oof_test  = np.zeros(self.X_test.shape[0])
        scores_train = []
        scores_val   = []

        CB_CAT_FLAG = True if 'CB_CAT' in name.upper() else False

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/Catboost')

        for fold, (train_idx, val_idx) in enumerate(CFG.CV.split(self.X, self.y)):
            x_train, y_train = self.X.iloc[train_idx], self.y.iloc[train_idx]
            x_val,   y_val   = self.X.iloc[val_idx],   self.y.iloc[val_idx]

            # Adds the original data to training set only
            if self.X_original is not None:
                x_train = pd.concat([x_train, self.X_original], axis=0)
                y_train = pd.concat([y_train, self.y_original], axis=0)

            # -- Create a special block to convert all features to categorical
            if CB_CAT_FLAG:
                x_train = self.convert_cat(x_train)
                x_val   = self.convert_cat(x_val)

            model = clone(model_)

            if 'CB' in name.upper():
              if train_flag==True:
                model.fit(x_train,y_train,eval_set=[(x_val,y_val)], early_stopping_rounds=101)
                model.save_model(f"{name}_{fold}.bin")
              else:
                print("Load Model")
                model = CatBoostRegressor()
                model.load_model(f"{name}_{fold}.bin")

            elif 'LGBMR' in name.upper():
              early_stop = early_stopping(stopping_rounds=101)
              if train_flag==True:
                model.fit(x_train, y_train, eval_set=[(x_val, y_val)], callbacks=[early_stop],categorical_feature=self.categorical_features)
                model.booster_.save_model(f'{name}_{fold}.txt')
              else:
                print("Load Model")
                model = lgb.Booster(model_file=f'{name}_{fold}.txt')

            elif 'LGBMP' in name.upper():
              # Fit the model
              if train_flag==True:
                model.fit(x_train, y_train)
                joblib.dump(model, f'{name}_{fold}.pkl')
              else:
                print("Load Model")
                model = joblib.load(f'{name}_{fold}.pkl')

            elif 'XGBR' in name.upper():
              if train_flag==True:
                model.fit(x_train, y_train, eval_set=[(x_val, y_val)],verbose=250)
                model.save_model(f'{name}_{fold}.json')
              else:
                print("Load Model")
                model = XGBRegressor()  # Create an instance of the model
                model.load_model(f'{name}_{fold}.json')

            elif 'LGBM_2' in name.upper():
              model.fit(x_train, y_train, eval_set=[(x_val, y_val)])


            elif 'HGB_' in name.upper():
              if train_flag==True:
                model.fit(x_train, y_train)
                joblib.dump(model, f'{name}_{fold}.pkl')
              else:
                print("Load Model")
                model = joblib.load(f'{name}_{fold}.pkl')

            else:

              model.fit(x_train, y_train)

            y_pred_train = model.predict(x_train).ravel()
            y_pred_val   = model.predict(x_val).ravel()
            y_pred_test  = model.predict(self.X_test if not CB_CAT_FLAG else self.convert_cat(self.X_test)).ravel()

            y_pred_train = np.expm1(y_pred_train)
            y_pred_val   = np.expm1(y_pred_val)
            y_pred_test  = np.expm1(y_pred_test)

            # Correct Ranges:

            print("Pred Min&Max Valid: {} and {}".format(y_pred_val.min(), y_pred_val.max()))
            print("Pred Min&Max Test: {} and {}".format(y_pred_test.min(), y_pred_test.max()))

            y_pred_train = np.maximum(y_pred_train, 1.0)
            y_pred_train = np.minimum(y_pred_train, 315.0)

            y_pred_val = np.maximum(y_pred_val, 1.0)
            y_pred_val = np.minimum(y_pred_val, 315.0)

            y_pred_test = np.maximum(y_pred_test, 1.0)
            y_pred_test = np.minimum(y_pred_test, 315.0)

            print("Pred Min&Max Valid Adj: {} and {}".format(y_pred_val.min(), y_pred_val.max()))
            print("Pred Min&Max Test Adj: {} and {}".format(y_pred_test.min(), y_pred_test.max()))

            oof_train[val_idx] = y_pred_val
            oof_test   += y_pred_test/CFG.CV.get_n_splits()

            train_score = root_mean_squared_log_error(np.expm1(y_train), y_pred_train)
            val_score   = root_mean_squared_log_error(np.expm1(y_val), y_pred_val)

            print(f'Fold {fold+1} → Training set Score: {train_score:.5f} | Validation set Score: {val_score:.5f}')

            scores_train.append(train_score)
            scores_val.append(val_score)

        self._OOF_train[name] = oof_train
        self._OOF_test[name]  = oof_test

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5')

        print(colored(f'Overall → Training set Score: {np.mean(scores_train):.5f}±{np.std(scores_train):.7f} | Validation set Score: {np.mean(scores_val):.5f}±{np.std(scores_val):.7f}',
              color='green', attrs=['bold', 'dark']))

    def fit_models(self):
        for name, model in list(self.models.items()):
            print(colored(f'{" "*4} Fitting {name}', color='red', attrs=['dark', 'bold']))
            self.fit_model(name, model[0], model[1])
            print("")

    @property
    def OOF_train(self):
        return self._OOF_train
    @property
    def OOF_test(self):
        return self._OOF_test

    def save_predictions(self):
        self._OOF_train.to_csv('OOF_train_many_models.csv', index=False)
        self._OOF_test.to_csv('OOF_test_many_models.csv', index=False)

# %% [markdown]
# ## 3.1.0 CatBoostClassifier:

# %%
cat_prob = {"objective":"RMSE","eval_metric":"RMSE"}

# %%
X = data.X
y = np.log1p(data.y)
categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
categorical_features

# %% [markdown]
# ### 3.1.1 Optuna Optimization:

# %%
def objective_catboost(trial, X, y, n_splits, n_repeats, model=CatBoostRegressor, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold", metrics=cat_prob,categorical_features=categorical_features):

    model_class = model

    categorical_features = categorical_features

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
        'iterations': 2500,
        'learning_rate': 0.02, #trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'depth': trial.suggest_int('depth', 8, 13),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-2, 0.1, log=True),
        "bootstrap_type": "Bernoulli", #trial.suggest_categorical("bootstrap_type",["Bayesian","Bernoulli"]),
        'random_strength': trial.suggest_float('random_strength', 0.5, 3.5, step=0.25),
        'border_count': trial.suggest_int('border_count', 190, 260, step=5),
        'cat_features': categorical_features,
        'task_type': 'GPU' if use_gpu else 'CPU',
        'random_seed':rs,
        'verbose': 250,
        'objective': metrics["objective"],
        'eval_metric': metrics["eval_metric"],
        "od_type":'EBS', #Early stopping hyperparmeter
        "od_wait":101,
        #"sampling_frequency":"PerTreeLevel",
        "use_best_model":True,
    }

    if params["bootstrap_type"] == "Bayesian":
        params["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0.5, 1.5, step=0.1)
    elif params["bootstrap_type"] == "Bernoulli":
        params["subsample"] = trial.suggest_float("subsample", 0.70, 1.0, step=0.025)

    if cv_strategy == 'RepKFold':
      kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
      kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
      kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
      kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmse_scores = []

    for idx_train, idx_valid in kf.split(X, y):

        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

        if fit_scaling:
          scaler = StandardScaler()
          X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
          X_valid[num_cols] = scaler.transform(X_valid[num_cols])

        # Create the Pool objects for CatBoost
        train_pool = Pool(data=X_train, label=y_train, cat_features=categorical_features)
        valid_pool = Pool(data=X_valid, label=y_valid, cat_features=categorical_features)

        # Create the pipeline
        model = model_class(**params)
        # Fit the model:
        model.fit(train_pool, eval_set=valid_pool, early_stopping_rounds=101,
                  #callbacks=[optuna.integration.CatBoostPruningCallback(trial, "RMSE")]
                  )

        # Make predictions on the validation set
        y_pred = model.predict(X_valid)

#        y_pred = np.expm1(y_pred)
#        y_valid = np.expm1(y_valid)

        # Calculate the RMSE for the current fold

        rmse_score = root_mean_squared_error(y_valid, y_pred)
        rmse_scores.append(rmse_score)

        gc.collect()

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmse_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=50))
    study.optimize(lambda trial: objective_catboost(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")

# %%
# usage with XGBRegressor
cat_study = tune_hyperparameters(X, y, model_class=CatBoostRegressor, n_trials=31, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)
save_results(cat_study, CatBoostRegressor, "CatBoost_ext")

# %% [markdown]
#   1. Trial 5 finished with value: 0.06006516957759047 and parameters: {'depth': 11, 'l2_leaf_reg': 0.013463992344840664, 'bootstrap_type': 'Bernoulli', 'random_strength': 0.5, 'border_count': 215, 'subsample': 0.9750000000000001}

# %%
cat_params = cat_study.best_params
cat_params

# %% [markdown]
# ### 3.1.2 Train Model:

# %%
metrics = {"objective":"RMSE","eval_metric":"RMSE"}
categorical_features = data.X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()

# %%
X = data.X
y = np.log1p(data.y)
categorical_features

# %%
X_test = data.X_test

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

# %% [markdown]
# **FIT THE MODEL**

# %%
param = {'iterations': 2500, 'learning_rate': 0.02, 'depth': 11,
        'l2_leaf_reg': 0.013463992345, "bootstrap_type": "Bernoulli",
        'random_strength': 0.5, 'border_count': 215,
        'cat_features': categorical_features, 'task_type': 'GPU',
        'random_seed':42, 'verbose': 250,
        'objective': metrics["objective"],
        'eval_metric': metrics["eval_metric"],
        "od_type":'EBS', "od_wait":101,
        "use_best_model":True,
          }

cb_cat_params_4   = {'one_hot_max_size': 2, 'learning_rate': 0.055, 'grow_policy': 'Depthwise'}

models={'CB2':[CatBoostRegressor(**param),True]}

TM = TrainModels(X=X, y=y, X_test=X_test, X_original=None, y_original=None, models=models)
TM.fit_models()

# %% [markdown]
# ### 3.1.3 Store Results:

# %%
name_experiment = "CB_adj_values"

test_pred = TM.OOF_test.mean(axis=1) #np.expm1(TM.OOF_test.mean(axis=1))
train_pred = TM.OOF_train.mean(axis=1) #np.expm1(TM.OOF_train.mean(axis=1))

# %%
test_pred.min(), test_pred.max()

# %%
test_pred.head()

# %%
sub["Calories"] =  test_pred.values

sub.head()

# %%
train_pred.head()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# ## **3.2.0 LGBMRegressor**

# %%
import lightgbm as lgb
lgbm_prob = {"objective":"regression","eval_metric":"rmse"}

# %%
X = data.X
y = np.log1p(data.y)
categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
categorical_features
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %% [markdown]
# ### 3.2.1 Optuna Optimization:

# %%
def objective_lgbm(trial, X, y, n_splits=5, n_repeats=5, model=LGBMRegressor, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold", metrics=lgbm_prob, categorical_features=categorical_features):

    model_class = model

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
        'num_leaves': trial.suggest_int('num_leaves', 31, 111),
        'learning_rate': 0.02, #trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        #'max_depth': trial.suggest_int('max_depth', 5, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 60),
        'subsample': trial.suggest_float('subsample', 0.5, 0.95),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 3),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        "reg_alpha" :         trial.suggest_float("reg_alpha", 1e-3, 1.0, log=True),
        "reg_lambda" :        trial.suggest_float("reg_lambda", 1e-3, 1.0, log=True),
        "boosting_type":      'gbdt',
        'n_estimators': 2501,
        'objective': metrics["objective"],
        'device': 'gpu' if use_gpu else 'cpu',
        'verbose': -1,
#       'categorical_feature': [2,4,5,9],
        'random_state': rs,
    }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmse_scores = []

    for idx_train, idx_valid in kf.split(X, y):

        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1, 1)

        if fit_scaling:
            scaler = StandardScaler()
            X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
            X_valid[num_cols] = scaler.transform(X_valid[num_cols])

        # Create the datasets for LightGBM
        # d_train = lgb.Dataset(X_train, label=y_train, categorical_feature=categorical_features)
        # d_valid = lgb.Dataset(X_valid, label=y_valid, categorical_feature=categorical_features)

        # Create the model
        model = model_class(**params)

        # Create the early stopping callback
        early_stop = early_stopping(stopping_rounds=101)

        # Fit the model
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], callbacks=[early_stop], eval_metric=metrics["eval_metric"], categorical_feature= categorical_features)

        # Make predictions on the validation set
        y_pred = model.predict(X_valid)

        # Calculate the RMSE for the current fold

        rmse_score = root_mean_squared_error(y_valid, y_pred)
        rmse_scores.append(rmse_score)

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmse_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=50))
    study.optimize(lambda trial: objective_lgbm(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
cat_study = tune_hyperparameters(X, y, model_class=LGBMRegressor, n_trials=31, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)
save_results(cat_study, LGBMRegressor, "LGBMBoost_ext")
cat_params = cat_study.best_params

# %% [markdown]
#   1. Trial 20 finished with value: 0.060152195761392024 and parameters: {'num_leaves': 100, 'min_child_samples': 53, 'subsample': 0.9110612004769245, 'subsample_freq': 2, 'colsample_bytree': 0.8399716198238704, 'reg_alpha': 0.964428009726069, 'reg_lambda': 0.011222743073631622}

# %% [markdown]
# ### 3.2.2 Train Model:

# %%
lgbm_prob = {"objective":"regression","eval_metric":"rmse"}
categorical_features = data.X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()

# %%
X = data.X
y = np.log1p(data.y)
categorical_features
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %%
X_test = data.X_test

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

# %% [markdown]
# **FIT THE MODEL**

# %%
param = {
        'num_leaves': 100,
        'learning_rate': 0.02,
        'min_child_samples': 53,
        'subsample': 0.911,
        'subsample_freq': 2,
        'colsample_bytree': 0.84,
        "reg_alpha" : 0.9644,
        "reg_lambda" : 0.011222743073631622,
        "boosting_type": 'gbdt',
        'n_estimators': 2501,
        'objective': lgbm_prob["objective"],
        'device': 'gpu',
        'verbose': -1,
        'random_state': 42,
        }

models={'LGBMR1':[LGBMRegressor(**param),True]}

TM = TrainModels(X=X, y=y, X_test=X_test, X_original=None, y_original=None, models=models)
TM.fit_models()
# Out:
#      Fitting LGBMR1
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1384]	valid_0's l2: 0.00354947
# Pred Min&Max Valid: 1.032988726715588 and 292.5480952333634
# Pred Min&Max Test: 0.9392459161049869 and 290.59603709048764
# Pred Min&Max Valid Adj: 1.032988726715588 and 292.5480952333634
# Pred Min&Max Test Adj: 1.0 and 290.59603709048764
# Fold 1 → Training set Score: 0.05653 | Validation set Score: 0.05958
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1593]	valid_0's l2: 0.00377433
# Pred Min&Max Valid: 0.9576994327220378 and 294.9981358836778
# Pred Min&Max Test: 0.9295468402035408 and 290.6443900313503
# Pred Min&Max Valid Adj: 1.0 and 294.9981358836778
# Pred Min&Max Test Adj: 1.0 and 290.6443900313503
# Fold 2 → Training set Score: 0.05608 | Validation set Score: 0.06144
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1224]	valid_0's l2: 0.00352347
# Pred Min&Max Valid: 1.0122898522887636 and 290.82761334657926
# Pred Min&Max Test: 0.932366875704449 and 290.4432144077622
# Pred Min&Max Valid Adj: 1.0122898522887636 and 290.82761334657926
# Pred Min&Max Test Adj: 1.0 and 290.4432144077622
# Fold 3 → Training set Score: 0.05686 | Validation set Score: 0.05936
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1958]	valid_0's l2: 0.00387073
# Pred Min&Max Valid: 0.951238082290189 and 285.0975261224084
# Pred Min&Max Test: 0.907805715299979 and 291.37503879912595
# Pred Min&Max Valid Adj: 1.0 and 285.0975261224084
# Pred Min&Max Test Adj: 1.0 and 291.37503879912595
# Fold 4 → Training set Score: 0.05533 | Validation set Score: 0.06222
# Training until validation scores don't improve for 101 rounds
# Did not meet early stopping. Best iteration is:
# [2497]	valid_0's l2: 0.00356315
# Pred Min&Max Valid: 0.9022515127780788 and 288.7492806254294
# Pred Min&Max Test: 0.8689667623138353 and 292.56208944103054
# Pred Min&Max Valid Adj: 1.0 and 288.7492806254294
# Pred Min&Max Test Adj: 1.0 and 292.56208944103054
# Fold 5 → Training set Score: 0.05472 | Validation set Score: 0.05969
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1265]	valid_0's l2: 0.00363715
# Pred Min&Max Valid: 1.0017598481556813 and 320.82072154866967
# Pred Min&Max Test: 0.9167748619992193 and 291.08720465118404
# Pred Min&Max Valid Adj: 1.0017598481556813 and 315.0
# Pred Min&Max Test Adj: 1.0 and 291.08720465118404
# Fold 6 → Training set Score: 0.05672 | Validation set Score: 0.06031
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1348]	valid_0's l2: 0.00333798
# Pred Min&Max Valid: 0.8928070772477594 and 291.61604927011973
# Pred Min&Max Test: 0.8928070772477594 and 291.1360023795073
# Pred Min&Max Valid Adj: 1.0 and 291.61604927011973
# Pred Min&Max Test Adj: 1.0 and 291.1360023795073
# Fold 7 → Training set Score: 0.05675 | Validation set Score: 0.05777
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1300]	valid_0's l2: 0.00350224
# Pred Min&Max Valid: 0.9844010137133263 and 288.7690121939562
# Pred Min&Max Test: 0.9429799324892129 and 292.0946460285041
# Pred Min&Max Valid Adj: 1.0 and 288.7690121939562
# Pred Min&Max Test Adj: 1.0 and 292.0946460285041
# Fold 8 → Training set Score: 0.05674 | Validation set Score: 0.05918
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1656]	valid_0's l2: 0.00373711
# Pred Min&Max Valid: 0.9972706934891155 and 292.1492513033814
# Pred Min&Max Test: 0.9222297030688452 and 292.67545787274685
# Pred Min&Max Valid Adj: 1.0 and 292.1492513033814
# Pred Min&Max Test Adj: 1.0 and 292.67545787274685
# Fold 9 → Training set Score: 0.05594 | Validation set Score: 0.06113
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [2136]	valid_0's l2: 0.00361933
# Pred Min&Max Valid: 0.9390176544423943 and 291.3545259072416
# Pred Min&Max Test: 0.9012167524340482 and 291.03644110933504
# Pred Min&Max Valid Adj: 1.0 and 291.3545259072416
# Pred Min&Max Test Adj: 1.0 and 291.03644110933504
# Fold 10 → Training set Score: 0.05523 | Validation set Score: 0.06016
# Training until validation scores don't improve for 101 rounds
# Early stopping, best iteration is:
# [1841]	valid_0's l2: 0.00349617
# Pred Min&Max Valid: 0.9605950186525326 and 291.9831024849306
# Pred Min&Max Test: 0.8901300468477407 and 291.05935046490816
# Pred Min&Max Valid Adj: 1.0 and 291.9831024849306
# Pred Min&Max Test Adj: 1.0 and 291.05935046490816
# Fold 11 → Training set Score: 0.05574 | Validation set Score: 0.05913
# Overall → Training set Score: 0.05606±0.0006997 | Validation set Score: 0.06000±0.0011847

# %% [markdown]
# ### 3.1.3 Store Results:

# %%
name_experiment = "LGBMR1_adj_values"

test_pred = TM.OOF_test.mean(axis=1) #np.expm1(TM.OOF_test.mean(axis=1))
train_pred = TM.OOF_train.mean(axis=1) #np.expm1(TM.OOF_train.mean(axis=1))

# %%
test_pred.min(), test_pred.max()
# Out:
# (1.0000000000000002, 291.14381449510853)

# %%
test_pred.head()
# Out:
# 0     27.279653
# 1    107.655338
# 2     87.842934
# 3    126.666362
# 4     76.492034
# dtype: float64

# %%
sub["Calories"] =  test_pred.values

sub.head()
# Out:
#           Calories
# id
# 750000   27.279653
# 750001  107.655338
# 750002   87.842934
# 750003  126.666362
# 750004   76.492034

# %%
train_pred.head()
# Out:
# 0    146.999462
# 1     36.106989
# 2     29.404559
# 3    137.793549
# 4    145.848326
# dtype: float64

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")

# %% [markdown]
# ## **3.3.0 XGBRegressor**

# %%
import xgboost as xgb
xgb_prob = {'objective': "reg:squarederror",'eval_metric': "rmse"}

# %%
X = data.X
y = np.log1p(data.y)
categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
categorical_features
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %% [markdown]
# ### 3.2.1 Optuna Optimization:

# %%
def objective_xgb(trial, X, y, n_splits=5, n_repeats=5, model=XGBRegressor, use_gpu=True, rs=42, fit_scaling=False, cv_strategy="KFold", metrics=xgb_prob, categorical_features=categorical_features):

    model_class = model

    num_cols = [col for col in X.columns if col not in categorical_features]

    params = {
              'n_estimators': 2000,
              'learning_rate': 0.02, #trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
              'max_depth': trial.suggest_int('max_depth', 7, 15),
              'max_bin': trial.suggest_int('max_bin', 255, 511),
              'min_child_weight': trial.suggest_int('min_child_weight', 1, 12),
              'subsample': trial.suggest_float('subsample', 0.5, 0.975, step=0.025),
              'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 0.975, step=0.025),
              'gamma': trial.suggest_float('gamma', 0, 1),
              'reg_alpha': trial.suggest_float('reg_alpha', 0.00001, 1.0, log=True),
              'reg_lambda': trial.suggest_float('reg_lambda', 0.00001, 10, log=True),
              'objective':  metrics["objective"],  # For binary classification
              'eval_metric': metrics["eval_metric"],
              "early_stopping_rounds":101,
              'tree_method': 'gpu_hist' if use_gpu else 'hist',  # Use GPU if available
              'random_state': rs,
              'enable_categorical': True,
#              'scale_pos_weight': sample_pos_weight,
             }

    if cv_strategy == 'RepKFold':
        kf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)
    elif cv_strategy == 'KFold':
        kf = KFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "StratKFold":
        kf = StratifiedKFold(n_splits=n_splits, random_state=rs, shuffle=True)
    elif cv_strategy == "RepStratKFold":
        kf = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=rs)

    rmse_scores = []

    for idx_train, idx_valid in kf.split(X, y):

        # Split the data into training and validation sets for the current fold
        X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1, 1)
        X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1, 1)

        if fit_scaling:
            scaler = StandardScaler()
            X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
            X_valid[num_cols] = scaler.transform(X_valid[num_cols])

        # Create the datasets for LightGBM
        # d_train = lgb.Dataset(X_train, label=y_train, categorical_feature=categorical_features)
        # d_valid = lgb.Dataset(X_valid, label=y_valid, categorical_feature=categorical_features)

        # Create the model
        model = model_class(**params)

        # Fit the model
        model.fit(X_train, y_train,
                  eval_set=[(X_valid, y_valid)],
                  verbose=False)

        # Make predictions on the validation set
        y_pred = model.predict(X_valid)

        # Calculate the RMSE for the current fold

        rmse_score = root_mean_squared_error(y_valid, y_pred)
        rmse_scores.append(rmse_score)

    # Calculate the mean RMSLE score across all folds
    key_metric = np.mean(rmse_scores)

    return key_metric

# %%
# Step 2: Tuning Hyperparameters with Optuna
def tune_hyperparameters(X, y, model_class, n_trials, n_splits_ ,n_repeats_, use_gpu=True):  #use_gpu
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner(n_warmup_steps=50))
    study.optimize(lambda trial: objective_xgb(trial, X, y, n_splits=n_splits_, n_repeats=n_repeats_, model=model_class, use_gpu=use_gpu, cv_strategy="KFold"), n_trials=n_trials)
    return study  # Return the study object

# Step 3: Saving Best Results and Models
def save_results(study, model_class, model_name):
    best_params_file = f"{model_name}_best_params.joblib"
    joblib.dump(study.best_params, best_params_file)
    print(f"Best parameters for {model_name} saved to {best_params_file}")

    verbose_file = f"{model_name}_optuna_verbose.log"
    with open(verbose_file, "w") as f:
        f.write(str(study.trials))
    print(f"Optuna verbose for {model_name} saved to {verbose_file}")# usage with XGBRegressor

# %%
cat_study = tune_hyperparameters(X, y, model_class=XGBRegressor, n_trials=31, n_splits_ = 5 ,n_repeats_=3, use_gpu=True)
save_results(cat_study, objective_xgb, "XGBoost_ext")
cat_params = cat_study.best_params
# Out:
# [I 2025-05-13 23:56:32,557] A new study created in memory with name: no-name-f61b9563-6cd9-409b-a823-4830f8bc403b
# [I 2025-05-13 23:56:47,659] Trial 0 finished with value: 0.06529265510506486 and parameters: {'max_depth': 3, 'max_bin': 364, 'min_child_weight': 4, 'subsample': 0.925, 'colsample_bytree': 0.925, 'gamma': 0.5853199987791803, 'reg_alpha': 9.334851179109873e-05, 'reg_lambda': 0.13678509600698566}. Best is trial 0 with value: 0.06529265510506486.
# [I 2025-05-13 23:57:00,992] Trial 1 finished with value: 0.0620054812155601 and parameters: {'max_depth': 6, 'max_bin': 286, 'min_child_weight': 6, 'subsample': 0.875, 'colsample_bytree': 0.925, 'gamma': 0.5323086203317581, 'reg_alpha': 0.0018671894773744566, 'reg_lambda': 0.0003852197809192416}. Best is trial 1 with value: 0.0620054812155601.
# [I 2025-05-13 23:57:14,664] Trial 2 finished with value: 0.060875612289450355 and parameters: {'max_depth': 7, 'max_bin': 357, 'min_child_weight': 12, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.8, 'gamma': 0.178738274341804, 'reg_alpha': 0.0022482006253020945, 'reg_lambda': 4.577682253027604e-05}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:57:26,559] Trial 3 finished with value: 0.06498220811658775 and parameters: {'max_depth': 4, 'max_bin': 361, 'min_child_weight': 9, 'subsample': 0.825, 'colsample_bytree': 0.925, 'gamma': 0.7959737471529797, 'reg_alpha': 1.7332446167972172e-05, 'reg_lambda': 2.632688743092755}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:57:45,385] Trial 4 finished with value: 0.061163859291907686 and parameters: {'max_depth': 10, 'max_bin': 479, 'min_child_weight': 10, 'subsample': 0.925, 'colsample_bytree': 0.675, 'gamma': 0.49261124821714175, 'reg_alpha': 6.0029495167202926e-05, 'reg_lambda': 1.4464157460281626}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:57:57,793] Trial 5 finished with value: 0.06353013310440059 and parameters: {'max_depth': 5, 'max_bin': 333, 'min_child_weight': 12, 'subsample': 0.9, 'colsample_bytree': 0.825, 'gamma': 0.7715579347547814, 'reg_alpha': 0.00018909716722202423, 'reg_lambda': 0.000747342409890726}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:58:14,732] Trial 6 finished with value: 0.06107187126602896 and parameters: {'max_depth': 9, 'max_bin': 435, 'min_child_weight': 10, 'subsample': 0.675, 'colsample_bytree': 0.775, 'gamma': 0.4629436008061365, 'reg_alpha': 1.3161828340519335e-05, 'reg_lambda': 0.0003363888703174185}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:58:25,841] Trial 7 finished with value: 0.06234284453185264 and parameters: {'max_depth': 6, 'max_bin': 427, 'min_child_weight': 7, 'subsample': 0.95, 'colsample_bytree': 0.9, 'gamma': 0.8459341388286613, 'reg_alpha': 0.0006830574135212922, 'reg_lambda': 1.193621870579611e-05}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:58:43,822] Trial 8 finished with value: 0.0612661130934178 and parameters: {'max_depth': 11, 'max_bin': 463, 'min_child_weight': 5, 'subsample': 0.625, 'colsample_bytree': 0.875, 'gamma': 0.6542734081373073, 'reg_alpha': 0.4265979109926748, 'reg_lambda': 0.2674248326366859}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:58:55,885] Trial 9 finished with value: 0.0654193834941527 and parameters: {'max_depth': 3, 'max_bin': 430, 'min_child_weight': 6, 'subsample': 0.725, 'colsample_bytree': 0.775, 'gamma': 0.7738242048058911, 'reg_alpha': 0.008725262582134245, 'reg_lambda': 0.07629770580167611}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:59:15,306] Trial 10 finished with value: 0.061133553688427135 and parameters: {'max_depth': 8, 'max_bin': 280, 'min_child_weight': 1, 'subsample': 0.5, 'colsample_bytree': 0.5, 'gamma': 0.09564220009364777, 'reg_alpha': 0.022000657389297767, 'reg_lambda': 1.22356191744771e-05}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:59:32,639] Trial 11 finished with value: 0.0609406522756498 and parameters: {'max_depth': 9, 'max_bin': 407, 'min_child_weight': 12, 'subsample': 0.7, 'colsample_bytree': 0.675, 'gamma': 0.2505395595177349, 'reg_alpha': 0.2278567960737405, 'reg_lambda': 0.000344923340341444}. Best is trial 2 with value: 0.060875612289450355.
# [I 2025-05-13 23:59:59,433] Trial 12 finished with value: 0.06077217567731995 and parameters: {'max_depth': 12, 'max_bin': 389, 'min_child_weight': 12, 'subsample': 0.8, 'colsample_bytree': 0.65, 'gamma': 0.1974041284386524, 'reg_alpha': 0.1059923928384762, 'reg_lambda': 0.004855029869544304}. Best is trial 12 with value: 0.06077217567731995.
# [I 2025-05-14 00:00:50,580] Trial 13 finished with value: 0.060350648468811594 and parameters: {'max_depth': 12, 'max_bin': 326, 'min_child_weight': 12, 'subsample': 0.8, 'colsample_bytree': 0.6, 'gamma': 0.018508753127972066, 'reg_alpha': 0.0552671436393784, 'reg_lambda': 0.005694020488157845}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:01:32,870] Trial 14 finished with value: 0.06075789188391183 and parameters: {'max_depth': 12, 'max_bin': 315, 'min_child_weight': 9, 'subsample': 0.775, 'colsample_bytree': 0.55, 'gamma': 0.036870059849070824, 'reg_alpha': 0.05885316112773869, 'reg_lambda': 0.0049250314423676545}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:02:23,124] Trial 15 finished with value: 0.060732249700172436 and parameters: {'max_depth': 12, 'max_bin': 320, 'min_child_weight': 8, 'subsample': 0.775, 'colsample_bytree': 0.5, 'gamma': 0.023502071296870455, 'reg_alpha': 0.047416899392530756, 'reg_lambda': 0.008433949629746059}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:02:44,632] Trial 16 finished with value: 0.06170792241048967 and parameters: {'max_depth': 11, 'max_bin': 256, 'min_child_weight': 3, 'subsample': 0.625, 'colsample_bytree': 0.575, 'gamma': 0.3354114630347529, 'reg_alpha': 0.9873445399197669, 'reg_lambda': 0.020184254690459202}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:03:03,344] Trial 17 finished with value: 0.06105385135423637 and parameters: {'max_depth': 10, 'max_bin': 312, 'min_child_weight': 8, 'subsample': 0.775, 'colsample_bytree': 0.6, 'gamma': 0.33524221222943124, 'reg_alpha': 0.015906652367994725, 'reg_lambda': 0.015655777899834456}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:03:20,081] Trial 18 finished with value: 0.06292058506997347 and parameters: {'max_depth': 12, 'max_bin': 332, 'min_child_weight': 10, 'subsample': 0.525, 'colsample_bytree': 0.5, 'gamma': 0.9926023072488238, 'reg_alpha': 0.04723997565132562, 'reg_lambda': 0.0013352160009310176}. Best is trial 13 with value: 0.060350648468811594.
# [I 2025-05-14 00:03:55,792] Trial 19 finished with value: 0.06026561787609451 and parameters: {'max_depth': 11, 'max_bin': 506, 'min_child_weight': 8, 'subsample': 0.75, 'colsample_bytree': 0.625, 'gamma': 0.03198716430356102, 'reg_alpha': 0.005920920023078226, 'reg_lambda': 9.235055695333049}. Best is trial 19 with value: 0.06026561787609451.
# [I 2025-05-14 00:04:20,881] Trial 20 finished with value: 0.0604551932139641 and parameters: {'max_depth': 10, 'max_bin': 507, 'min_child_weight': 2, 'subsample': 0.65, 'colsample_bytree': 0.725, 'gamma': 0.12057683168076294, 'reg_alpha': 0.000781785761512836, 'reg_lambda': 5.616851101479858}. Best is trial 19 with value: 0.06026561787609451.
# [I 2025-05-14 00:04:48,853] Trial 21 finished with value: 0.060509401824771256 and parameters: {'max_depth': 10, 'max_bin': 510, 'min_child_weight': 1, 'subsample': 0.65, 'colsample_bytree': 0.725, 'gamma': 0.11283242166307769, 'reg_alpha': 0.005184173223404903, 'reg_lambda': 7.392186945435729}. Best is trial 19 with value: 0.06026561787609451.
# [I 2025-05-14 00:05:26,609] Trial 22 finished with value: 0.0602147861785423 and parameters: {'max_depth': 11, 'max_bin': 510, 'min_child_weight': 3, 'subsample': 0.575, 'colsample_bytree': 0.625, 'gamma': 0.021768835141640692, 'reg_alpha': 0.0007093863226804355, 'reg_lambda': 0.7040293909117527}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:05:47,475] Trial 23 finished with value: 0.06102519565401473 and parameters: {'max_depth': 11, 'max_bin': 475, 'min_child_weight': 4, 'subsample': 0.55, 'colsample_bytree': 0.6, 'gamma': 0.2887956920267579, 'reg_alpha': 0.0006074904734497947, 'reg_lambda': 0.6204430663841445}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:06:18,476] Trial 24 finished with value: 0.06024260720312259 and parameters: {'max_depth': 9, 'max_bin': 493, 'min_child_weight': 5, 'subsample': 0.575, 'colsample_bytree': 0.65, 'gamma': 0.005279479682215683, 'reg_alpha': 0.004641947307868475, 'reg_lambda': 0.05355723390937575}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:06:49,036] Trial 25 finished with value: 0.06028009808685201 and parameters: {'max_depth': 8, 'max_bin': 491, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.65, 'gamma': 0.005526354594843932, 'reg_alpha': 0.003099311539085243, 'reg_lambda': 0.8061743642620728}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:07:07,053] Trial 26 finished with value: 0.061077613319862764 and parameters: {'max_depth': 9, 'max_bin': 455, 'min_child_weight': 3, 'subsample': 0.575, 'colsample_bytree': 0.7, 'gamma': 0.3920261311285902, 'reg_alpha': 0.0003254977076259817, 'reg_lambda': 0.05794212810514074}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:07:32,083] Trial 27 finished with value: 0.061121242035771864 and parameters: {'max_depth': 11, 'max_bin': 492, 'min_child_weight': 7, 'subsample': 0.725, 'colsample_bytree': 0.55, 'gamma': 0.18165630950507602, 'reg_alpha': 0.0013382475862118357, 'reg_lambda': 0.32244757548031633}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:07:53,158] Trial 28 finished with value: 0.060585479162935274 and parameters: {'max_depth': 9, 'max_bin': 452, 'min_child_weight': 5, 'subsample': 0.525, 'colsample_bytree': 0.625, 'gamma': 0.08300014549038395, 'reg_alpha': 0.006611887270293495, 'reg_lambda': 2.8725561814111984}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:08:10,883] Trial 29 finished with value: 0.06137616558447069 and parameters: {'max_depth': 8, 'max_bin': 493, 'min_child_weight': 4, 'subsample': 0.575, 'colsample_bytree': 0.55, 'gamma': 0.20820767922399552, 'reg_alpha': 0.00012432850387365143, 'reg_lambda': 0.1656888253380197}. Best is trial 22 with value: 0.0602147861785423.
# [I 2025-05-14 00:08:28,667] Trial 30 finished with value: 0.06108701461638292 and parameters: {'max_depth': 7, 'max_bin': 509, 'min_child_weight': 3, 'subsample': 0.675, 'colsample_bytree': 0.65, 'gamma': 0.15421284270936855, 'reg_alpha': 0.017373161577890157, 'reg_lambda': 9.503655092825545}. Best is trial 22 with value: 0.0602147861785423.
# Best parameters for LGBMBoost_ext saved to LGBMBoost_ext_best_params.joblib
# Optuna verbose for LGBMBoost_ext saved to LGBMBoost_ext_optuna_verbose.log

# %% [markdown]
#   1. Trial 22 finished with value: 0.0602147861785423 and parameters: {'max_depth': 11, 'max_bin': 510, 'min_child_weight': 3, 'subsample': 0.575, 'colsample_bytree': 0.625, 'gamma': 0.021768835141640692, 'reg_alpha': 0.0007093863226804355, 'reg_lambda': 0.7040293909117527}

# %%
cat_params
# Out:
# {'max_depth': 11,
#  'max_bin': 510,
#  'min_child_weight': 3,
#  'subsample': 0.575,
#  'colsample_bytree': 0.625,
#  'gamma': 0.021768835141640692,
#  'reg_alpha': 0.0007093863226804355,
#  'reg_lambda': 0.7040293909117527}

# %% [markdown]
# ### 3.2.2 Train Model:

# %%
xgb_prob = {'objective': "reg:squarederror",'eval_metric': "rmse"}
categorical_features = data.X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()

# %%
X = data.X
y = np.log1p(data.y)
categorical_features
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %%
X_test = data.X_test

sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)

# %% [markdown]
# **FIT THE MODEL**

# %%
param = {
              'n_estimators': 2000,
              'learning_rate': 0.02,
              'max_depth': 11,
              'max_bin': 510,
              'min_child_weight': 3,
              'subsample': 0.575,
              'colsample_bytree': 0.625,
              'gamma': 0.02177,
              'reg_alpha': 0.00071,
              'reg_lambda': 0.70403,
              'objective':  xgb_prob["objective"],
              'eval_metric': xgb_prob["eval_metric"],
              "early_stopping_rounds":101,
              'tree_method': 'gpu_hist' ,
              'random_state': 42,
              'enable_categorical': True,
             }

models={'XGBR1':[XGBRegressor(**param),True]}

TM = TrainModels(X=X, y=y, X_test=X_test, X_original=None, y_original=None, models=models)
TM.fit_models()
# Out:
#      Fitting XGBR1
# [0]	validation_0-rmse:0.94211
# [250]	validation_0-rmse:0.06070
# [500]	validation_0-rmse:0.05988
# [740]	validation_0-rmse:0.05989
# Pred Min&Max Valid: 0.9872747659683228 and 296.73199462890625
# Pred Min&Max Test: 0.9147478938102722 and 297.70037841796875
# Pred Min&Max Valid Adj: 1.0 and 296.73199462890625
# Pred Min&Max Test Adj: 1.0 and 297.70037841796875
# Fold 1 → Training set Score: 0.05223 | Validation set Score: 0.05986
# [0]	validation_0-rmse:0.94696
# [250]	validation_0-rmse:0.06236
# [500]	validation_0-rmse:0.06136
# [750]	validation_0-rmse:0.06133
# [855]	validation_0-rmse:0.06133
# Pred Min&Max Valid: 1.0667113065719604 and 299.7885437011719
# Pred Min&Max Test: 0.9063337445259094 and 298.1318054199219
# Pred Min&Max Valid Adj: 1.0667113065719604 and 299.7885437011719
# Pred Min&Max Test Adj: 1.0 and 298.1318054199219
# Fold 2 → Training set Score: 0.05191 | Validation set Score: 0.06132
# [0]	validation_0-rmse:0.93967
# [250]	validation_0-rmse:0.06012
# [500]	validation_0-rmse:0.05946
# [550]	validation_0-rmse:0.05948
# Pred Min&Max Valid: 0.9888100028038025 and 295.44964599609375
# Pred Min&Max Test: 0.926777184009552 and 296.3290710449219
# Pred Min&Max Valid Adj: 1.0 and 295.44964599609375
# Pred Min&Max Test Adj: 1.0 and 296.3290710449219
# Fold 3 → Training set Score: 0.05302 | Validation set Score: 0.05944
# [0]	validation_0-rmse:0.94168
# [250]	validation_0-rmse:0.06316
# [500]	validation_0-rmse:0.06190
# [750]	validation_0-rmse:0.06184
# [837]	validation_0-rmse:0.06185
# Pred Min&Max Valid: 0.930097222328186 and 296.9490051269531
# Pred Min&Max Test: 0.8886658549308777 and 297.9425964355469
# Pred Min&Max Valid Adj: 1.0 and 296.9490051269531
# Pred Min&Max Test Adj: 1.0 and 297.9425964355469
# Fold 4 → Training set Score: 0.05186 | Validation set Score: 0.06184
# [0]	validation_0-rmse:0.94858
# [250]	validation_0-rmse:0.06003
# [500]	validation_0-rmse:0.05923
# [692]	validation_0-rmse:0.05922
# Pred Min&Max Valid: 0.9776326417922974 and 289.9680480957031
# Pred Min&Max Test: 0.9414525032043457 and 298.1326599121094
# Pred Min&Max Valid Adj: 1.0 and 289.9680480957031
# Pred Min&Max Test Adj: 1.0 and 298.1326599121094
# Fold 5 → Training set Score: 0.05241 | Validation set Score: 0.05921
# [0]	validation_0-rmse:0.94494
# [250]	validation_0-rmse:0.06174
# [500]	validation_0-rmse:0.06107
# [675]	validation_0-rmse:0.06109
# Pred Min&Max Valid: 0.9956483840942383 and 307.4631042480469
# Pred Min&Max Test: 0.9295869469642639 and 294.0664367675781
# Pred Min&Max Valid Adj: 1.0 and 307.4631042480469
# Pred Min&Max Test Adj: 1.0 and 294.0664367675781
# Fold 6 → Training set Score: 0.05243 | Validation set Score: 0.06106
# [0]	validation_0-rmse:0.93836
# [250]	validation_0-rmse:0.05853
# [500]	validation_0-rmse:0.05780
# [639]	validation_0-rmse:0.05780
# Pred Min&Max Valid: 0.9077377915382385 and 296.5127258300781
# Pred Min&Max Test: 0.9077377915382385 and 300.20965576171875
# Pred Min&Max Valid Adj: 1.0 and 296.5127258300781
# Pred Min&Max Test Adj: 1.0 and 300.20965576171875
# Fold 7 → Training set Score: 0.05261 | Validation set Score: 0.05778
# [0]	validation_0-rmse:0.94590
# [250]	validation_0-rmse:0.06040
# [500]	validation_0-rmse:0.05980
# [607]	validation_0-rmse:0.05981
# Pred Min&Max Valid: 1.007584571838379 and 293.82257080078125
# Pred Min&Max Test: 0.9130253195762634 and 297.3527526855469
# Pred Min&Max Valid Adj: 1.007584571838379 and 293.82257080078125
# Pred Min&Max Test Adj: 1.0 and 297.3527526855469
# Fold 8 → Training set Score: 0.05280 | Validation set Score: 0.05980
# [0]	validation_0-rmse:0.94638
# [250]	validation_0-rmse:0.06189
# [500]	validation_0-rmse:0.06084
# [750]	validation_0-rmse:0.06083
# [771]	validation_0-rmse:0.06084
# Pred Min&Max Valid: 0.9901741743087769 and 294.3338928222656
# Pred Min&Max Test: 0.9060819745063782 and 299.6474609375
# Pred Min&Max Valid Adj: 1.0 and 294.3338928222656
# Pred Min&Max Test Adj: 1.0 and 299.6474609375
# Fold 9 → Training set Score: 0.05211 | Validation set Score: 0.06079
# [0]	validation_0-rmse:0.94432
# [250]	validation_0-rmse:0.06101
# [500]	validation_0-rmse:0.06008
# [669]	validation_0-rmse:0.06009
# Pred Min&Max Valid: 0.9718769192695618 and 296.1157531738281
# Pred Min&Max Test: 0.919245719909668 and 300.2544860839844
# Pred Min&Max Valid Adj: 1.0 and 296.1157531738281
# Pred Min&Max Test Adj: 1.0 and 300.2544860839844
# Fold 10 → Training set Score: 0.05252 | Validation set Score: 0.06005
# [0]	validation_0-rmse:0.94556
# [250]	validation_0-rmse:0.06011
# [500]	validation_0-rmse:0.05949
# [544]	validation_0-rmse:0.05949
# Pred Min&Max Valid: 1.083740234375 and 295.4007263183594
# Pred Min&Max Test: 0.9200512170791626 and 296.8116455078125
# Pred Min&Max Valid Adj: 1.083740234375 and 295.4007263183594
# Pred Min&Max Test Adj: 1.0 and 296.8116455078125
# Fold 11 → Training set Score: 0.05304 | Validation set Score: 0.05947
# Overall → Training set Score: 0.05245±0.0003838 | Validation set Score: 0.06006±0.0010890

# %% [markdown]
# ### 3.1.3 Store Results:

# %%
name_experiment = "XGBR1_adj_values"

test_pred = TM.OOF_test.mean(axis=1) #np.expm1(TM.OOF_test.mean(axis=1))
train_pred = TM.OOF_train.mean(axis=1) #np.expm1(TM.OOF_train.mean(axis=1))

# %%
test_pred.min(), test_pred.max()
# Out:
# (1.0000000298023224, 297.8708152770996)

# %%
test_pred.head()
# Out:
# 0     27.330049
# 1    107.175077
# 2     87.019606
# 3    127.669816
# 4     75.983582
# dtype: float64

# %%
sub["Calories"] =  test_pred.values

sub.head()
# Out:
#           Calories
# id
# 750000   27.330049
# 750001  107.175077
# 750002   87.019606
# 750003  127.669816
# 750004   75.983582

# %%
train_pred.head()
# Out:
# 0    146.823349
# 1     36.095840
# 2     29.293856
# 3    138.474319
# 4    145.539383
# dtype: float64

# %%
fig, ax = plt.subplots(1,2,figsize=(12,3))

ax[0].hist(train_pred, bins=31)
ax[1].hist(sub, bins=31, color="salmon")

plt.show()

# %%
sub.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/submission_{name_experiment}.csv")
train_pred.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train_pred_{name_experiment}.csv")
